# %% [markdown]
# # STHSL End-to-End Runner — Baseline / Option1 / Option2 (NYC + CHI)
#
# 1. **Path verification**
# 2. Train NYC (baseline)
# 3. Test NYC (baseline) — `metrics_generation.py`
# 4. Extract + analyze NYC (baseline) — `metrics_extraction.py` + `analyse_metrics.py`
# 5. Repeat 2–4 for NYC (option1)
# 6. Repeat 2–4 for NYC (option2)
# 7. Repeat 2–6 for CHI

# %% [markdown]
# ## 1) Path verification + shared helpers

# %%
from pathlib import Path
import os, shlex, subprocess

# ---- EDIT ONLY IF NEEDED ----
REPO_ROOT = Path(".").resolve()
PYTHON = os.environ.get("PYTHON", "python")

TRAIN = REPO_ROOT / "train.py"
METRICS_GEN = REPO_ROOT / "metrics_generation.py"
METRICS_EXTRACT = REPO_ROOT / "metrics_extraction.py"
ANALYSE = REPO_ROOT / "analyse_metrics.py"

SAVE_DIR = REPO_ROOT / "Save"                 # training outputs
LOGS_DIR = REPO_ROOT / "Logs"                 # where you move checkpoints
TESTS_DIR = REPO_ROOT / "tests_validation"    # metrics_generation out-dir root

def must_exist(p: Path):
    if not p.exists():
        raise FileNotFoundError(f"Missing: {p}")
    print("OK:", p)

print("REPO_ROOT:", REPO_ROOT)
must_exist(TRAIN)
must_exist(METRICS_GEN)
must_exist(METRICS_EXTRACT)
must_exist(ANALYSE)

# Ensure dirs exist
SAVE_DIR.mkdir(exist_ok=True)
LOGS_DIR.mkdir(exist_ok=True)
TESTS_DIR.mkdir(exist_ok=True)

def run(cmd, cwd=REPO_ROOT, timeout=None):
    """Run a command (list[str] or str). Prints the command and last output."""
    if isinstance(cmd, str):
        printable = cmd
        shell = True
    else:
        printable = " ".join(shlex.quote(str(x)) for x in cmd)
        shell = False
    print("\\n$ " + printable)
    p = subprocess.run(
        cmd,
        cwd=str(cwd),
        shell=shell,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        encoding="utf-8",   # <-- forces decoding as UTF-8
        errors="replace",   # <-- prevents crash on bad bytes
        timeout=timeout
    )
    out = p.stdout or ""
    print(out[-4000:])
    if p.returncode != 0:
        raise RuntimeError(f"Command failed (rc={p.returncode}). See output above.")
    return out

def ensure_dir(p: Path):
    p.mkdir(parents=True, exist_ok=True)
    return p

print("\nReady.")
# Out:
# REPO_ROOT: /home/jovyan/STHSL
# OK: /home/jovyan/STHSL/train.py
# OK: /home/jovyan/STHSL/metrics_generation.py
# OK: /home/jovyan/STHSL/metrics_extraction.py
# OK: /home/jovyan/STHSL/analyse_metrics.py
#
# Ready.

# %% [markdown]
# ## Conventions
#
# - `--use_ode_option`: `baseline`, `option1`, `option2`
# - Dataset values: `NYC`, `CHI`
# - Test output: `tests_validation/<arch>/<dataset>/`
# - Logs: `Logs/<arch>/<dataset>/`

# %%
def logs_dir(arch: str, ds: str) -> Path:
    return LOGS_DIR / arch / ds

def tests_dir(arch: str, ds: str) -> Path:
    return TESTS_DIR / arch / ds

def metrics_pivot_csv(arch: str, ds: str) -> Path:
    return tests_dir(arch, ds) / "metrics_all_epochs_pivot.csv"

# %% [markdown]
# ## Helper defs for pipeline (train → test → extract → analyze)

# %%
import shutil
import glob
from pathlib import Path

def step_train(ds: str, arch: str):
    # baseline: python train.py --data NYC
    # option1:  python train.py --data NYC --use_ode_option option1
    # option2:  python train.py --data NYC --use_ode_option option2
    cmd = [PYTHON, str(TRAIN), "--data", ds]
    if arch in ("option1", "option2"):
        cmd += ["--use_ode_option", arch]
    elif arch == "baseline":
        cmd += ["--use_ode_option", "baseline"]
        pass
    else:
        raise ValueError(f"Unknown arch: {arch}")
    run(cmd)

def step_test_metrics_generation(ds: str, arch: str):
    # example command: python metrics_generation.py --data NYC --use_ode_option baseline --out-dir tests_validation/baseline/NYC
    out_dir = ensure_dir(tests_dir(arch, ds))
    cmd = [PYTHON, str(METRICS_GEN), "--data", ds, "--use_ode_option", arch, "--save-root", LOGS_DIR/arch, "--out-dir", str(out_dir)]
    run(cmd)

def step_metrics_extraction(ds: str, arch: str):
    # example command: python metrics_extraction.py tests_validation/baseline/NYC/
    out_dir = tests_dir(arch, ds)
    cmd = [PYTHON, str(METRICS_EXTRACT), str(out_dir)]
    run(cmd)

def step_analyse(ds: str, arch: str):
    # example command: python analyse_metrics.py tests_validation/baseline/NYC/metrics_all_epochs_pivot.csv
    pivot = metrics_pivot_csv(arch, ds)
    cmd = [PYTHON, str(ANALYSE), str(pivot)]

    print("Running:", " ".join(cmd))
    subprocess.run(cmd, check=True)

def step_move_checkpoints(
    ds: str,
    arch: str,
    on_conflict: str = "prompt",  # "abort" | "overwrite" | "skip" | "prompt"
):
    """
    Move checkpoints from Save/<ds>/_epoch_* to Logs/<arch>/<ds>/.

    on_conflict behavior:
      - "abort"     : stop if destination files exist (default, safest)
      - "overwrite" : overwrite existing files
      - "skip"      : skip files that already exist
      - "prompt"    : ask user interactively (not for batch runs)
    """
    src_dir = SAVE_DIR / ds
    dst_dir = ensure_dir(logs_dir(arch, ds))

    pattern = str(src_dir / "_epoch_*")
    src_files = sorted(glob.glob(pattern))

    if not src_files:
        raise RuntimeError(f"No checkpoints found matching {pattern}")

    # Detect conflicts
    conflicts = []
    for f in src_files:
        if (dst_dir / Path(f).name).exists():
            conflicts.append(Path(f).name)

    # Resolve conflict policy
    if conflicts:
        if on_conflict == "abort":
            raise RuntimeError(
                f"Checkpoint conflicts detected in {dst_dir}. "
                f"Refusing to overwrite: {conflicts}"
            )

        if on_conflict == "prompt":
            print("\n Existing checkpoint files detected:")
            for c in conflicts:
                print("   -", c)

            print("\nChoose an action:")
            print("  [o] overwrite existing files")
            print("  [s] skip existing files")
            print("  [a] abort")

            choice = input("Your choice [o/s/a]: ").strip().lower()
            if choice == "o":
                on_conflict = "overwrite"
            elif choice == "s":
                on_conflict = "skip"
            else:
                print("Aborted by user.")
                return

        if on_conflict not in ("overwrite", "skip"):
            raise ValueError(f"Invalid on_conflict value: {on_conflict}")

    moved, skipped = 0, 0

    for f in src_files:
        src = Path(f)
        dst = dst_dir / src.name

        if dst.exists():
            if on_conflict == "skip":
                skipped += 1
                continue
            elif on_conflict == "overwrite":
                dst.unlink()

        shutil.move(str(src), str(dst))
        moved += 1

    print(f"\n Checkpoint move completed ({ds} / {arch})")
    print(f"   Moved   : {moved}")
    print(f"   Skipped : {skipped}")

def step_move_checkpoints_from_seeds(
    ds: str,
    arch: str,
    on_conflict: str = "prompt",  # "abort" | "overwrite" | "skip" | "prompt"
):
    """
    Move checkpoints from:
        Save/<ds>/seed_*/   (preferred)
    OR
        Save/<ds>/_epoch_*  (fallback)

    Into:
        Logs/<arch>/<ds>/[seed_x/]...

    Conflict policy:
      - "abort"
      - "overwrite"
      - "skip"
      - "prompt"
    """

    src_root = SAVE_DIR / ds
    dst_root = ensure_dir(logs_dir(arch, ds))

    # -------- Detect seed folders --------
    seed_dirs = sorted([p for p in src_root.glob("seed_*") if p.is_dir()])

    src_files = []
    seed_mode = False

    if seed_dirs:
        seed_mode = True
        print(f"Detected seed folders under {src_root}")
        for seed_dir in seed_dirs:
            pattern = str(seed_dir / "*.pth")
            for f in glob.glob(pattern):
                src_files.append(Path(f))
    else:
        # Fallback: old layout
        pattern = str(src_root / "_epoch_*")
        src_files = [Path(f) for f in glob.glob(pattern)]

    if not src_files:
        raise RuntimeError(f"No checkpoints found in {src_root}")

    # -------- Detect conflicts --------
    conflicts = []
    for src in src_files:
        if seed_mode:
            seed_name = src.parent.name
            dst_dir = ensure_dir(dst_root / seed_name)
        else:
            dst_dir = dst_root

        if (dst_dir / src.name).exists():
            conflicts.append(str((dst_dir / src.name).relative_to(dst_root)))

    if conflicts:
        if on_conflict == "abort":
            raise RuntimeError(
                f"Checkpoint conflicts detected in {dst_root}. "
                f"Refusing to overwrite: {conflicts}"
            )

        if on_conflict == "prompt":
            print("\nExisting checkpoint files detected:")
            for c in conflicts:
                print("  -", c)

            print("\nChoose an action:")
            print("  [o] overwrite existing files")
            print("  [s] skip existing files")
            print("  [a] abort")

            choice = input("Your choice [o/s/a]: ").strip().lower()
            if choice == "o":
                on_conflict = "overwrite"
            elif choice == "s":
                on_conflict = "skip"
            else:
                print("Aborted by user.")
                return

        if on_conflict not in ("overwrite", "skip"):
            raise ValueError(f"Invalid on_conflict value: {on_conflict}")

    moved, skipped = 0, 0

    # -------- Move files --------
    for src in src_files:
        if seed_mode:
            seed_name = src.parent.name
            dst_dir = ensure_dir(dst_root / seed_name)
        else:
            dst_dir = dst_root

        dst = dst_dir / src.name

        if dst.exists():
            if on_conflict == "skip":
                skipped += 1
                continue
            elif on_conflict == "overwrite":
                dst.unlink()

        shutil.move(str(src), str(dst))
        moved += 1

    print(f"\nCheckpoint move completed ({ds} / {arch})")
    print(f"  Mode     : {'seed-aware' if seed_mode else 'flat fallback'}")
    print(f"  Moved    : {moved}")
    print(f"  Skipped  : {skipped}")

# %% [markdown]
# ## Imports

# %%
import sys
print(sys.executable)
# %pip install torchdiffeq
# Out:
# /opt/conda/bin/python
# ...
#   Using cached torchdiffeq-0.2.5-py3-none-any.whl.metadata (440 bytes)
# ...
# Using cached torchdiffeq-0.2.5-py3-none-any.whl (32 kB)
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## cleaning

# %%
# !./cleanup_experiments.sh --dataset NYC --arch all --target all -y
# !./cleanup_experiments.sh --dataset CHI --arch all --target all -y
# Out:
# CLEAN (all contents): Logs/baseline/NYC
# CLEAN (all contents): Logs/option1/NYC
# CLEAN (all contents): Logs/option2/NYC
# CLEAN (all contents): tests_validation/baseline/NYC
# CLEAN (all contents): tests_validation/option1/NYC
# CLEAN (all contents): tests_validation/option2/NYC
# CLEAN (pattern _epoch*): Save/NYC
# Cleanup done.
# CLEAN (all contents): Logs/baseline/CHI
# CLEAN (all contents): Logs/option1/CHI
# CLEAN (all contents): Logs/option2/CHI
# CLEAN (all contents): tests_validation/baseline/CHI
# CLEAN (all contents): tests_validation/option1/CHI
# CLEAN (all contents): tests_validation/option2/CHI
# CLEAN (pattern _epoch*): Save/CHI
# Cleanup done.

# %% [markdown]
# ## Evaluation of error and accuracy metrics separately

# %%
# !python train.py --data NYC --use_ode_option baseline --device cuda --eval_metrics error
step_move_checkpoints_from_seeds("NYC", "baseline", on_conflict="overwrite")
step_test_metrics_generation("NYC", "baseline")
step_metrics_extraction("NYC", "baseline")
step_analyse("NYC", "baseline")

# %%
# !python train.py --data NYC --use_ode_option option1 --device cuda --eval_metrics error
step_move_checkpoints_from_seeds("NYC", "option1", on_conflict="overwrite")
step_test_metrics_generation("NYC", "option1")
step_metrics_extraction("NYC", "option1")
step_analyse("NYC", "option1")

# %%
# !python train.py --data NYC --use_ode_option option2 --device cuda --eval_metrics error
step_move_checkpoints_from_seeds("NYC", "option2", on_conflict="overwrite")
step_test_metrics_generation("NYC", "option2")
step_metrics_extraction("NYC", "option2")
step_analyse("NYC", "option2")

# %%
# !python train.py --data CHI --use_ode_option baseline --device cuda --eval_metrics error
step_move_checkpoints_from_seeds("CHI", "baseline", on_conflict="overwrite")
step_test_metrics_generation("CHI", "baseline")
step_metrics_extraction("CHI", "baseline")
step_analyse("CHI", "baseline")

# %%
# !python train.py --data CHI --use_ode_option option1 --device cuda --eval_metrics error
step_move_checkpoints_from_seeds("CHI", "option1", on_conflict="overwrite")
step_test_metrics_generation("CHI", "option1")
step_metrics_extraction("CHI", "option1")
step_analyse("CHI", "option1")

# %%
# !python train.py --data CHI --use_ode_option option2 --device cuda --eval_metrics error
step_move_checkpoints_from_seeds("CHI", "option2", on_conflict="overwrite")
step_test_metrics_generation("CHI", "option2")
step_metrics_extraction("CHI", "option2")
step_analyse("CHI", "option2")

# %%
# !pwd
# !mv /home/jovyan/STHSL/Logs/* /home/jovyan/error_metrics_10seeds_10epochs/Logs/
# !mv /home/jovyan/STHSL/tests_validation/*/home/jovyan/error_metrics_10seeds_10epochs/tests_validation/

# %%
# !./cleanup_experiments.sh --dataset NYC --arch all --target all -y
# !./cleanup_experiments.sh --dataset CHI --arch all --target all -y

# %%
# !python train.py --data NYC --use_ode_option baseline --device cuda --eval_metrics accuracy
step_move_checkpoints_from_seeds("NYC", "baseline", on_conflict="overwrite")
step_test_metrics_generation("NYC", "baseline")
step_metrics_extraction("NYC", "baseline")
step_analyse("NYC", "baseline")

# %%
# !python train.py --data NYC --use_ode_option option1 --device cuda --eval_metrics accuracy
step_move_checkpoints_from_seeds("NYC", "option1", on_conflict="overwrite")
step_test_metrics_generation("NYC", "option1")
step_metrics_extraction("NYC", "option1")
step_analyse("NYC", "option1")

# %%
# !python train.py --data NYC --use_ode_option option2 --device cuda --eval_metrics accuracy
step_move_checkpoints_from_seeds("NYC", "option2", on_conflict="overwrite")
step_test_metrics_generation("NYC", "option2")
step_metrics_extraction("NYC", "option2")
step_analyse("NYC", "option2")

# %%
# !python train.py --data CHI --use_ode_option baseline --device cuda --eval_metrics accuracy
step_move_checkpoints_from_seeds("CHI", "baseline", on_conflict="overwrite")
step_test_metrics_generation("CHI", "baseline")
step_metrics_extraction("CHI", "baseline")
step_analyse("CHI", "baseline")

# %%
# !python train.py --data CHI --use_ode_option option1 --device cuda --eval_metrics accuracy
step_move_checkpoints_from_seeds("CHI", "option1", on_conflict="overwrite")
step_test_metrics_generation("CHI", "option1")
step_metrics_extraction("CHI", "option1")
step_analyse("CHI", "option1")

# %%
# !python train.py --data CHI --use_ode_option option2 --device cuda --eval_metrics accuracy
step_move_checkpoints_from_seeds("CHI", "option2", on_conflict="overwrite")
step_test_metrics_generation("CHI", "option2")
step_metrics_extraction("CHI", "option2")
step_analyse("CHI", "option2")

# %%
# !pwd
# !mv /home/jovyan/STHSL/Logs/* /home/jovyan/accuracy_metrics_10seeds_10epochs/Logs/
# !mv /home/jovyan/STHSL/tests_validation/*/home/jovyan/accuracy_metrics_10seeds_10epochs/tests_validation/

# %% [markdown]
# ## Evaluation using different seeds

# %%
# !python train_seeds.py --data NYC --use_ode_option baseline --device cuda
step_train("NYC", "baseline")
step_move_checkpoints_from_seeds("NYC", "baseline", on_conflict="overwrite")
step_test_metrics_generation("NYC", "baseline")
step_metrics_extraction("NYC", "baseline")
# !python analyse_metrics.py tests_validation/baseline/NYC/metrics_all_epochs_pivot.csv
step_analyse("NYC", "baseline")

# %%
step_train("NYC", "option1")
step_move_checkpoints_from_seeds("NYC", "option1", on_conflict="overwrite")
step_test_metrics_generation("NYC", "option1")
step_metrics_extraction("NYC", "option1")
# !python analyse_metrics.py tests_validation/option1/NYC/metrics_all_epochs_pivot.csv
step_analyse("NYC", "option1")

# %%
step_train("NYC", "option2")
step_move_checkpoints_from_seeds("NYC", "option2", on_conflict="overwrite")
step_test_metrics_generation("NYC", "option2")
step_metrics_extraction("NYC", "option2")
# !python analyse_metrics.py tests_validation/option2/NYC/metrics_all_epochs_pivot.csv
step_analyse("NYC", "option2")

# %%
step_train("CHI", "baseline")
step_move_checkpoints_from_seeds("CHI", "baseline", on_conflict="overwrite")
step_test_metrics_generation("CHI", "baseline")
step_metrics_extraction("CHI", "baseline")
# !python analyse_metrics.py tests_validation/baseline/CHI/metrics_all_epochs_pivot.csv
step_analyse("CHI", "baseline")

# %%
step_train("CHI", "option1")
step_move_checkpoints_from_seeds("CHI", "option1", on_conflict="overwrite")
step_test_metrics_generation("CHI", "option1")
step_metrics_extraction("CHI", "option1")
# !python analyse_metrics.py tests_validation/option1/CHI/metrics_all_epochs_pivot.csv
step_analyse("CHI", "option1")

# %%
step_train("CHI", "option2")
step_move_checkpoints_from_seeds("CHI", "option2", on_conflict="overwrite")
step_test_metrics_generation("CHI", "option2")
step_metrics_extraction("CHI", "option2")
# !python analyse_metrics.py tests_validation/option2/CHI/metrics_all_epochs_pivot.csv
step_analyse("CHI", "option2")

# %% [markdown]
# ## tuned parameter training

# %%
# !python train.py --data NYC --use_ode_option baseline --device cuda --lr 2e-3 --weight_decay 2e-5 --batch 4 --latdim 8 --dropRateL 0.3318 --dropRateG 0.1456 --cr 0.9 --ir 1.4846 --kernelSize 5 --hyperNum 64
# step_move_checkpoints("NYC", "baseline", on_conflict="overwrite")
# !python metrics_generation_tuned.py --data NYC --use_ode_option baseline --device cuda --lr 2e-3 --weight_decay 2e-5 --batch 4 --latdim 8 --dropRateL 0.3318 --dropRateG 0.1456 --cr 0.9 --ir 1.4846 --kernelSize 5 --hyperNum 64 --out-dir tests_validation/baseline/NYC
# step_metrics_extraction("NYC", "baseline")
# step_analyse("NYC", "baseline")

# %%
# !python train.py --data NYC --use_ode_option option1 --device cuda --lr 0.0014 --weight_decay 3e-5 --batch 8 --latdim 32 --dropRateL 0.0632 --dropRateG 0.049 --cr 0.6465 --ir 0.552 --kernelSize 5 --hyperNum 256 --n_traj_samples 4 --ode_method euler --odeint_atol 1.95e-5 --odeint_rtol 2.15e-5 --gen_layers 3 --gen_dim 64 --gcn_step 1 --horizon 24
# step_move_checkpoints("NYC", "option1", on_conflict="overwrite")
# !python metrics_generation_tuned.py --data NYC --use_ode_option option1 --device cuda --lr 0.0014 --weight_decay 3e-5 --batch 8 --latdim 32 --dropRateL 0.0632 --dropRateG 0.049 --cr 0.6465 --ir 0.552 --kernelSize 5 --hyperNum 256 --n_traj_samples 4 --ode_method euler --odeint_atol 1.95e-5 --odeint_rtol 2.15e-5 --gen_layers 3 --gen_dim 64 --gcn_step 1 --horizon 24 --out-dir tests_validation/option1/NYC --save-root Logs/option1/
# step_metrics_extraction("NYC", "option1")
# step_analyse("NYC", "option1")

# %%
# !python train.py --data NYC --use_ode_option option2 --device cuda --lr 0.00374 --weight_decay 0.0003365 --batch 4 --latdim 32 --dropRateL 0.0684 --dropRateG 0.2004 --cr 0.4365 --ir 0.6314 --kernelSize 3 --hyperNum 64 --n_traj_samples 2 --ode_method rk4 --odeint_atol 0.000183 --odeint_rtol 0.00062 --gen_layers 3 --gen_dim 64 --gcn_step 2 --horizon 24
# step_move_checkpoints("NYC", "option2", on_conflict="overwrite")
# !python metrics_generation_tuned.py --data NYC --use_ode_option option2 --device cuda --lr 0.00374 --weight_decay 0.0003365 --batch 4 --latdim 32 --dropRateL 0.0684 --dropRateG 0.2004 --cr 0.4365 --ir 0.6314 --kernelSize 3 --hyperNum 64 --n_traj_samples 2 --ode_method rk4 --odeint_atol 0.000183 --odeint_rtol 0.00062 --gen_layers 3 --gen_dim 64 --gcn_step 2 --horizon 24 --out-dir tests_validation/option2/NYC --save-root Logs/option2
# step_metrics_extraction("NYC", "option2")
# step_analyse("NYC", "option2")

# %%
# !python train.py --data CHI --use_ode_option baseline --device cuda --lr 0.0014 --weight_decay 2.3e-5 --batch 8 --latdim 32 --dropRateL  0.265 --dropRateG 0.0121 --cr 0.563 --ir 0.9504 --kernelSize 5 --hyperNum 64
# step_move_checkpoints("CHI", "baseline", on_conflict="overwrite")
# !python metrics_generation_tuned.py --data CHI --use_ode_option baseline --device cuda --lr 0.0014 --weight_decay 2.3e-5 --batch 8 --latdim 32 --dropRateL  0.265 --dropRateG 0.0121 --cr 0.563 --ir 0.9504 --kernelSize 5 --hyperNum 64 --out-dir tests_validation/baseline/CHI
# step_metrics_extraction("CHI", "baseline")
# step_analyse("CHI", "baseline")

# %%
# !python train.py --data CHI --use_ode_option option1 --device cuda --lr 0.0023 --weight_decay 0.00015 --batch 16 --latdim 8 --dropRateL  0.0108 --dropRateG  0.2907 --cr  0.6855 --ir 1.874 --kernelSize 5 --hyperNum 128 --n_traj_samples 2 --ode_method rk4 --odeint_atol 0.0002 --odeint_rtol 0.00026 --gen_layers 3 --gen_dim 64 --gcn_step 3 --horizon 6
# step_move_checkpoints("CHI", "option1", on_conflict="overwrite")
# !python metrics_generation_tuned.py --data CHI --use_ode_option option1 --device cuda --lr 0.0023 --weight_decay 0.00015 --batch 16 --latdim 8 --dropRateL  0.0108 --dropRateG  0.2907 --cr  0.6855 --ir 1.874 --kernelSize 5 --hyperNum 128 --n_traj_samples 2 --ode_method rk4 --odeint_atol 0.0002 --odeint_rtol 0.00026 --gen_layers 3 --gen_dim 64 --gcn_step 3 --horizon 6 --out-dir tests_validation/option1/CHI --save-root Logs/option1/
# step_metrics_extraction("CHI", "option1")
# step_analyse("CHI", "option1")

# %%
# !python train.py --data CHI --use_ode_option option2 --device cuda --lr 0.00373 --weight_decay 0.0003365 --batch 4 --latdim 32 --dropRateL  0.0681 --dropRateG 0.20047 --cr 0.43649 --ir 0.63143 --kernelSize 3 --hyperNum 64 --n_traj_samples 2 --ode_method rk4 --odeint_atol  0.00018334 --odeint_rtol 0.000621 --gen_layers 3 --gen_dim 64 --gcn_step 2 --horizon 24
# step_move_checkpoints("CHI", "option2", on_conflict="overwrite")
# !python metrics_generation_tuned.py --data CHI --use_ode_option option2 --device cuda --lr 0.00373 --weight_decay 0.0003365 --batch 4 --latdim 32 --dropRateL  0.0681 --dropRateG 0.20047 --cr 0.43649 --ir 0.63143 --kernelSize 3 --hyperNum 64 --n_traj_samples 2 --ode_method rk4 --odeint_atol  0.00018334 --odeint_rtol 0.000621 --gen_layers 3 --gen_dim 64 --gcn_step 2 --horizon 24 --out-dir tests_validation/option2/CHI --save-root Logs/option2/
# step_metrics_extraction("CHI", "option2")
# step_analyse("CHI", "option2")

# %% [markdown]
# ## regular training

# %%
step_train("NYC", "baseline")
step_move_checkpoints("NYC", "baseline", on_conflict="overwrite")
step_test_metrics_generation("NYC", "baseline")
step_metrics_extraction("NYC", "baseline")
step_analyse("NYC", "baseline")

# %%
step_train("NYC", "option1")
step_move_checkpoints("NYC", "option1", on_conflict="overwrite")
step_test_metrics_generation("NYC", "option1")
step_metrics_extraction("NYC", "option1")
step_analyse("NYC", "option1")

# %%
step_train("NYC", "option2")
step_move_checkpoints("NYC", "option2", on_conflict="overwrite")
step_test_metrics_generation("NYC", "option2")
step_metrics_extraction("NYC", "option2")
step_analyse("NYC", "option2")

# %%
step_train("CHI", "baseline")
step_move_checkpoints("CHI", "baseline", on_conflict="overwrite")
step_test_metrics_generation("CHI", "baseline")
step_metrics_extraction("CHI", "baseline")
step_analyse("CHI", "baseline")

# %%
step_train("CHI", "option1")
step_move_checkpoints("CHI", "option1", on_conflict="overwrite")
step_test_metrics_generation("CHI", "option1")
step_metrics_extraction("CHI", "option1")
step_analyse("CHI", "option1")

# %%
step_train("CHI", "option2")
step_move_checkpoints("CHI", "option2", on_conflict="overwrite")
step_test_metrics_generation("CHI", "option2")
step_metrics_extraction("CHI", "option2")
step_analyse("CHI", "option2")

# %%
# test cell
