# %% [markdown]
# ## playground

# %%
# import pandas as pd
# df = pd.read_csv("Datasets/NYC_crime/NYC_crime.zip", low_memory=False)
# print(df.columns.tolist())
# print(df["Offense"].value_counts().head(20))

# %%
# import pandas as pd
# import zipfile, io

# with zipfile.ZipFile("Datasets/CHI_crime/CHI_Crime.zip") as z:
#     with z.open(z.namelist()[0]) as f:
#         df = pd.read_csv(io.BytesIO(f.read()), header=None)

# df[1].value_counts().loc[["THEFT","BATTERY","CRIMINAL DAMAGE","ASSAULT"]]

# %%
# import pandas as pd
# df = pd.read_csv("Datasets/SEA_crime/SEA_crime.zip", low_memory=False)
# print(df.columns.tolist())
# for i, col in enumerate(df.columns):
#     print(i, col)
# print(df["Offense Sub Category"].value_counts().head(20))

# %%
# import pandas as pd
# df = pd.read_csv("Datasets/LA_crime/LA_crime.zip", low_memory=False)
# print(df.columns.tolist())
# for i, col in enumerate(df.columns):
#     print(i, col)
# print(df["Crm Cd Desc"].value_counts().head(20))

# %%
# import pickle

# meta = pickle.load(open("Datasets/SEA_crime/meta.pkl","rb"))
# print(meta)
# print(meta["dataset_split"])
# print(meta["spatial_grid"])

# %% [markdown]
# ## STHSL End-to-End Executions — Baseline / Option1 / Option2 (NYC + CHI)
#
# 1. **Path verification**
# 2. Train NYC (baseline)
# 3. Test NYC (baseline) — `metrics_generation.py`
# 4. Extract + analyze NYC (baseline) — `metrics_extraction.py` + `analyse_metrics.py`
# 5. Repeat 2–4 for NYC (option1)
# 6. Repeat 2–4 for NYC (option2)
# 7. Repeat 2–6 for CHI

# %% [markdown]
# ### 1) Path verification + shared helpers

# %%
from pathlib import Path
import os, shlex, subprocess

# ---- EDIT ONLY IF NEEDED ----
REPO_ROOT = Path(".").resolve()
PYTHON = os.environ.get("PYTHON", "python")

TRAIN = REPO_ROOT / "train.py"
METRICS_GEN = REPO_ROOT / "metrics_generation.py"
METRICS_EXTRACT = REPO_ROOT / "metrics_extraction.py"
ANALYSE = REPO_ROOT / "analyse_metrics.py"

SAVE_DIR = REPO_ROOT / "Save"                 # training outputs
LOGS_DIR = REPO_ROOT / "Logs"                 # where you move checkpoints
TESTS_DIR = REPO_ROOT / "tests_validation"    # metrics_generation out-dir root

def must_exist(p: Path):
    if not p.exists():
        raise FileNotFoundError(f"Missing: {p}")
    print("OK:", p)

print("REPO_ROOT:", REPO_ROOT)
must_exist(TRAIN)
must_exist(METRICS_GEN)
must_exist(METRICS_EXTRACT)
must_exist(ANALYSE)

# Ensure dirs exist
SAVE_DIR.mkdir(exist_ok=True)
LOGS_DIR.mkdir(exist_ok=True)
TESTS_DIR.mkdir(exist_ok=True)

def run(cmd, cwd=REPO_ROOT, timeout=None):
    """Run a command (list[str] or str). Prints the command and last output."""
    if isinstance(cmd, str):
        printable = cmd
        shell = True
    else:
        printable = " ".join(shlex.quote(str(x)) for x in cmd)
        shell = False
    print("\\n$ " + printable)
    p = subprocess.run(
        cmd,
        cwd=str(cwd),
        shell=shell,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        encoding="utf-8",   # <-- forces decoding as UTF-8
        errors="replace",   # <-- prevents crash on bad bytes
        timeout=timeout
    )
    out = p.stdout or ""
    print(out[-4000:])
    if p.returncode != 0:
        raise RuntimeError(f"Command failed (rc={p.returncode}). See output above.")
    return out

def ensure_dir(p: Path):
    p.mkdir(parents=True, exist_ok=True)
    return p

print("\nReady.")
# Out:
# REPO_ROOT: /home/jovyan/STHSL
# OK: /home/jovyan/STHSL/train.py
# OK: /home/jovyan/STHSL/metrics_generation.py
# OK: /home/jovyan/STHSL/metrics_extraction.py
# OK: /home/jovyan/STHSL/analyse_metrics.py
#
# Ready.

# %% [markdown]
# ### Conventions
#
# - `--use_ode_option`: `baseline`, `option1`, `option2`
# - Dataset values: `NYC`, `CHI`
# - Test output: `tests_validation/<arch>/<dataset>/`
# - Logs: `Logs/<arch>/<dataset>/`

# %%
def logs_dir(arch: str, ds: str) -> Path:
    return LOGS_DIR / arch / ds

def tests_dir(arch: str, ds: str) -> Path:
    return TESTS_DIR / arch / ds

def metrics_pivot_csv(arch: str, ds: str) -> Path:
    return tests_dir(arch, ds) / "metrics_all_epochs_pivot.csv"

# %% [markdown]
# ### Helper defs for pipeline (train → test → extract → analyze)

# %%
import shutil
import glob
from pathlib import Path

def step_train(ds: str, arch: str):
    # baseline: python train.py --data NYC
    # option1:  python train.py --data NYC --use_ode_option option1
    # option2:  python train.py --data NYC --use_ode_option option2
    cmd = [PYTHON, str(TRAIN), "--data", ds]
    if arch in ("option1", "option2"):
        cmd += ["--use_ode_option", arch]
    elif arch == "baseline":
        cmd += ["--use_ode_option", "baseline"]
        pass
    else:
        raise ValueError(f"Unknown arch: {arch}")
    run(cmd)

def step_test_metrics_generation(ds: str, arch: str):
    # example command: python metrics_generation.py --data NYC --use_ode_option baseline --out-dir tests_validation/baseline/NYC
    out_dir = ensure_dir(tests_dir(arch, ds))
    cmd = [PYTHON, str(METRICS_GEN), "--data", ds, "--use_ode_option", arch, "--save-root", LOGS_DIR/arch, "--out-dir", str(out_dir)]
    run(cmd)

def step_metrics_extraction(ds: str, arch: str):
    # example command: python metrics_extraction.py tests_validation/baseline/NYC/
    out_dir = tests_dir(arch, ds)
    city = 'chicago' if 'chi' in ds.lower() else 'nyc'
    cmd = [PYTHON, str(METRICS_EXTRACT), str(out_dir), '--city', city]
    run(cmd)

def step_analyse(ds: str, arch: str):
    # example command: python analyse_metrics.py tests_validation/baseline/NYC/metrics_all_epochs_pivot.csv
    pivot = metrics_pivot_csv(arch, ds)
    cmd = [PYTHON, str(ANALYSE), str(pivot)]

    print("Running:", " ".join(cmd))
    subprocess.run(cmd, check=True)

def step_move_checkpoints(
    ds: str,
    arch: str,
    on_conflict: str = "prompt",  # "abort" | "overwrite" | "skip" | "prompt"
):
    """
    Move checkpoints from:
        Save/<ds>/seed_*/   (preferred)
    OR
        Save/<ds>/_epoch_*  (fallback)

    Into:
        Logs/<arch>/<ds>/[seed_x/]...

    Conflict policy:
      - "abort"
      - "overwrite"
      - "skip"
      - "prompt"
    """

    src_root = SAVE_DIR / ds
    dst_root = ensure_dir(logs_dir(arch, ds))

    # -------- Detect seed folders --------
    seed_dirs = sorted([p for p in src_root.glob("seed_*") if p.is_dir()])

    src_files = []
    seed_mode = False

    if seed_dirs:
        seed_mode = True
        print(f"Detected seed folders under {src_root}")
        for seed_dir in seed_dirs:
            pattern = str(seed_dir / "*.pth")
            for f in glob.glob(pattern):
                src_files.append(Path(f))
    else:
        # Fallback: old layout
        pattern = str(src_root / "_epoch_*")
        src_files = [Path(f) for f in glob.glob(pattern)]

    if not src_files:
        raise RuntimeError(f"No checkpoints found in {src_root}")

    # -------- Detect conflicts --------
    conflicts = []
    for src in src_files:
        if seed_mode:
            seed_name = src.parent.name
            dst_dir = ensure_dir(dst_root / seed_name)
        else:
            dst_dir = dst_root

        if (dst_dir / src.name).exists():
            conflicts.append(str((dst_dir / src.name).relative_to(dst_root)))

    if conflicts:
        if on_conflict == "abort":
            raise RuntimeError(
                f"Checkpoint conflicts detected in {dst_root}. "
                f"Refusing to overwrite: {conflicts}"
            )

        if on_conflict == "prompt":
            print("\nExisting checkpoint files detected:")
            for c in conflicts:
                print("  -", c)

            print("\nChoose an action:")
            print("  [o] overwrite existing files")
            print("  [s] skip existing files")
            print("  [a] abort")

            choice = input("Your choice [o/s/a]: ").strip().lower()
            if choice == "o":
                on_conflict = "overwrite"
            elif choice == "s":
                on_conflict = "skip"
            else:
                print("Aborted by user.")
                return

        if on_conflict not in ("overwrite", "skip"):
            raise ValueError(f"Invalid on_conflict value: {on_conflict}")

    moved, skipped = 0, 0

    # -------- Move files --------
    for src in src_files:
        if seed_mode:
            seed_name = src.parent.name
            dst_dir = ensure_dir(dst_root / seed_name)
        else:
            dst_dir = dst_root

        dst = dst_dir / src.name

        if dst.exists():
            if on_conflict == "skip":
                skipped += 1
                continue
            elif on_conflict == "overwrite":
                dst.unlink()

        shutil.move(str(src), str(dst))
        moved += 1

    print(f"\nCheckpoint move completed ({ds} / {arch})")
    print(f"  Mode     : {'seed-aware' if seed_mode else 'flat fallback'}")
    print(f"  Moved    : {moved}")
    print(f"  Skipped  : {skipped}")

# %% [markdown]
# ### Imports

# %%
import sys
print(sys.executable)
# %pip install torchdiffeq
# Out:
# /opt/conda/bin/python
# Requirement already satisfied: torchdiffeq in /opt/conda/lib/python3.11/site-packages (0.2.5)
# Requirement already satisfied: torch>=1.5.0 in /opt/conda/lib/python3.11/site-packages (from torchdiffeq) (2.3.1)
# Requirement already satisfied: scipy>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from torchdiffeq) (1.14.0)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /opt/conda/lib/python3.11/site-packages (from scipy>=1.4.0->torchdiffeq) (1.26.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.5.0->torchdiffeq) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=1.5.0->torchdiffeq) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy->torch>=1.5.0->torchdiffeq) (1.3.0)
#
# [notice] A new release of pip is available: 24.1.2 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### cleaning

# %%
# !./cleanup_experiments.sh --dataset all --arch all --target all -y
# Out:
# SKIP (not a dir): Logs/baseline/NYC
# SKIP (not a dir): Logs/baseline/CHI
# SKIP (not a dir): Logs/baseline/LA
# SKIP (not a dir): Logs/baseline/SEA
# SKIP (not a dir): Logs/baseline/NEW_CHI
# SKIP (not a dir): Logs/baseline/SYN
# SKIP (not a dir): Logs/baseline/NYC_1km
# EMPTY: Logs/baseline/NYC_5km
# SKIP (not a dir): Logs/baseline/CHI_1km
# EMPTY: Logs/baseline/CHI_5km
# SKIP (not a dir): Logs/baseline/old_NYC_5km
# SKIP (not a dir): Logs/baseline/old_CHI_5km
# EMPTY: Logs/baseline/NYC_3km
# EMPTY: Logs/baseline/CHI_3km
# SKIP (not a dir): Logs/option1/NYC
# SKIP (not a dir): Logs/option1/CHI
# SKIP (not a dir): Logs/option1/LA
# SKIP (not a dir): Logs/option1/SEA
# SKIP (not a dir): Logs/option1/NEW_CHI
# SKIP (not a dir): Logs/option1/SYN
# SKIP (not a dir): Logs/option1/NYC_1km
# EMPTY: Logs/option1/NYC_5km
# SKIP (not a dir): Logs/option1/CHI_1km
# EMPTY: Logs/option1/CHI_5km
# SKIP (not a dir): Logs/option1/old_NYC_5km
# SKIP (not a dir): Logs/option1/old_CHI_5km
# EMPTY: Logs/option1/NYC_3km
# EMPTY: Logs/option1/CHI_3km
# SKIP (not a dir): Logs/option2/NYC
# SKIP (not a dir): Logs/option2/CHI
# SKIP (not a dir): Logs/option2/LA
# SKIP (not a dir): Logs/option2/SEA
# SKIP (not a dir): Logs/option2/NEW_CHI
# SKIP (not a dir): Logs/option2/SYN
# SKIP (not a dir): Logs/option2/NYC_1km
# EMPTY: Logs/option2/NYC_5km
# SKIP (not a dir): Logs/option2/CHI_1km
# EMPTY: Logs/option2/CHI_5km
# SKIP (not a dir): Logs/option2/old_NYC_5km
# SKIP (not a dir): Logs/option2/old_CHI_5km
# EMPTY: Logs/option2/NYC_3km
# EMPTY: Logs/option2/CHI_3km
# SKIP (not a dir): tests_validation/baseline/NYC
# SKIP (not a dir): tests_validation/baseline/CHI
# SKIP (not a dir): tests_validation/baseline/LA
# SKIP (not a dir): tests_validation/baseline/SEA
# SKIP (not a dir): tests_validation/baseline/NEW_CHI
# SKIP (not a dir): tests_validation/baseline/SYN
# SKIP (not a dir): tests_validation/baseline/NYC_1km
# EMPTY: tests_validation/baseline/NYC_5km
# SKIP (not a dir): tests_validation/baseline/CHI_1km
# EMPTY: tests_validation/baseline/CHI_5km
# SKIP (not a dir): tests_validation/baseline/old_NYC_5km
# SKIP (not a dir): tests_validation/baseline/old_CHI_5km
# EMPTY: tests_validation/baseline/NYC_3km
# EMPTY: tests_validation/baseline/CHI_3km
# SKIP (not a dir): tests_validation/option1/NYC
# SKIP (not a dir): tests_validation/option1/CHI
# SKIP (not a dir): tests_validation/option1/LA
# SKIP (not a dir): tests_validation/option1/SEA
# SKIP (not a dir): tests_validation/option1/NEW_CHI
# SKIP (not a dir): tests_validation/option1/SYN
# SKIP (not a dir): tests_validation/option1/NYC_1km
# EMPTY: tests_validation/option1/NYC_5km
# SKIP (not a dir): tests_validation/option1/CHI_1km
# EMPTY: tests_validation/option1/CHI_5km
# SKIP (not a dir): tests_validation/option1/old_NYC_5km
# SKIP (not a dir): tests_validation/option1/old_CHI_5km
# EMPTY: tests_validation/option1/NYC_3km
# EMPTY: tests_validation/option1/CHI_3km
# SKIP (not a dir): tests_validation/option2/NYC
# SKIP (not a dir): tests_validation/option2/CHI
# SKIP (not a dir): tests_validation/option2/LA
# SKIP (not a dir): tests_validation/option2/SEA
# SKIP (not a dir): tests_validation/option2/NEW_CHI
# SKIP (not a dir): tests_validation/option2/SYN
# SKIP (not a dir): tests_validation/option2/NYC_1km
# EMPTY: tests_validation/option2/NYC_5km
# SKIP (not a dir): tests_validation/option2/CHI_1km
# EMPTY: tests_validation/option2/CHI_5km
# SKIP (not a dir): tests_validation/option2/old_NYC_5km
# SKIP (not a dir): tests_validation/option2/old_CHI_5km
# EMPTY: tests_validation/option2/NYC_3km
# EMPTY: tests_validation/option2/CHI_3km
# NO-MATCH: Save/NYC/_epoch*
# NO-MATCH: Save/CHI/_epoch*
# NO-MATCH: Save/LA/_epoch*
# NO-MATCH: Save/SEA/_epoch*
# SKIP (not a dir): Save/NEW_CHI
# NO-MATCH: Save/SYN/_epoch*
# NO-MATCH: Save/NYC_1km/_epoch*
# NO-MATCH: Save/NYC_5km/_epoch*
# NO-MATCH: Save/CHI_1km/_epoch*
# NO-MATCH: Save/CHI_5km/_epoch*
# NO-MATCH: Save/old_NYC_5km/_epoch*
# NO-MATCH: Save/old_CHI_5km/_epoch*
# NO-MATCH: Save/NYC_3km/_epoch*
# NO-MATCH: Save/CHI_3km/_epoch*
# Cleanup done.

# %% [markdown]
# # report results executions

# %% [markdown]
# ## Tuning NYC 3km for ODE Hyperparameters

# %%
# !python tune_STHSL.py --data NYC_3km --arch baseline --num-trials 10 --gpus 1 --workers 1

# %%
# !python tune_STHSL.py --data NYC_3km --arch option1 --num-trials 10 --gpus 1 --workers 1

# %%
# !python tune_STHSL.py --data NYC_3km --arch option2 --num-trials 10 --gpus 1 --workers 1

# %% [markdown]
# ## Training with best hyper parameters from tuning

# %% [markdown]
# ### 3km grid

# %%
# !python train.py --data NYC_3km --use_ode_option baseline --device cuda --eval_metrics all --batch 16
step_move_checkpoints("NYC_3km", "baseline", on_conflict="overwrite")
# !python metrics_generation.py --data NYC_3km --use_ode_option baseline --device cuda --eval_metrics all --batch 16 --out-dir tests_validation/baseline/NYC_3km --save-root Logs/baseline
step_metrics_extraction("NYC_3km", "baseline")
step_analyse("NYC_3km", "baseline")
# Out:
# self.predir Datasets/common_data/NYC_crime_3km/
# (256, 153, 4)
# Row: 16 , Col: 16
# Sparsity: 0.017908406649908594
# use_ode_option: baseline
# ODE is not enabled, baseline STHSL model is initialized
# DEBUG SHAPES status: True
#
# ===== SEED 10 =====
# start training...
# ===== TRAINING ARGS =====
# lr: 0.001
# weight_decay: 0.0001
# cr: 0.8
# ir: 1
# t: 0.05
# batch: 16
# epoch: 1
# latdim: 16
# temporalRange: 30
# cateNum: 4
# data: NYC_3km
# kernelSize: 3
# border: 0.5
# hyperNum: 128
# dropRateL: 0.2
# dropRateG: 0.1
# use_ode_option: baseline
# n_traj_samples: 1
# ode_method: dopri5
# odeint_atol: 0.0001
# odeint_rtol: 0.001
# gen_layers: 1
# gen_dim: 64
# save_latent: false
# gcn_step: 2
# rnn_units: 64
# horizon: 12
# filter_type: 2
# device: cuda
# tstEpoch: 1
# save: ./Save/
# checkpoint: ./Save/NYC/
# eval_metrics: all
# f1_label_threshold: 0.0
# f1_pred_threshold: 0.5
# seeds: [10]
# row: 16
# col: 16
# offNum: 4
# areaNum: 256
# trnDays: 547
# valDays: 31
# tstDays: 153
# decay_step: 34
# ==========================
# Epoch  1 Training Time 11.486s
# Epoch 1/1, Train Loss =  29.8710,  preLoss =  13.1826
# /home/jovyan/STHSL/engine.py:402: RuntimeWarning: invalid value encountered in scalar divide
#   ret['RMSE_mask_4'] = np.sqrt(np.sum(epochSqLoss4) / np.sum(epochTstNum4))
# /home/jovyan/STHSL/engine.py:403: RuntimeWarning: invalid value encountered in scalar divide
#   ret['MAE_mask_4'] = np.sum(epochAbsLoss4) / np.sum(epochTstNum4)
# /home/jovyan/STHSL/engine.py:404: RuntimeWarning: invalid value encountered in scalar divide
#   ret['MAPE_mask_4'] = np.sum(epochApeLoss4) / np.sum(epochPosNums4)
# Val (MicroF1+MacroF1) increase from -1.0000 to 1.4762
# /home/jovyan/STHSL/engine.py:402: RuntimeWarning: invalid value encountered in scalar divide
#   ret['RMSE_mask_4'] = np.sqrt(np.sum(epochSqLoss4) / np.sum(epochTstNum4))
# /home/jovyan/STHSL/engine.py:403: RuntimeWarning: invalid value encountered in scalar divide
#   ret['MAE_mask_4'] = np.sum(epochAbsLoss4) / np.sum(epochTstNum4)
# /home/jovyan/STHSL/engine.py:404: RuntimeWarning: invalid value encountered in scalar divide
#   ret['MAPE_mask_4'] = np.sum(epochApeLoss4) / np.sum(epochPosNums4)
# Epoch 1/1, Test: MacroF1 = 0.4953, MicroF1 = 0.9814, AP = 0.0231, Acc = 0.9814, MacroF1_cate_0 = 0.4974, MicroF1_cate_0 = 0.9895, Acc_cate_0 = 0.9895, AP_cate_0 = 0.0140, MacroF1_cate_1 = 0.4958, MicroF1_cate_1 = 0.9833, Acc_cate_1 = 0.9833, AP_cate_1 = 0.0182, MacroF1_cate_2 = 0.4913, MicroF1_cate_2 = 0.9657, Acc_cate_2 = 0.9657, AP_cate_2 = 0.0415, MacroF1_cate_3 = 0.4967, MicroF1_cate_3 = 0.9870, Acc_cate_3 = 0.9870, AP_cate_3 = 0.0227, MacroF1_over_categories = 0.4953, MicroF1_over_categories = 0.9814, MacroAP_over_categories = 0.0241, MacroAcc_over_categories = 0.9814, MacroF1_mask_1 = 0.4872, MicroF1_mask_1 = 0.9501, Acc_mask_1 = 0.9501, AP_mask_1 = 0.0550, MacroF1_mask_2 = 0.4153, MicroF1_mask_2 = 0.7102, Acc_mask_2 = 0.7102, AP_mask_2 = 0.3114, MacroF1_mask_3 = 0.2817, MicroF1_mask_3 = 0.3922, Acc_mask_3 = 0.3922, AP_mask_3 = 0.6380, MacroF1_mask_4 = nan, MicroF1_mask_4 = 0.0000, Acc_mask_4 = nan, AP_mask_4 = nan, MacroF1_cate_0_mask_1 = 0.4910, MicroF1_cate_0_mask_1 = 0.9646, Acc_cate_0_mask_1 = 0.9646, AP_cate_0_mask_1 = 0.0404, MacroF1_cate_0_mask_2 = nan, MicroF1_cate_0_mask_2 = 0.0000, Acc_cate_0_mask_2 = nan, AP_cate_0_mask_2 = nan, MacroF1_cate_0_mask_3 = nan, MicroF1_cate_0_mask_3 = 0.0000, Acc_cate_0_mask_3 = nan, AP_cate_0_mask_3 = nan, MacroF1_cate_0_mask_4 = nan, MicroF1_cate_0_mask_4 = 0.0000, Acc_cate_0_mask_4 = nan, AP_cate_0_mask_4 = nan, MacroF1_cate_1_mask_1 = 0.4872, MicroF1_cate_1_mask_1 = 0.9502, Acc_cate_1_mask_1 = 0.9502, AP_cate_1_mask_1 = 0.0530, MacroF1_cate_1_mask_2 = nan, MicroF1_cate_1_mask_2 = 0.0000, Acc_cate_1_mask_2 = nan, AP_cate_1_mask_2 = nan, MacroF1_cate_1_mask_3 = nan, MicroF1_cate_1_mask_3 = 0.0000, Acc_cate_1_mask_3 = nan, AP_cate_1_mask_3 = nan, MacroF1_cate_1_mask_4 = nan, MicroF1_cate_1_mask_4 = 0.0000, Acc_cate_1_mask_4 = nan, AP_cate_1_mask_4 = nan, MacroF1_cate_2_mask_1 = 0.4823, MicroF1_cate_2_mask_1 = 0.9317, Acc_cate_2_mask_1 = 0.9317, AP_cate_2_mask_1 = 0.0740, MacroF1_cate_2_mask_2 = 0.4153, MicroF1_cate_2_mask_2 = 0.7102, Acc_cate_2_mask_2 = 0.7102, AP_cate_2_mask_2 = 0.3114, MacroF1_cate_2_mask_3 = 0.2817, MicroF1_cate_2_mask_3 = 0.3922, Acc_cate_2_mask_3 = 0.3922, AP_cate_2_mask_3 = 0.6380, MacroF1_cate_2_mask_4 = nan, MicroF1_cate_2_mask_4 = 0.0000, Acc_cate_2_mask_4 = nan, AP_cate_2_mask_4 = nan, MacroF1_cate_3_mask_1 = 0.4895, MicroF1_cate_3_mask_1 = 0.9588, Acc_cate_3_mask_1 = 0.9588, AP_cate_3_mask_1 = 0.0539, MacroF1_cate_3_mask_2 = nan, MicroF1_cate_3_mask_2 = 0.0000, Acc_cate_3_mask_2 = nan, AP_cate_3_mask_2 = nan, MacroF1_cate_3_mask_3 = nan, MicroF1_cate_3_mask_3 = 0.0000, Acc_cate_3_mask_3 = nan, AP_cate_3_mask_3 = nan, MacroF1_cate_3_mask_4 = nan, MicroF1_cate_3_mask_4 = 0.0000, Acc_cate_3_mask_4 = nan, AP_cate_3_mask_4 = nan, RMSE = 1.1249, MAE = 1.0655, MAPE = 0.9677, RMSE_cate_0 = 1.0169, MAE_cate_0 = 0.9958, MAPE_cate_0 = 0.9556, RMSE_cate_1 = 1.0665, MAE_cate_1 = 1.0343, MAPE_cate_1 = 0.9727, RMSE_cate_2 = 1.2076, MAE_cate_2 = 1.1190, MAPE_cate_2 = 0.9719, RMSE_cate_3 = 1.0531, MAE_cate_3 = 1.0209, MAPE_cate_3 = 0.9599, RMSE_mask_1 = 1.0525, MAE_mask_1 = 1.0230, MAPE_mask_1 = 0.9661, RMSE_mask_2 = 1.1711, MAE_mask_2 = 1.1078, MAPE_mask_2 = 0.9666, RMSE_mask_3 = 1.8424, MAE_mask_3 = 1.6292, MAPE_mask_3 = 0.9900, RMSE_mask_4 = nan, MAE_mask_4 = nan, MAPE_mask_4 = nan, epochLoss = 1.2631
# MacroF1=0.4953 MicroF1=0.9814 AP=0.0231
#
#   [RUNTIME] Epoch 1: train=11.49s | train+eval=12.60s
#
# ============================================================
# RUNTIME ANALYSIS SUMMARY (STHSL)
# ============================================================
#   Seed:                      10
#   Epochs run:                1
#   Avg train time/epoch:      11.49s (+/- 0.00s)
#   Avg total time/epoch:      12.60s (+/- 0.00s)
#   Per-epoch train times:     ['11.49']
#   Total training time:       12.60s
# ============================================================
#
# Epoch 1/1, Best: MacroF1 = 0.4953, MicroF1 = 0.9814, AP = 0.0231, Acc = 0.9814, MacroF1_cate_0 = 0.4974, MicroF1_cate_0 = 0.9895, Acc_cate_0 = 0.9895, AP_cate_0 = 0.0140, MacroF1_cate_1 = 0.4958, MicroF1_cate_1 = 0.9833, Acc_cate_1 = 0.9833, AP_cate_1 = 0.0182, MacroF1_cate_2 = 0.4913, MicroF1_cate_2 = 0.9657, Acc_cate_2 = 0.9657, AP_cate_2 = 0.0415, MacroF1_cate_3 = 0.4967, MicroF1_cate_3 = 0.9870, Acc_cate_3 = 0.9870, AP_cate_3 = 0.0227, MacroF1_over_categories = 0.4953, MicroF1_over_categories = 0.9814, MacroAP_over_categories = 0.0241, MacroAcc_over_categories = 0.9814, MacroF1_mask_1 = 0.4872, MicroF1_mask_1 = 0.9501, Acc_mask_1 = 0.9501, AP_mask_1 = 0.0550, MacroF1_mask_2 = 0.4153, MicroF1_mask_2 = 0.7102, Acc_mask_2 = 0.7102, AP_mask_2 = 0.3114, MacroF1_mask_3 = 0.2817, MicroF1_mask_3 = 0.3922, Acc_mask_3 = 0.3922, AP_mask_3 = 0.6380, MacroF1_mask_4 = nan, MicroF1_mask_4 = 0.0000, Acc_mask_4 = nan, AP_mask_4 = nan, MacroF1_cate_0_mask_1 = 0.4910, MicroF1_cate_0_mask_1 = 0.9646, Acc_cate_0_mask_1 = 0.9646, AP_cate_0_mask_1 = 0.0404, MacroF1_cate_0_mask_2 = nan, MicroF1_cate_0_mask_2 = 0.0000, Acc_cate_0_mask_2 = nan, AP_cate_0_mask_2 = nan, MacroF1_cate_0_mask_3 = nan, MicroF1_cate_0_mask_3 = 0.0000, Acc_cate_0_mask_3 = nan, AP_cate_0_mask_3 = nan, MacroF1_cate_0_mask_4 = nan, MicroF1_cate_0_mask_4 = 0.0000, Acc_cate_0_mask_4 = nan, AP_cate_0_mask_4 = nan, MacroF1_cate_1_mask_1 = 0.4872, MicroF1_cate_1_mask_1 = 0.9502, Acc_cate_1_mask_1 = 0.9502, AP_cate_1_mask_1 = 0.0530, MacroF1_cate_1_mask_2 = nan, MicroF1_cate_1_mask_2 = 0.0000, Acc_cate_1_mask_2 = nan, AP_cate_1_mask_2 = nan, MacroF1_cate_1_mask_3 = nan, MicroF1_cate_1_mask_3 = 0.0000, Acc_cate_1_mask_3 = nan, AP_cate_1_mask_3 = nan, MacroF1_cate_1_mask_4 = nan, MicroF1_cate_1_mask_4 = 0.0000, Acc_cate_1_mask_4 = nan, AP_cate_1_mask_4 = nan, MacroF1_cate_2_mask_1 = 0.4823, MicroF1_cate_2_mask_1 = 0.9317, Acc_cate_2_mask_1 = 0.9317, AP_cate_2_mask_1 = 0.0740, MacroF1_cate_2_mask_2 = 0.4153, MicroF1_cate_2_mask_2 = 0.7102, Acc_cate_2_mask_2 = 0.7102, AP_cate_2_mask_2 = 0.3114, MacroF1_cate_2_mask_3 = 0.2817, MicroF1_cate_2_mask_3 = 0.3922, Acc_cate_2_mask_3 = 0.3922, AP_cate_2_mask_3 = 0.6380, MacroF1_cate_2_mask_4 = nan, MicroF1_cate_2_mask_4 = 0.0000, Acc_cate_2_mask_4 = nan, AP_cate_2_mask_4 = nan, MacroF1_cate_3_mask_1 = 0.4895, MicroF1_cate_3_mask_1 = 0.9588, Acc_cate_3_mask_1 = 0.9588, AP_cate_3_mask_1 = 0.0539, MacroF1_cate_3_mask_2 = nan, MicroF1_cate_3_mask_2 = 0.0000, Acc_cate_3_mask_2 = nan, AP_cate_3_mask_2 = nan, MacroF1_cate_3_mask_3 = nan, MicroF1_cate_3_mask_3 = 0.0000, Acc_cate_3_mask_3 = nan, AP_cate_3_mask_3 = nan, MacroF1_cate_3_mask_4 = nan, MicroF1_cate_3_mask_4 = 0.0000, Acc_cate_3_mask_4 = nan, AP_cate_3_mask_4 = nan, RMSE = 1.1249, MAE = 1.0655, MAPE = 0.9677, RMSE_cate_0 = 1.0169, MAE_cate_0 = 0.9958, MAPE_cate_0 = 0.9556, RMSE_cate_1 = 1.0665, MAE_cate_1 = 1.0343, MAPE_cate_1 = 0.9727, RMSE_cate_2 = 1.2076, MAE_cate_2 = 1.1190, MAPE_cate_2 = 0.9719, RMSE_cate_3 = 1.0531, MAE_cate_3 = 1.0209, MAPE_cate_3 = 0.9599, RMSE_mask_1 = 1.0525, MAE_mask_1 = 1.0230, MAPE_mask_1 = 0.9661, RMSE_mask_2 = 1.1711, MAE_mask_2 = 1.1078, MAPE_mask_2 = 0.9666, RMSE_mask_3 = 1.8424, MAE_mask_3 = 1.6292, MAPE_mask_3 = 0.9900, RMSE_mask_4 = nan, MAE_mask_4 = nan, MAPE_mask_4 = nan, epochLoss = 1.2631
#
# ===== SUMMARY: best result per seed =====
# seed=10: {'MacroF1': 0.4952967554055099, 'MicroF1': 0.9813623366013072, 'AP': 0.02310989669333427, 'Acc': 0.9813623366013072, 'MacroF1_cate_0': 0.4973563985421693, 'MicroF1_cate_0': 0.9894812091503268, 'Acc_cate_0': 0.9894812091503268, 'AP_cate_0': 0.013982289966233102, 'MacroF1_cate_1': 0.49578403985530567, 'MicroF1_cate_1': 0.9832771650326797, 'Acc_cate_1': 0.9832771650326797, 'AP_cate_1': 0.018201994763009398, 'MacroF1_cate_2': 0.4912784279090307, 'MicroF1_cate_2': 0.9657118055555556, 'Acc_cate_2': 0.9657118055555556, 'AP_cate_2': 0.04148305129997584, 'MacroF1_cate_3': 0.4967234600262123, 'MicroF1_cate_3': 0.9869791666666666, 'Acc_cate_3': 0.9869791666666666, 'AP_cate_3': 0.0227420077773281, 'MacroF1_over_categories': 0.4952855815831795, 'MicroF1_over_categories': 0.9813623366013072, 'MacroAP_over_categories': 0.024102335951636612, 'MacroAcc_over_categories': 0.9813623366013072, 'MacroF1_mask_1': 0.48721804511278194, 'MicroF1_mask_1': 0.9501466275659824, 'Acc_mask_1': 0.9501466275659824, 'AP_mask_1': 0.05500103628548014, 'MacroF1_mask_2': 0.4152866242038217, 'MicroF1_mask_2': 0.710239651416122, 'Acc_mask_2': 0.710239651416122, 'AP_mask_2': 0.31144723625361725, 'MacroF1_mask_3': 0.28169014084507044, 'MicroF1_mask_3': 0.39215686274509803, 'Acc_mask_3': 0.39215686274509803, 'AP_mask_3': 0.6379622050162386, 'MacroF1_mask_4': nan, 'MicroF1_mask_4': 0.0, 'Acc_mask_4': nan, 'AP_mask_4': nan, 'MacroF1_cate_0_mask_1': 0.49098231483102783, 'MicroF1_cate_0_mask_1': 0.9645682834537324, 'Acc_cate_0_mask_1': 0.9645682834537324, 'AP_cate_0_mask_1': 0.04035345394463469, 'MacroF1_cate_0_mask_2': nan, 'MicroF1_cate_0_mask_2': 0.0, 'Acc_cate_0_mask_2': nan, 'AP_cate_0_mask_2': nan, 'MacroF1_cate_0_mask_3': nan, 'MicroF1_cate_0_mask_3': 0.0, 'Acc_cate_0_mask_3': nan, 'AP_cate_0_mask_3': nan, 'MacroF1_cate_0_mask_4': nan, 'MicroF1_cate_0_mask_4': 0.0, 'Acc_cate_0_mask_4': nan, 'AP_cate_0_mask_4': nan, 'MacroF1_cate_1_mask_1': 0.48723744203265656, 'MicroF1_cate_1_mask_1': 0.9502203982368141, 'Acc_cate_1_mask_1': 0.9502203982368141, 'AP_cate_1_mask_1': 0.05302168154339795, 'MacroF1_cate_1_mask_2': nan, 'MicroF1_cate_1_mask_2': 0.0, 'Acc_cate_1_mask_2': nan, 'AP_cate_1_mask_2': nan, 'MacroF1_cate_1_mask_3': nan, 'MicroF1_cate_1_mask_3': 0.0, 'Acc_cate_1_mask_3': nan, 'AP_cate_1_mask_3': nan, 'MacroF1_cate_1_mask_4': nan, 'MicroF1_cate_1_mask_4': 0.0, 'Acc_cate_1_mask_4': nan, 'AP_cate_1_mask_4': nan, 'MacroF1_cate_2_mask_1': 0.48232288357961606, 'MicroF1_cate_2_mask_1': 0.9317060157396292, 'Acc_cate_2_mask_1': 0.9317060157396292, 'AP_cate_2_mask_1': 0.07399016607696286, 'MacroF1_cate_2_mask_2': 0.4152866242038217, 'MicroF1_cate_2_mask_2': 0.710239651416122, 'Acc_cate_2_mask_2': 0.710239651416122, 'AP_cate_2_mask_2': 0.31144723625361725, 'MacroF1_cate_2_mask_3': 0.28169014084507044, 'MicroF1_cate_2_mask_3': 0.39215686274509803, 'Acc_cate_2_mask_3': 0.39215686274509803, 'AP_cate_2_mask_3': 0.6379622050162386, 'MacroF1_cate_2_mask_4': nan, 'MicroF1_cate_2_mask_4': 0.0, 'Acc_cate_2_mask_4': nan, 'AP_cate_2_mask_4': nan, 'MacroF1_cate_3_mask_1': 0.4894957983193277, 'MicroF1_cate_3_mask_1': 0.9588477366255144, 'Acc_cate_3_mask_1': 0.9588477366255144, 'AP_cate_3_mask_1': 0.05385540503542361, 'MacroF1_cate_3_mask_2': nan, 'MicroF1_cate_3_mask_2': 0.0, 'Acc_cate_3_mask_2': nan, 'AP_cate_3_mask_2': nan, 'MacroF1_cate_3_mask_3': nan, 'MicroF1_cate_3_mask_3': 0.0, 'Acc_cate_3_mask_3': nan, 'AP_cate_3_mask_3': nan, 'MacroF1_cate_3_mask_4': nan, 'MicroF1_cate_3_mask_4': 0.0, 'Acc_cate_3_mask_4': nan, 'AP_cate_3_mask_4': nan, 'RMSE': 1.1249140133831947, 'MAE': 1.0654646165668964, 'MAPE': 0.9676711377445861, 'RMSE_cate_0': 1.0169260347133509, 'MAE_cate_0': 0.9958382685673287, 'MAPE_cate_0': 0.9556293755980173, 'RMSE_cate_1': 1.0665136182295354, 'MAE_cate_1': 1.034267436279311, 'MAPE_cate_1': 0.9727195851923042, 'RMSE_cate_2': 1.2075735736540332, 'MAE_cate_2': 1.1189553043087328, 'MAPE_cate_2': 0.971853559122435, 'RMSE_cate_3': 1.0530592472561726, 'MAE_cate_3': 1. ...
# Total time spent: 13.4393
# Detected seed folders under /home/jovyan/STHSL/Save/NYC_3km
#
# Checkpoint move completed (NYC_3km / baseline)
#   Mode     : seed-aware
#   Moved    : 1
#   Skipped  : 0
# Found 1 checkpoints under Logs/baseline/NYC_3km (seed folders) (sorted by seed, epoch).
#
# [seed 10 epoch 1] Running: /opt/conda/bin/python test.py --data NYC_3km --use_ode_option baseline --checkpoint Logs/baseline/NYC_3km/seed_10/_seed_10_epoch_1_MAE_1.07_MAPE_0.97_MicroF1_0.9814.pth --batch 16 --eval_metrics all
# [seed 10 epoch 1] Writing: tests_validation/baseline/NYC_3km/seed_10_epoch_1_main.txt
# [seed 10 epoch 1] OK
# \n$ python /home/jovyan/STHSL/metrics_extraction.py /home/jovyan/STHSL/tests_validation/baseline/NYC_3km --city nyc
#
# Reading folder: /home/jovyan/STHSL/tests_validation/baseline/NYC_3km
#
# City: nyc — using category map: {'0': 'BURGLARY', '1': 'FELONY ASSAULT', '2': 'GRAND LARCENY', '3': 'ROBBERY'}
# Processing seed10_epoch1: seed_10_epoch_1_main.txt
#
# Created: /home/jovyan/STHSL/tests_validation/baseline/NYC_3km/metrics_all_epochs_pivot.csv
#
#                       seed10_epoch1  seed_avg_seed10  all_seeds_avg
# MacroF1                      0.4953           0.4953         0.4953
# MicroF1                      0.9814           0.9814         0.9814
# AP                           0.0231           0.0231         0.0231
# Acc                          0.9814           0.9814         0.9814
# MacroF1_BURGLARY             0.4974           0.4974         0.4974
# ...                             ...              ...            ...
# MAPE_sparsity_<=0.5          0.9666           0.9666         0.9666
# RMSE_sparsity_<=0.75         1.8424           1.8424         1.8424
# MAE_sparsity_<=0.75          1.6292           1.6292         1.6292
# MAPE_sparsity_<=0.75         0.9900           0.9900         0.9900
# epochLoss                   12.6313          12.6313        12.6313
#
# [61 rows x 3 columns]
#
# Running: python /home/jovyan/STHSL/analyse_metrics.py /home/jovyan/STHSL/tests_validation/baseline/NYC_3km/metrics_all_epochs_pivot.csv
#
# ==============================
# BEST (SEED, EPOCH) PER METRIC (across all seeds/epochs)
# ==============================
#
#                   Metric  BestSeed  BestEpoch  BestValue Goal(min/max)
#                  MacroF1        10          1     0.4953           max
#                  MicroF1        10          1     0.9814           max
#                       AP        10          1     0.0231           max
#                      Acc        10          1     0.9814           max
#         MacroF1_BURGLARY        10          1     0.4974           min
#         MicroF1_BURGLARY        10          1     0.9895           min
#             Acc_BURGLARY        10          1     0.9895           max
#              AP_BURGLARY        10          1     0.0140           max
#   MacroF1_FELONY ASSAULT        10          1     0.4958           min
#   MicroF1_FELONY ASSAULT        10          1     0.9833           min
#       Acc_FELONY ASSAULT        10          1     0.9833           max
#        AP_FELONY ASSAULT        10          1     0.0182           max
#    MacroF1_GRAND LARCENY        10          1     0.4913           min
#    MicroF1_GRAND LARCENY        10          1     0.9657           min
#        Acc_GRAND LARCENY        10          1     0.9657           max
#         AP_GRAND LARCENY        10          1     0.0415           max
#          MacroF1_ROBBERY        10          1     0.4967           min
#          MicroF1_ROBBERY        10          1     0.9870           min
#              Acc_ROBBERY        10          1     0.9870           max
#               AP_ROBBERY        10          1     0.0227           max
#  MacroF1_over_categories        10          1     0.4953           max
#  MacroAP_over_categories        10          1     0.0241           max
# MacroAcc_over_categories        10          1     0.9814           max
#  MacroF1_sparsity_<=0.25        10          1     0.4872           min
#  MicroF1_sparsity_<=0.25        10          1     0.9501           min
#      Acc_sparsity_<=0.25        10          1     0.9501           max
#       AP_sparsity_<=0.25        10          1     0.0550           max
#   MacroF1_sparsity_<=0.5        10          1     0.4153           min
#   MicroF1_sparsity_<=0.5        10          1     0.7102           min
#       Acc_sparsity_<=0.5        10          1     0.7102           max
#        AP_sparsity_<=0.5        10          1     0.3114           max
#  MacroF1_sparsity_<=0.75        10          1     0.2817           min
#  MicroF1_sparsity_<=0.75        10          1     0.3922           min
#      Acc_sparsity_<=0.75        10          1     0.3922           max
#       AP_sparsity_<=0.75        10          1     0.6380           max
#   MicroF1_sparsity_<=1.0        10          1     0.0000           min
#                     RMSE        10          1     1.1249           min
#                      MAE        10          1     1.0655           min
#                     MAPE        10          1     0.9677           min
#            RMSE_BURGLARY        10          1     1.0169           min
#             MAE_BURGLARY        10          1     0.9958           min
#            MAPE_BURGLARY        10          1     0.9556           min
#      RMSE_FELONY ASSAULT        10          1     1.0665           min
#       MAE_FELONY ASSAULT        10          1     1.0343           min
#      MAPE_FELONY ASSAULT        10          1     0.9727           min
#       RMSE_GRAND LARCENY        10          1     1.2076           min
#        MAE_GRAND LARCENY        10          1     1.1190           min
#       MAPE_GRAND LARCENY        10          1     0.9719           min
#             RMSE_ROBBERY        10          1     1.0531           min
#              MAE_ROBBERY        10          1     1.0209           min
#             MAPE_ROBBERY        10          1     0.9599           min
#     RMSE_sparsity_<=0.25        10          1     1.0525           min
#      MAE_sparsity_<=0.25        10          1     1.0230           min
#     MAPE_sparsity_<=0.25        10          1     0.9661           min
#      RMSE_sparsity_<=0.5        10          1     1.1711           min
#       MAE_sparsity_<=0.5        10          1     1.1078           min
#      MAPE_sparsity_<=0.5        10          1     0.9666           min
#     RMSE_sparsity_<=0.75        10          1     1.8424           min
#      MAE_sparsity_<=0.75        10          1     1.6292           min
#     MAPE_sparsity_<=0.75        10          1     0.9900           min
#                epochLoss        10          1    12.6313           min
#
# ==============================
# OVERALL BEST (SEED, EPOCH) BY 'MOST METRICS WON'
# ==============================
# Best (seed, epoch) overall: seed=10 epoch=1 (wins 61 metrics)
#
#
# ==============================
# OVERALL BEST EPOCH WITHIN EACH SEED (wins across metrics)
# ==============================
#
#  Seed  OverallBestEpochWithinSeed  WinsCount
#    10                           1         61
#
# ==============================
# BEST SEED BY AVERAGE-OVER-EPOCHS (per metric)
# ==============================
#
#                   Metric  BestSeedByAvgEpochs  BestValueByAvgEpochs Goal(min/max)
#                  MacroF1                   10                0.4953           max
#                  MicroF1                   10                0.9814           max
#                       AP                   10                0.0231           max
#                      Acc                   10                0.9814           max
#         MacroF1_BURGLARY                   10                0.4974           min
#         MicroF1_BURGLARY                   10                0.9895           min
#             Acc_BURGLARY                   10                0.9895           max
#              AP_BURGLARY                   10                0.0140           max
#   MacroF1_FELONY ASSAULT                   10                0.4958           min
#   MicroF1_FELONY ASSAULT                   10                0.9833           min
#       Acc_FELONY ASSAULT                   10                0.9833           max
#        AP_FELONY ASSAULT                   10                0.0182           max
#    MacroF1_GRAND LARCENY                   10                0.4913           min
#    MicroF1_GRAND LARCENY                   10                0.9657           min
#        Acc_GRAND LARCENY                   10                0.9657           max
#         AP_GRAND LARCENY                   10                0.0415           max
#          MacroF1_ROBBERY                   10                0.4967           min
#          MicroF1_ROBBERY                   10                0.9870           min
#              Acc_ROBBERY                   10                0.9870           max
#               AP_ROBBERY                   10                0.0227           max
#  MacroF1_over_categories                   10                0.4953           max
#  MacroAP_over_categories                   10                0.0241           max
# MacroAcc_over_categories                   10                0.9814           max
#  MacroF1_sparsity_<=0.25                   10                0.4872           min
#  MicroF1_sparsity_<=0.25                   10                0.9501           min
#      Acc_sparsity_<=0.25                   10                0.9501           max
#       AP_sparsity_<=0.25                   10                0.0550           max
#   MacroF1_sparsity_<=0.5                   10                0.4153           min
#   MicroF1_sparsity_<=0.5                   10                0.7102           min
#       Acc_sparsity_<=0.5                   10                0.7102           max
#        AP_sparsity_<=0.5                   10                0.3114           max
#  MacroF1_sparsity_<=0.75                   10                0.2817           min
#  MicroF1_sparsity_<=0.75                   10                0.3922           min
#      Acc_sparsity_<=0.75                   10                0.3922           max
#       AP_sparsity_<=0.75                   10                0.6380           max
#   MicroF1_sparsity_<=1.0                   10                0.0000           min
#                     RMSE                   10                1.1249           min
#                      MAE                   10                1.0655           min
#                     MAPE                   10                0.9677           min
#            RMSE_BURGLARY                   10                1.0169           min
#             MAE_BURGLARY                   10                0.9958           min
#            MAPE_BURGLARY                   10                0.9556           min
#      RMSE_FELONY ASSAULT                   10                1.0665           min
#       MAE_FELONY ASSAULT                   10                1.0343           min
#      MAPE_FELONY ASSAULT                   10                0.9727           min
#       RMSE_GRAND LARCENY                   10                1.2076           min
#        MAE_GRAND LARCENY                   10                1.1190           min
#       MAPE_GRAND LARCENY                   10                0.9719           min
#             RMSE_ROBBERY                   10                1.0531           min
#              MAE_ROBBERY                   10                1.0209           min
#             MAPE_ROBBERY                   10                0.9599           min
#     RMSE_sparsity_<=0.25                   10                1.0525           min
#      MAE_sparsity_<=0.25                   10                1.0230           min
#     MAPE_sparsity_<=0.25                   10                0.9661           min
#      RMSE_sparsity_<=0.5                   10                1.1711           min
#       MAE_sparsity_<=0.5                   10                1.1078           min
#      MAPE_sparsity_<=0.5                   10                0.9666           min
#     RMSE_sparsity_<=0.75                   10                1.8424           min
#      MAE_sparsity_<=0.75                   10                1.6292           min
#     MAPE_sparsity_<=0.75                   10                0.9900           min
#                epochLoss                   10               12.6313           min
#
# Saved: /home/jovyan/STHSL/tests_validation/baseline/NYC_3km/metrics_all_epochs_pivot_ranking_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/NYC_3km/metrics_all_epochs_pivot_ranking_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/NYC_3km/metrics_all_epochs_pivot_summary_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/NYC_3km/metrics_all_epochs_pivot_summary_overall_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/NYC_3km/metrics_all_epochs_pivot_ranking_best_seed_by_avg.csv

# %%
# !python train.py --data NYC_3km --use_ode_option option1 --device cuda --eval_metrics all --batch 16 --n_traj_samples 2 --ode_method dopri5 --odeint_atol 0.01 --odeint_rtol 0.0001 --gen_layers 2 --gen_dim 64 --gcn_step 2 --horizon 12
step_move_checkpoints("NYC_3km", "option1", on_conflict="overwrite")
# !python metrics_generation.py --data NYC_3km --use_ode_option option1 --device cuda --eval_metrics all --batch 16 --n_traj_samples 2 --ode_method dopri5 --odeint_atol 0.01 --odeint_rtol 0.0001 --gen_layers 2 --gen_dim 64 --gcn_step 2 --horizon 12 --save-root Logs/option1 --out-dir tests_validation/option1/NYC_3km 
step_metrics_extraction("NYC_3km", "option1")
step_analyse("NYC_3km", "option1")
# Out:
# self.predir Datasets/common_data/NYC_crime_3km/
# (256, 153, 4)
# Row: 16 , Col: 16
# Sparsity: 0.017908406649908594
# use_ode_option: option1
# ODE option 1 is enabled, STHSL model with option1 components is initialized
# ODE setting --latent 16 --samples 2 --method dopri5                 --atol 0.010000 --rtol 0.000100 --gen_layer 2 --gen_dim 64 --num_nodes 256
# DEBUG SHAPES status: True
#
# ===== SEED 10 =====
# start training...
# ===== TRAINING ARGS =====
# lr: 0.001
# weight_decay: 0.0001
# cr: 0.8
# ir: 1
# t: 0.05
# batch: 16
# epoch: 1
# latdim: 16
# temporalRange: 30
# cateNum: 4
# data: NYC_3km
# kernelSize: 3
# border: 0.5
# hyperNum: 128
# dropRateL: 0.2
# dropRateG: 0.1
# use_ode_option: option1
# n_traj_samples: 2
# ode_method: dopri5
# odeint_atol: 0.01
# odeint_rtol: 0.0001
# gen_layers: 2
# gen_dim: 64
# save_latent: false
# gcn_step: 2
# rnn_units: 64
# horizon: 12
# filter_type: 2
# device: cuda
# tstEpoch: 1
# save: ./Save/
# checkpoint: ./Save/NYC/
# eval_metrics: all
# f1_label_threshold: 0.0
# f1_pred_threshold: 0.5
# seeds: [10]
# row: 16
# col: 16
# offNum: 4
# areaNum: 256
# trnDays: 547
# valDays: 31
# tstDays: 153
# decay_step: 34
# ==========================
# time grid: torch.Size([12])
# n_traj_samples: 2
# Decoder input Z_t shape: torch.Size([16, 1024, 64])
# Labels shape: torch.Size([16, 256, 4])
# Epoch  1 Training Time 17.954s
# Epoch 1/1, Train Loss =  6.5817,  preLoss =  5.9905
# /home/jovyan/STHSL/engine.py:402: RuntimeWarning: invalid value encountered in scalar divide
#   ret['RMSE_mask_4'] = np.sqrt(np.sum(epochSqLoss4) / np.sum(epochTstNum4))
# /home/jovyan/STHSL/engine.py:403: RuntimeWarning: invalid value encountered in scalar divide
#   ret['MAE_mask_4'] = np.sum(epochAbsLoss4) / np.sum(epochTstNum4)
# /home/jovyan/STHSL/engine.py:404: RuntimeWarning: invalid value encountered in scalar divide
#   ret['MAPE_mask_4'] = np.sum(epochApeLoss4) / np.sum(epochPosNums4)
# Val (MicroF1+MacroF1) increase from -1.0000 to 1.4762
# /home/jovyan/STHSL/engine.py:402: RuntimeWarning: invalid value encountered in scalar divide
#   ret['RMSE_mask_4'] = np.sqrt(np.sum(epochSqLoss4) / np.sum(epochTstNum4))
# /home/jovyan/STHSL/engine.py:403: RuntimeWarning: invalid value encountered in scalar divide
#   ret['MAE_mask_4'] = np.sum(epochAbsLoss4) / np.sum(epochTstNum4)
# /home/jovyan/STHSL/engine.py:404: RuntimeWarning: invalid value encountered in scalar divide
#   ret['MAPE_mask_4'] = np.sum(epochApeLoss4) / np.sum(epochPosNums4)
# Epoch 1/1, Test: MacroF1 = 0.4953, MicroF1 = 0.9814, AP = 0.0399, Acc = 0.9814, MacroF1_cate_0 = 0.4974, MicroF1_cate_0 = 0.9895, Acc_cate_0 = 0.9895, AP_cate_0 = 0.0102, MacroF1_cate_1 = 0.4958, MicroF1_cate_1 = 0.9833, Acc_cate_1 = 0.9833, AP_cate_1 = 0.0317, MacroF1_cate_2 = 0.4913, MicroF1_cate_2 = 0.9657, Acc_cate_2 = 0.9657, AP_cate_2 = 0.0813, MacroF1_cate_3 = 0.4967, MicroF1_cate_3 = 0.9870, Acc_cate_3 = 0.9870, AP_cate_3 = 0.0123, MacroF1_over_categories = 0.4953, MicroF1_over_categories = 0.9814, MacroAP_over_categories = 0.0339, MacroAcc_over_categories = 0.9814, MacroF1_mask_1 = 0.4872, MicroF1_mask_1 = 0.9501, Acc_mask_1 = 0.9501, AP_mask_1 = 0.0650, MacroF1_mask_2 = 0.4153, MicroF1_mask_2 = 0.7102, Acc_mask_2 = 0.7102, AP_mask_2 = 0.3179, MacroF1_mask_3 = 0.2817, MicroF1_mask_3 = 0.3922, Acc_mask_3 = 0.3922, AP_mask_3 = 0.6471, MacroF1_mask_4 = nan, MicroF1_mask_4 = 0.0000, Acc_mask_4 = nan, AP_mask_4 = nan, MacroF1_cate_0_mask_1 = 0.4910, MicroF1_cate_0_mask_1 = 0.9646, Acc_cate_0_mask_1 = 0.9646, AP_cate_0_mask_1 = 0.0384, MacroF1_cate_0_mask_2 = nan, MicroF1_cate_0_mask_2 = 0.0000, Acc_cate_0_mask_2 = nan, AP_cate_0_mask_2 = nan, MacroF1_cate_0_mask_3 = nan, MicroF1_cate_0_mask_3 = 0.0000, Acc_cate_0_mask_3 = nan, AP_cate_0_mask_3 = nan, MacroF1_cate_0_mask_4 = nan, MicroF1_cate_0_mask_4 = 0.0000, Acc_cate_0_mask_4 = nan, AP_cate_0_mask_4 = nan, MacroF1_cate_1_mask_1 = 0.4872, MicroF1_cate_1_mask_1 = 0.9502, Acc_cate_1_mask_1 = 0.9502, AP_cate_1_mask_1 = 0.0639, MacroF1_cate_1_mask_2 = nan, MicroF1_cate_1_mask_2 = 0.0000, Acc_cate_1_mask_2 = nan, AP_cate_1_mask_2 = nan, MacroF1_cate_1_mask_3 = nan, MicroF1_cate_1_mask_3 = 0.0000, Acc_cate_1_mask_3 = nan, AP_cate_1_mask_3 = nan, MacroF1_cate_1_mask_4 = nan, MicroF1_cate_1_mask_4 = 0.0000, Acc_cate_1_mask_4 = nan, AP_cate_1_mask_4 = nan, MacroF1_cate_2_mask_1 = 0.4823, MicroF1_cate_2_mask_1 = 0.9317, Acc_cate_2_mask_1 = 0.9317, AP_cate_2_mask_1 = 0.0796, MacroF1_cate_2_mask_2 = 0.4153, MicroF1_cate_2_mask_2 = 0.7102, Acc_cate_2_mask_2 = 0.7102, AP_cate_2_mask_2 = 0.3179, MacroF1_cate_2_mask_3 = 0.2817, MicroF1_cate_2_mask_3 = 0.3922, Acc_cate_2_mask_3 = 0.3922, AP_cate_2_mask_3 = 0.6471, MacroF1_cate_2_mask_4 = nan, MicroF1_cate_2_mask_4 = 0.0000, Acc_cate_2_mask_4 = nan, AP_cate_2_mask_4 = nan, MacroF1_cate_3_mask_1 = 0.4895, MicroF1_cate_3_mask_1 = 0.9588, Acc_cate_3_mask_1 = 0.9588, AP_cate_3_mask_1 = 0.0528, MacroF1_cate_3_mask_2 = nan, MicroF1_cate_3_mask_2 = 0.0000, Acc_cate_3_mask_2 = nan, AP_cate_3_mask_2 = nan, MacroF1_cate_3_mask_3 = nan, MicroF1_cate_3_mask_3 = 0.0000, Acc_cate_3_mask_3 = nan, AP_cate_3_mask_3 = nan, MacroF1_cate_3_mask_4 = nan, MicroF1_cate_3_mask_4 = 0.0000, Acc_cate_3_mask_4 = nan, AP_cate_3_mask_4 = nan, RMSE = 1.1309, MAE = 1.0745, MAPE = 0.9766, RMSE_cate_0 = 1.0442, MAE_cate_0 = 1.0251, MAPE_cate_0 = 0.9843, RMSE_cate_1 = 1.0647, MAE_cate_1 = 1.0337, MAPE_cate_1 = 0.9720, RMSE_cate_2 = 1.2041, MAE_cate_2 = 1.1184, MAPE_cate_2 = 0.9718, RMSE_cate_3 = 1.0805, MAE_cate_3 = 1.0513, MAPE_cate_3 = 0.9891, RMSE_mask_1 = 1.0623, MAE_mask_1 = 1.0348, MAPE_mask_1 = 0.9775, RMSE_mask_2 = 1.1710, MAE_mask_2 = 1.1112, MAPE_mask_2 = 0.9709, RMSE_mask_3 = 1.8210, MAE_mask_3 = 1.6035, MAPE_mask_3 = 0.9691, RMSE_mask_4 = nan, MAE_mask_4 = nan, MAPE_mask_4 = nan, epochLoss = 1.2763
# MacroF1=0.4953 MicroF1=0.9814 AP=0.0399
#
#   [RUNTIME] Epoch 1: train=17.95s | train+eval=20.07s
#
# ============================================================
# RUNTIME ANALYSIS SUMMARY (STHSL)
# ============================================================
#   Seed:                      10
#   Epochs run:                1
#   Avg train time/epoch:      17.95s (+/- 0.00s)
#   Avg total time/epoch:      20.07s (+/- 0.00s)
#   Per-epoch train times:     ['17.95']
#   Total training time:       20.07s
# ============================================================
#
# Epoch 1/1, Best: MacroF1 = 0.4953, MicroF1 = 0.9814, AP = 0.0399, Acc = 0.9814, MacroF1_cate_0 = 0.4974, MicroF1_cate_0 = 0.9895, Acc_cate_0 = 0.9895, AP_cate_0 = 0.0102, MacroF1_cate_1 = 0.4958, MicroF1_cate_1 = 0.9833, Acc_cate_1 = 0.9833, AP_cate_1 = 0.0317, MacroF1_cate_2 = 0.4913, MicroF1_cate_2 = 0.9657, Acc_cate_2 = 0.9657, AP_cate_2 = 0.0813, MacroF1_cate_3 = 0.4967, MicroF1_cate_3 = 0.9870, Acc_cate_3 = 0.9870, AP_cate_3 = 0.0123, MacroF1_over_categories = 0.4953, MicroF1_over_categories = 0.9814, MacroAP_over_categories = 0.0339, MacroAcc_over_categories = 0.9814, MacroF1_mask_1 = 0.4872, MicroF1_mask_1 = 0.9501, Acc_mask_1 = 0.9501, AP_mask_1 = 0.0650, MacroF1_mask_2 = 0.4153, MicroF1_mask_2 = 0.7102, Acc_mask_2 = 0.7102, AP_mask_2 = 0.3179, MacroF1_mask_3 = 0.2817, MicroF1_mask_3 = 0.3922, Acc_mask_3 = 0.3922, AP_mask_3 = 0.6471, MacroF1_mask_4 = nan, MicroF1_mask_4 = 0.0000, Acc_mask_4 = nan, AP_mask_4 = nan, MacroF1_cate_0_mask_1 = 0.4910, MicroF1_cate_0_mask_1 = 0.9646, Acc_cate_0_mask_1 = 0.9646, AP_cate_0_mask_1 = 0.0384, MacroF1_cate_0_mask_2 = nan, MicroF1_cate_0_mask_2 = 0.0000, Acc_cate_0_mask_2 = nan, AP_cate_0_mask_2 = nan, MacroF1_cate_0_mask_3 = nan, MicroF1_cate_0_mask_3 = 0.0000, Acc_cate_0_mask_3 = nan, AP_cate_0_mask_3 = nan, MacroF1_cate_0_mask_4 = nan, MicroF1_cate_0_mask_4 = 0.0000, Acc_cate_0_mask_4 = nan, AP_cate_0_mask_4 = nan, MacroF1_cate_1_mask_1 = 0.4872, MicroF1_cate_1_mask_1 = 0.9502, Acc_cate_1_mask_1 = 0.9502, AP_cate_1_mask_1 = 0.0639, MacroF1_cate_1_mask_2 = nan, MicroF1_cate_1_mask_2 = 0.0000, Acc_cate_1_mask_2 = nan, AP_cate_1_mask_2 = nan, MacroF1_cate_1_mask_3 = nan, MicroF1_cate_1_mask_3 = 0.0000, Acc_cate_1_mask_3 = nan, AP_cate_1_mask_3 = nan, MacroF1_cate_1_mask_4 = nan, MicroF1_cate_1_mask_4 = 0.0000, Acc_cate_1_mask_4 = nan, AP_cate_1_mask_4 = nan, MacroF1_cate_2_mask_1 = 0.4823, MicroF1_cate_2_mask_1 = 0.9317, Acc_cate_2_mask_1 = 0.9317, AP_cate_2_mask_1 = 0.0796, MacroF1_cate_2_mask_2 = 0.4153, MicroF1_cate_2_mask_2 = 0.7102, Acc_cate_2_mask_2 = 0.7102, AP_cate_2_mask_2 = 0.3179, MacroF1_cate_2_mask_3 = 0.2817, MicroF1_cate_2_mask_3 = 0.3922, Acc_cate_2_mask_3 = 0.3922, AP_cate_2_mask_3 = 0.6471, MacroF1_cate_2_mask_4 = nan, MicroF1_cate_2_mask_4 = 0.0000, Acc_cate_2_mask_4 = nan, AP_cate_2_mask_4 = nan, MacroF1_cate_3_mask_1 = 0.4895, MicroF1_cate_3_mask_1 = 0.9588, Acc_cate_3_mask_1 = 0.9588, AP_cate_3_mask_1 = 0.0528, MacroF1_cate_3_mask_2 = nan, MicroF1_cate_3_mask_2 = 0.0000, Acc_cate_3_mask_2 = nan, AP_cate_3_mask_2 = nan, MacroF1_cate_3_mask_3 = nan, MicroF1_cate_3_mask_3 = 0.0000, Acc_cate_3_mask_3 = nan, AP_cate_3_mask_3 = nan, MacroF1_cate_3_mask_4 = nan, MicroF1_cate_3_mask_4 = 0.0000, Acc_cate_3_mask_4 = nan, AP_cate_3_mask_4 = nan, RMSE = 1.1309, MAE = 1.0745, MAPE = 0.9766, RMSE_cate_0 = 1.0442, MAE_cate_0 = 1.0251, MAPE_cate_0 = 0.9843, RMSE_cate_1 = 1.0647, MAE_cate_1 = 1.0337, MAPE_cate_1 = 0.9720, RMSE_cate_2 = 1.2041, MAE_cate_2 = 1.1184, MAPE_cate_2 = 0.9718, RMSE_cate_3 = 1.0805, MAE_cate_3 = 1.0513, MAPE_cate_3 = 0.9891, RMSE_mask_1 = 1.0623, MAE_mask_1 = 1.0348, MAPE_mask_1 = 0.9775, RMSE_mask_2 = 1.1710, MAE_mask_2 = 1.1112, MAPE_mask_2 = 0.9709, RMSE_mask_3 = 1.8210, MAE_mask_3 = 1.6035, MAPE_mask_3 = 0.9691, RMSE_mask_4 = nan, MAE_mask_4 = nan, MAPE_mask_4 = nan, epochLoss = 1.2763
#
# ===== SUMMARY: best result per seed =====
# seed=10: {'MacroF1': 0.4952967554055099, 'MicroF1': 0.9813623366013072, 'AP': 0.03993967309923445, 'Acc': 0.9813623366013072, 'MacroF1_cate_0': 0.4973563985421693, 'MicroF1_cate_0': 0.9894812091503268, 'Acc_cate_0': 0.9894812091503268, 'AP_cate_0': 0.010190666761879618, 'MacroF1_cate_1': 0.49578403985530567, 'MicroF1_cate_1': 0.9832771650326797, 'Acc_cate_1': 0.9832771650326797, 'AP_cate_1': 0.03174597580232608, 'MacroF1_cate_2': 0.4912784279090307, 'MicroF1_cate_2': 0.9657118055555556, 'Acc_cate_2': 0.9657118055555556, 'AP_cate_2': 0.0813184674448198, 'MacroF1_cate_3': 0.4967234600262123, 'MicroF1_cate_3': 0.9869791666666666, 'Acc_cate_3': 0.9869791666666666, 'AP_cate_3': 0.012300108931646124, 'MacroF1_over_categories': 0.4952855815831795, 'MicroF1_over_categories': 0.9813623366013072, 'MacroAP_over_categories': 0.03388880473516791, 'MacroAcc_over_categories': 0.9813623366013072, 'MacroF1_mask_1': 0.48721804511278194, 'MicroF1_mask_1': 0.9501466275659824, 'Acc_mask_1': 0.9501466275659824, 'AP_mask_1': 0.06502798695142935, 'MacroF1_mask_2': 0.4152866242038217, 'MicroF1_mask_2': 0.710239651416122, 'Acc_mask_2': 0.710239651416122, 'AP_mask_2': 0.3178943241837823, 'MacroF1_mask_3': 0.28169014084507044, 'MicroF1_mask_3': 0.39215686274509803, 'Acc_mask_3': 0.39215686274509803, 'AP_mask_3': 0.6471376016067238, 'MacroF1_mask_4': nan, 'MicroF1_mask_4': 0.0, 'Acc_mask_4': nan, 'AP_mask_4': nan, 'MacroF1_cate_0_mask_1': 0.49098231483102783, 'MicroF1_cate_0_mask_1': 0.9645682834537324, 'Acc_cate_0_mask_1': 0.9645682834537324, 'AP_cate_0_mask_1': 0.038390148573060286, 'MacroF1_cate_0_mask_2': nan, 'MicroF1_cate_0_mask_2': 0.0, 'Acc_cate_0_mask_2': nan, 'AP_cate_0_mask_2': nan, 'MacroF1_cate_0_mask_3': nan, 'MicroF1_cate_0_mask_3': 0.0, 'Acc_cate_0_mask_3': nan, 'AP_cate_0_mask_3': nan, 'MacroF1_cate_0_mask_4': nan, 'MicroF1_cate_0_mask_4': 0.0, 'Acc_cate_0_mask_4': nan, 'AP_cate_0_mask_4': nan, 'MacroF1_cate_1_mask_1': 0.48723744203265656, 'MicroF1_cate_1_mask_1': 0.9502203982368141, 'Acc_cate_1_mask_1': 0.9502203982368141, 'AP_cate_1_mask_1': 0.06392731712300587, 'MacroF1_cate_1_mask_2': nan, 'MicroF1_cate_1_mask_2': 0.0, 'Acc_cate_1_mask_2': nan, 'AP_cate_1_mask_2': nan, 'MacroF1_cate_1_mask_3': nan, 'MicroF1_cate_1_mask_3': 0.0, 'Acc_cate_1_mask_3': nan, 'AP_cate_1_mask_3': nan, 'MacroF1_cate_1_mask_4': nan, 'MicroF1_cate_1_mask_4': 0.0, 'Acc_cate_1_mask_4': nan, 'AP_cate_1_mask_4': nan, 'MacroF1_cate_2_mask_1': 0.48232288357961606, 'MicroF1_cate_2_mask_1': 0.9317060157396292, 'Acc_cate_2_mask_1': 0.9317060157396292, 'AP_cate_2_mask_1': 0.0796020158685096, 'MacroF1_cate_2_mask_2': 0.4152866242038217, 'MicroF1_cate_2_mask_2': 0.710239651416122, 'Acc_cate_2_mask_2': 0.710239651416122, 'AP_cate_2_mask_2': 0.3178943241837823, 'MacroF1_cate_2_mask_3': 0.28169014084507044, 'MicroF1_cate_2_mask_3': 0.39215686274509803, 'Acc_cate_2_mask_3': 0.39215686274509803, 'AP_cate_2_mask_3': 0.6471376016067238, 'MacroF1_cate_2_mask_4': nan, 'MicroF1_cate_2_mask_4': 0.0, 'Acc_cate_2_mask_4': nan, 'AP_cate_2_mask_4': nan, 'MacroF1_cate_3_mask_1': 0.4894957983193277, 'MicroF1_cate_3_mask_1': 0.9588477366255144, 'Acc_cate_3_mask_1': 0.9588477366255144, 'AP_cate_3_mask_1': 0.052836758973461344, 'MacroF1_cate_3_mask_2': nan, 'MicroF1_cate_3_mask_2': 0.0, 'Acc_cate_3_mask_2': nan, 'AP_cate_3_mask_2': nan, 'MacroF1_cate_3_mask_3': nan, 'MicroF1_cate_3_mask_3': 0.0, 'Acc_cate_3_mask_3': nan, 'AP_cate_3_mask_3': nan, 'MacroF1_cate_3_mask_4': nan, 'MicroF1_cate_3_mask_4': 0.0, 'Acc_cate_3_mask_4': nan, 'AP_cate_3_mask_4': nan, 'RMSE': 1.1308843300395357, 'MAE': 1.074506467510627, 'MAPE': 0.9766359342504285, 'RMSE_cate_0': 1.04420913368296, 'MAE_cate_0': 1.0251441815646491, 'MAPE_cate_0': 0.9842507752452169, 'RMSE_cate_1': 1.06469224777807, 'MAE_cate_1': 1.0337185146073804, 'MAPE_cate_1': 0.9719979235355805, 'RMSE_cate_2': 1.2041440228028066, 'MAE_cate_2': 1.118350250955757, 'MAPE_cate_2': 0.9718386631838295, 'RMSE_cate_3': 1.0804541907771135, 'MAE_cate_3': 1.051312 ...
# Total time spent: 21.0232
# Detected seed folders under /home/jovyan/STHSL/Save/NYC_3km
#
# Checkpoint move completed (NYC_3km / option1)
#   Mode     : seed-aware
#   Moved    : 1
#   Skipped  : 0
# Found 1 checkpoints under Logs/option1/NYC_3km (seed folders) (sorted by seed, epoch).
#
# [seed 10 epoch 1] Running: /opt/conda/bin/python test.py --data NYC_3km --use_ode_option option1 --checkpoint Logs/option1/NYC_3km/seed_10/_seed_10_epoch_1_MAE_1.07_MAPE_0.98_MicroF1_0.9814.pth --batch 16 --eval_metrics all --n_traj_samples 2 --ode_method dopri5 --odeint_atol 0.01 --odeint_rtol 0.0001 --gen_layers 2 --gen_dim 64 --gcn_step 2 --rnn_units 64 --horizon 12 --filter_type 2
# [seed 10 epoch 1] Writing: tests_validation/option1/NYC_3km/seed_10_epoch_1_main.txt
# [seed 10 epoch 1] OK
# \n$ python /home/jovyan/STHSL/metrics_extraction.py /home/jovyan/STHSL/tests_validation/option1/NYC_3km --city nyc
#
# Reading folder: /home/jovyan/STHSL/tests_validation/option1/NYC_3km
#
# City: nyc — using category map: {'0': 'BURGLARY', '1': 'FELONY ASSAULT', '2': 'GRAND LARCENY', '3': 'ROBBERY'}
# Processing seed10_epoch1: seed_10_epoch_1_main.txt
#
# Created: /home/jovyan/STHSL/tests_validation/option1/NYC_3km/metrics_all_epochs_pivot.csv
#
#                       seed10_epoch1  seed_avg_seed10  all_seeds_avg
# MacroF1                      0.4953           0.4953         0.4953
# MicroF1                      0.9814           0.9814         0.9814
# AP                           0.0399           0.0399         0.0399
# Acc                          0.9814           0.9814         0.9814
# MacroF1_BURGLARY             0.4974           0.4974         0.4974
# ...                             ...              ...            ...
# MAPE_sparsity_<=0.5          0.9709           0.9709         0.9709
# RMSE_sparsity_<=0.75         1.8210           1.8210         1.8210
# MAE_sparsity_<=0.75          1.6035           1.6035         1.6035
# MAPE_sparsity_<=0.75         0.9691           0.9691         0.9691
# epochLoss                   12.7632          12.7632        12.7632
#
# [61 rows x 3 columns]
#
# Running: python /home/jovyan/STHSL/analyse_metrics.py /home/jovyan/STHSL/tests_validation/option1/NYC_3km/metrics_all_epochs_pivot.csv
#
# ==============================
# BEST (SEED, EPOCH) PER METRIC (across all seeds/epochs)
# ==============================
#
#                   Metric  BestSeed  BestEpoch  BestValue Goal(min/max)
#                  MacroF1        10          1     0.4953           max
#                  MicroF1        10          1     0.9814           max
#                       AP        10          1     0.0399           max
#                      Acc        10          1     0.9814           max
#         MacroF1_BURGLARY        10          1     0.4974           min
#         MicroF1_BURGLARY        10          1     0.9895           min
#             Acc_BURGLARY        10          1     0.9895           max
#              AP_BURGLARY        10          1     0.0102           max
#   MacroF1_FELONY ASSAULT        10          1     0.4958           min
#   MicroF1_FELONY ASSAULT        10          1     0.9833           min
#       Acc_FELONY ASSAULT        10          1     0.9833           max
#        AP_FELONY ASSAULT        10          1     0.0317           max
#    MacroF1_GRAND LARCENY        10          1     0.4913           min
#    MicroF1_GRAND LARCENY        10          1     0.9657           min
#        Acc_GRAND LARCENY        10          1     0.9657           max
#         AP_GRAND LARCENY        10          1     0.0813           max
#          MacroF1_ROBBERY        10          1     0.4967           min
#          MicroF1_ROBBERY        10          1     0.9870           min
#              Acc_ROBBERY        10          1     0.9870           max
#               AP_ROBBERY        10          1     0.0123           max
#  MacroF1_over_categories        10          1     0.4953           max
#  MacroAP_over_categories        10          1     0.0339           max
# MacroAcc_over_categories        10          1     0.9814           max
#  MacroF1_sparsity_<=0.25        10          1     0.4872           min
#  MicroF1_sparsity_<=0.25        10          1     0.9501           min
#      Acc_sparsity_<=0.25        10          1     0.9501           max
#       AP_sparsity_<=0.25        10          1     0.0650           max
#   MacroF1_sparsity_<=0.5        10          1     0.4153           min
#   MicroF1_sparsity_<=0.5        10          1     0.7102           min
#       Acc_sparsity_<=0.5        10          1     0.7102           max
#        AP_sparsity_<=0.5        10          1     0.3179           max
#  MacroF1_sparsity_<=0.75        10          1     0.2817           min
#  MicroF1_sparsity_<=0.75        10          1     0.3922           min
#      Acc_sparsity_<=0.75        10          1     0.3922           max
#       AP_sparsity_<=0.75        10          1     0.6471           max
#   MicroF1_sparsity_<=1.0        10          1     0.0000           min
#                     RMSE        10          1     1.1309           min
#                      MAE        10          1     1.0745           min
#                     MAPE        10          1     0.9766           min
#            RMSE_BURGLARY        10          1     1.0442           min
#             MAE_BURGLARY        10          1     1.0251           min
#            MAPE_BURGLARY        10          1     0.9843           min
#      RMSE_FELONY ASSAULT        10          1     1.0647           min
#       MAE_FELONY ASSAULT        10          1     1.0337           min
#      MAPE_FELONY ASSAULT        10          1     0.9720           min
#       RMSE_GRAND LARCENY        10          1     1.2041           min
#        MAE_GRAND LARCENY        10          1     1.1184           min
#       MAPE_GRAND LARCENY        10          1     0.9718           min
#             RMSE_ROBBERY        10          1     1.0805           min
#              MAE_ROBBERY        10          1     1.0513           min
#             MAPE_ROBBERY        10          1     0.9891           min
#     RMSE_sparsity_<=0.25        10          1     1.0623           min
#      MAE_sparsity_<=0.25        10          1     1.0348           min
#     MAPE_sparsity_<=0.25        10          1     0.9775           min
#      RMSE_sparsity_<=0.5        10          1     1.1710           min
#       MAE_sparsity_<=0.5        10          1     1.1112           min
#      MAPE_sparsity_<=0.5        10          1     0.9709           min
#     RMSE_sparsity_<=0.75        10          1     1.8210           min
#      MAE_sparsity_<=0.75        10          1     1.6035           min
#     MAPE_sparsity_<=0.75        10          1     0.9691           min
#                epochLoss        10          1    12.7632           min
#
# ==============================
# OVERALL BEST (SEED, EPOCH) BY 'MOST METRICS WON'
# ==============================
# Best (seed, epoch) overall: seed=10 epoch=1 (wins 61 metrics)
#
#
# ==============================
# OVERALL BEST EPOCH WITHIN EACH SEED (wins across metrics)
# ==============================
#
#  Seed  OverallBestEpochWithinSeed  WinsCount
#    10                           1         61
#
# ==============================
# BEST SEED BY AVERAGE-OVER-EPOCHS (per metric)
# ==============================
#
#                   Metric  BestSeedByAvgEpochs  BestValueByAvgEpochs Goal(min/max)
#                  MacroF1                   10                0.4953           max
#                  MicroF1                   10                0.9814           max
#                       AP                   10                0.0399           max
#                      Acc                   10                0.9814           max
#         MacroF1_BURGLARY                   10                0.4974           min
#         MicroF1_BURGLARY                   10                0.9895           min
#             Acc_BURGLARY                   10                0.9895           max
#              AP_BURGLARY                   10                0.0102           max
#   MacroF1_FELONY ASSAULT                   10                0.4958           min
#   MicroF1_FELONY ASSAULT                   10                0.9833           min
#       Acc_FELONY ASSAULT                   10                0.9833           max
#        AP_FELONY ASSAULT                   10                0.0317           max
#    MacroF1_GRAND LARCENY                   10                0.4913           min
#    MicroF1_GRAND LARCENY                   10                0.9657           min
#        Acc_GRAND LARCENY                   10                0.9657           max
#         AP_GRAND LARCENY                   10                0.0813           max
#          MacroF1_ROBBERY                   10                0.4967           min
#          MicroF1_ROBBERY                   10                0.9870           min
#              Acc_ROBBERY                   10                0.9870           max
#               AP_ROBBERY                   10                0.0123           max
#  MacroF1_over_categories                   10                0.4953           max
#  MacroAP_over_categories                   10                0.0339           max
# MacroAcc_over_categories                   10                0.9814           max
#  MacroF1_sparsity_<=0.25                   10                0.4872           min
#  MicroF1_sparsity_<=0.25                   10                0.9501           min
#      Acc_sparsity_<=0.25                   10                0.9501           max
#       AP_sparsity_<=0.25                   10                0.0650           max
#   MacroF1_sparsity_<=0.5                   10                0.4153           min
#   MicroF1_sparsity_<=0.5                   10                0.7102           min
#       Acc_sparsity_<=0.5                   10                0.7102           max
#        AP_sparsity_<=0.5                   10                0.3179           max
#  MacroF1_sparsity_<=0.75                   10                0.2817           min
#  MicroF1_sparsity_<=0.75                   10                0.3922           min
#      Acc_sparsity_<=0.75                   10                0.3922           max
#       AP_sparsity_<=0.75                   10                0.6471           max
#   MicroF1_sparsity_<=1.0                   10                0.0000           min
#                     RMSE                   10                1.1309           min
#                      MAE                   10                1.0745           min
#                     MAPE                   10                0.9766           min
#            RMSE_BURGLARY                   10                1.0442           min
#             MAE_BURGLARY                   10                1.0251           min
#            MAPE_BURGLARY                   10                0.9843           min
#      RMSE_FELONY ASSAULT                   10                1.0647           min
#       MAE_FELONY ASSAULT                   10                1.0337           min
#      MAPE_FELONY ASSAULT                   10                0.9720           min
#       RMSE_GRAND LARCENY                   10                1.2041           min
#        MAE_GRAND LARCENY                   10                1.1184           min
#       MAPE_GRAND LARCENY                   10                0.9718           min
#             RMSE_ROBBERY                   10                1.0805           min
#              MAE_ROBBERY                   10                1.0513           min
#             MAPE_ROBBERY                   10                0.9891           min
#     RMSE_sparsity_<=0.25                   10                1.0623           min
#      MAE_sparsity_<=0.25                   10                1.0348           min
#     MAPE_sparsity_<=0.25                   10                0.9775           min
#      RMSE_sparsity_<=0.5                   10                1.1710           min
#       MAE_sparsity_<=0.5                   10                1.1112           min
#      MAPE_sparsity_<=0.5                   10                0.9709           min
#     RMSE_sparsity_<=0.75                   10                1.8210           min
#      MAE_sparsity_<=0.75                   10                1.6035           min
#     MAPE_sparsity_<=0.75                   10                0.9691           min
#                epochLoss                   10               12.7632           min
#
# Saved: /home/jovyan/STHSL/tests_validation/option1/NYC_3km/metrics_all_epochs_pivot_ranking_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/NYC_3km/metrics_all_epochs_pivot_ranking_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/NYC_3km/metrics_all_epochs_pivot_summary_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/NYC_3km/metrics_all_epochs_pivot_summary_overall_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/NYC_3km/metrics_all_epochs_pivot_ranking_best_seed_by_avg.csv

# %%
# !python train.py --data NYC_3km --use_ode_option option2 --device cuda --eval_metrics all --batch 16 --n_traj_samples 1 --ode_method dopri5 --odeint_atol 0.001 --odeint_rtol 0.001 --gen_layers 1 --gen_dim 64 --gcn_step 1 --horizon 12
# step_move_checkpoints("NYC_3km", "option2", on_conflict="overwrite")
# !python metrics_generation.py --data NYC_3km --use_ode_option option2 --device cuda --eval_metrics all --batch 16 --n_traj_samples 1 --ode_method dopri5 --odeint_atol 0.001 --odeint_rtol 0.001 --gen_layers 1 --gen_dim 64 --gcn_step 1 --horizon 12 --out-dir tests_validation/option2/NYC_3km --save-root Logs/option2
# step_metrics_extraction("NYC_3km", "option2")
# step_analyse("NYC_3km", "option2")

# %%
# !python train.py --data CHI_3km --use_ode_option baseline --device cuda --eval_metrics all --batch 16
step_move_checkpoints("CHI_3km", "baseline", on_conflict="overwrite")
# !python metrics_generation.py --data CHI_3km --use_ode_option baseline --device cuda --eval_metrics all --batch 16 --out-dir tests_validation/baseline/CHI_3km --save-root Logs/baseline
step_metrics_extraction("CHI_3km", "baseline")
step_analyse("CHI_3km", "baseline")
# Out:
# self.predir Datasets/common_data/CHI_crime_3km/
# (168, 153, 4)
# Row: 14 , Col: 12
# Sparsity: 0.25770436145207626
# use_ode_option: baseline
# ODE is not enabled, baseline STHSL model is initialized
# DEBUG SHAPES status: True
#
# ===== SEED 10 =====
# start training...
# ===== TRAINING ARGS =====
# lr: 0.001
# weight_decay: 0.0001
# cr: 0.8
# ir: 1
# t: 0.05
# batch: 16
# epoch: 1
# latdim: 16
# temporalRange: 30
# cateNum: 4
# data: CHI_3km
# kernelSize: 3
# border: 0.5
# hyperNum: 128
# dropRateL: 0.2
# dropRateG: 0.1
# use_ode_option: baseline
# n_traj_samples: 1
# ode_method: dopri5
# odeint_atol: 0.0001
# odeint_rtol: 0.001
# gen_layers: 1
# gen_dim: 64
# save_latent: false
# gcn_step: 2
# rnn_units: 64
# horizon: 12
# filter_type: 2
# device: cuda
# tstEpoch: 1
# save: ./Save/
# checkpoint: ./Save/NYC/
# eval_metrics: all
# f1_label_threshold: 0.0
# f1_pred_threshold: 0.5
# seeds: [10]
# row: 14
# col: 12
# offNum: 4
# areaNum: 168
# trnDays: 547
# valDays: 31
# tstDays: 153
# decay_step: 34
# ==========================
# Epoch  1 Training Time 3.239s
# Epoch 1/1, Train Loss =  13.7188,  preLoss =  7.4134
# Val (MicroF1+MacroF1) increase from -1.0000 to 1.0187
# Epoch 1/1, Test: MacroF1 = 0.4955, MicroF1 = 0.4957, AP = 0.6659, Acc = 0.4957, MacroF1_cate_0 = 0.4046, MicroF1_cate_0 = 0.4079, Acc_cate_0 = 0.4079, AP_cate_0 = 0.3483, MacroF1_cate_1 = 0.5303, MicroF1_cate_1 = 0.5305, Acc_cate_1 = 0.5305, AP_cate_1 = 0.7812, MacroF1_cate_2 = 0.4652, MicroF1_cate_2 = 0.4656, Acc_cate_2 = 0.4656, AP_cate_2 = 0.5455, MacroF1_cate_3 = 0.5787, MicroF1_cate_3 = 0.5787, Acc_cate_3 = 0.5787, AP_cate_3 = 0.7745, MacroF1_over_categories = 0.4947, MicroF1_over_categories = 0.4957, MacroAP_over_categories = 0.6124, MacroAcc_over_categories = 0.4957, MacroF1_mask_1 = 0.3531, MicroF1_mask_1 = 0.4136, Acc_mask_1 = 0.4136, AP_mask_1 = 0.0895, MacroF1_mask_2 = 0.4248, MicroF1_mask_2 = 0.4367, Acc_mask_2 = 0.4367, AP_mask_2 = 0.3775, MacroF1_mask_3 = 0.4832, MicroF1_mask_3 = 0.6030, Acc_mask_3 = 0.6030, AP_mask_3 = 0.6474, MacroF1_mask_4 = 0.4936, MicroF1_mask_4 = 0.8540, Acc_mask_4 = 0.8540, AP_mask_4 = 0.9265, MacroF1_cate_0_mask_1 = 0.3377, MicroF1_cate_0_mask_1 = 0.3940, Acc_cate_0_mask_1 = 0.3940, AP_cate_0_mask_1 = 0.0900, MacroF1_cate_0_mask_2 = 0.4058, MicroF1_cate_0_mask_2 = 0.4314, Acc_cate_0_mask_2 = 0.4314, AP_cate_0_mask_2 = 0.3854, MacroF1_cate_0_mask_3 = 0.4470, MicroF1_cate_0_mask_3 = 0.6137, Acc_cate_0_mask_3 = 0.6137, AP_cate_0_mask_3 = 0.6511, MacroF1_cate_0_mask_4 = 0.4571, MicroF1_cate_0_mask_4 = 0.7706, Acc_cate_0_mask_4 = 0.7706, AP_cate_0_mask_4 = 0.7973, MacroF1_cate_1_mask_1 = 0.3853, MicroF1_cate_1_mask_1 = 0.4568, Acc_cate_1_mask_1 = 0.4568, AP_cate_1_mask_1 = 0.1093, MacroF1_cate_1_mask_2 = 0.4557, MicroF1_cate_1_mask_2 = 0.4608, Acc_cate_1_mask_2 = 0.4608, AP_cate_1_mask_2 = 0.3925, MacroF1_cate_1_mask_3 = 0.4388, MicroF1_cate_1_mask_3 = 0.6531, Acc_cate_1_mask_3 = 0.6531, AP_cate_1_mask_3 = 0.6722, MacroF1_cate_1_mask_4 = 0.4987, MicroF1_cate_1_mask_4 = 0.8985, Acc_cate_1_mask_4 = 0.8985, AP_cate_1_mask_4 = 0.9466, MacroF1_cate_2_mask_1 = 0.3441, MicroF1_cate_2_mask_1 = 0.4013, Acc_cate_2_mask_1 = 0.4013, AP_cate_2_mask_1 = 0.0783, MacroF1_cate_2_mask_2 = 0.4070, MicroF1_cate_2_mask_2 = 0.4139, Acc_cate_2_mask_2 = 0.4139, AP_cate_2_mask_2 = 0.3651, MacroF1_cate_2_mask_3 = 0.4935, MicroF1_cate_2_mask_3 = 0.5639, Acc_cate_2_mask_3 = 0.5639, AP_cate_2_mask_3 = 0.6324, MacroF1_cate_2_mask_4 = 0.4764, MicroF1_cate_2_mask_4 = 0.7996, Acc_cate_2_mask_4 = 0.7996, AP_cate_2_mask_4 = 0.8426, MacroF1_cate_3_mask_1 = 0.3500, MicroF1_cate_3_mask_1 = 0.4082, Acc_cate_3_mask_1 = 0.4082, AP_cate_3_mask_1 = 0.0929, MacroF1_cate_3_mask_2 = 0.4345, MicroF1_cate_3_mask_2 = 0.4417, Acc_cate_3_mask_2 = 0.4417, AP_cate_3_mask_2 = 0.3660, MacroF1_cate_3_mask_3 = 0.5158, MicroF1_cate_3_mask_3 = 0.5915, Acc_cate_3_mask_3 = 0.5915, AP_cate_3_mask_3 = 0.6351, MacroF1_cate_3_mask_4 = 0.5100, MicroF1_cate_3_mask_4 = 0.8751, Acc_cate_3_mask_4 = 0.8751, AP_cate_3_mask_4 = 0.9506, RMSE = 1.9136, MAE = 1.3247, MAPE = 0.5189, RMSE_cate_0 = 1.2210, MAE_cate_0 = 0.8483, MAPE_cate_0 = 0.4503, RMSE_cate_1 = 1.9822, MAE_cate_1 = 1.4054, MAPE_cate_1 = 0.5278, RMSE_cate_2 = 1.6631, MAE_cate_2 = 1.1755, MAPE_cate_2 = 0.5279, RMSE_cate_3 = 2.3220, MAE_cate_3 = 1.6471, MAPE_cate_3 = 0.5439, RMSE_mask_1 = 0.7438, MAE_mask_1 = 0.5507, MAPE_mask_1 = 0.4693, RMSE_mask_2 = 0.9182, MAE_mask_2 = 0.6691, MAPE_mask_2 = 0.4536, RMSE_mask_3 = 1.3163, MAE_mask_3 = 0.9432, MAPE_mask_3 = 0.4898, RMSE_mask_4 = 2.2928, MAE_mask_4 = 1.6762, MAPE_mask_4 = 0.5481, epochLoss = 3.6358
# MacroF1=0.4955 MicroF1=0.4957 AP=0.6659
#
#   [RUNTIME] Epoch 1: train=3.24s | train+eval=3.96s
#
# ============================================================
# RUNTIME ANALYSIS SUMMARY (STHSL)
# ============================================================
#   Seed:                      10
#   Epochs run:                1
#   Avg train time/epoch:      3.24s (+/- 0.00s)
#   Avg total time/epoch:      3.96s (+/- 0.00s)
#   Per-epoch train times:     ['3.24']
#   Total training time:       3.96s
# ============================================================
#
# Epoch 1/1, Best: MacroF1 = 0.4955, MicroF1 = 0.4957, AP = 0.6659, Acc = 0.4957, MacroF1_cate_0 = 0.4046, MicroF1_cate_0 = 0.4079, Acc_cate_0 = 0.4079, AP_cate_0 = 0.3483, MacroF1_cate_1 = 0.5303, MicroF1_cate_1 = 0.5305, Acc_cate_1 = 0.5305, AP_cate_1 = 0.7812, MacroF1_cate_2 = 0.4652, MicroF1_cate_2 = 0.4656, Acc_cate_2 = 0.4656, AP_cate_2 = 0.5455, MacroF1_cate_3 = 0.5787, MicroF1_cate_3 = 0.5787, Acc_cate_3 = 0.5787, AP_cate_3 = 0.7745, MacroF1_over_categories = 0.4947, MicroF1_over_categories = 0.4957, MacroAP_over_categories = 0.6124, MacroAcc_over_categories = 0.4957, MacroF1_mask_1 = 0.3531, MicroF1_mask_1 = 0.4136, Acc_mask_1 = 0.4136, AP_mask_1 = 0.0895, MacroF1_mask_2 = 0.4248, MicroF1_mask_2 = 0.4367, Acc_mask_2 = 0.4367, AP_mask_2 = 0.3775, MacroF1_mask_3 = 0.4832, MicroF1_mask_3 = 0.6030, Acc_mask_3 = 0.6030, AP_mask_3 = 0.6474, MacroF1_mask_4 = 0.4936, MicroF1_mask_4 = 0.8540, Acc_mask_4 = 0.8540, AP_mask_4 = 0.9265, MacroF1_cate_0_mask_1 = 0.3377, MicroF1_cate_0_mask_1 = 0.3940, Acc_cate_0_mask_1 = 0.3940, AP_cate_0_mask_1 = 0.0900, MacroF1_cate_0_mask_2 = 0.4058, MicroF1_cate_0_mask_2 = 0.4314, Acc_cate_0_mask_2 = 0.4314, AP_cate_0_mask_2 = 0.3854, MacroF1_cate_0_mask_3 = 0.4470, MicroF1_cate_0_mask_3 = 0.6137, Acc_cate_0_mask_3 = 0.6137, AP_cate_0_mask_3 = 0.6511, MacroF1_cate_0_mask_4 = 0.4571, MicroF1_cate_0_mask_4 = 0.7706, Acc_cate_0_mask_4 = 0.7706, AP_cate_0_mask_4 = 0.7973, MacroF1_cate_1_mask_1 = 0.3853, MicroF1_cate_1_mask_1 = 0.4568, Acc_cate_1_mask_1 = 0.4568, AP_cate_1_mask_1 = 0.1093, MacroF1_cate_1_mask_2 = 0.4557, MicroF1_cate_1_mask_2 = 0.4608, Acc_cate_1_mask_2 = 0.4608, AP_cate_1_mask_2 = 0.3925, MacroF1_cate_1_mask_3 = 0.4388, MicroF1_cate_1_mask_3 = 0.6531, Acc_cate_1_mask_3 = 0.6531, AP_cate_1_mask_3 = 0.6722, MacroF1_cate_1_mask_4 = 0.4987, MicroF1_cate_1_mask_4 = 0.8985, Acc_cate_1_mask_4 = 0.8985, AP_cate_1_mask_4 = 0.9466, MacroF1_cate_2_mask_1 = 0.3441, MicroF1_cate_2_mask_1 = 0.4013, Acc_cate_2_mask_1 = 0.4013, AP_cate_2_mask_1 = 0.0783, MacroF1_cate_2_mask_2 = 0.4070, MicroF1_cate_2_mask_2 = 0.4139, Acc_cate_2_mask_2 = 0.4139, AP_cate_2_mask_2 = 0.3651, MacroF1_cate_2_mask_3 = 0.4935, MicroF1_cate_2_mask_3 = 0.5639, Acc_cate_2_mask_3 = 0.5639, AP_cate_2_mask_3 = 0.6324, MacroF1_cate_2_mask_4 = 0.4764, MicroF1_cate_2_mask_4 = 0.7996, Acc_cate_2_mask_4 = 0.7996, AP_cate_2_mask_4 = 0.8426, MacroF1_cate_3_mask_1 = 0.3500, MicroF1_cate_3_mask_1 = 0.4082, Acc_cate_3_mask_1 = 0.4082, AP_cate_3_mask_1 = 0.0929, MacroF1_cate_3_mask_2 = 0.4345, MicroF1_cate_3_mask_2 = 0.4417, Acc_cate_3_mask_2 = 0.4417, AP_cate_3_mask_2 = 0.3660, MacroF1_cate_3_mask_3 = 0.5158, MicroF1_cate_3_mask_3 = 0.5915, Acc_cate_3_mask_3 = 0.5915, AP_cate_3_mask_3 = 0.6351, MacroF1_cate_3_mask_4 = 0.5100, MicroF1_cate_3_mask_4 = 0.8751, Acc_cate_3_mask_4 = 0.8751, AP_cate_3_mask_4 = 0.9506, RMSE = 1.9136, MAE = 1.3247, MAPE = 0.5189, RMSE_cate_0 = 1.2210, MAE_cate_0 = 0.8483, MAPE_cate_0 = 0.4503, RMSE_cate_1 = 1.9822, MAE_cate_1 = 1.4054, MAPE_cate_1 = 0.5278, RMSE_cate_2 = 1.6631, MAE_cate_2 = 1.1755, MAPE_cate_2 = 0.5279, RMSE_cate_3 = 2.3220, MAE_cate_3 = 1.6471, MAPE_cate_3 = 0.5439, RMSE_mask_1 = 0.7438, MAE_mask_1 = 0.5507, MAPE_mask_1 = 0.4693, RMSE_mask_2 = 0.9182, MAE_mask_2 = 0.6691, MAPE_mask_2 = 0.4536, RMSE_mask_3 = 1.3163, MAE_mask_3 = 0.9432, MAPE_mask_3 = 0.4898, RMSE_mask_4 = 2.2928, MAE_mask_4 = 1.6762, MAPE_mask_4 = 0.5481, epochLoss = 3.6358
#
# ===== SUMMARY: best result per seed =====
# seed=10: {'MacroF1': 0.49551914296557886, 'MicroF1': 0.49567187986305633, 'AP': 0.6658578816241107, 'Acc': 0.49567187986305633, 'MacroF1_cate_0': 0.404641773096852, 'MicroF1_cate_0': 0.40787426081543726, 'Acc_cate_0': 0.40787426081543726, 'AP_cate_0': 0.3482952254684979, 'MacroF1_cate_1': 0.5303175889817262, 'MicroF1_cate_1': 0.5304621848739496, 'Acc_cate_1': 0.5304621848739496, 'AP_cate_1': 0.781218820009933, 'MacroF1_cate_2': 0.4652473015832781, 'MicroF1_cate_2': 0.4656084656084656, 'Acc_cate_2': 0.4656084656084656, 'AP_cate_2': 0.5454565640002413, 'MacroF1_cate_3': 0.5786764891945426, 'MicroF1_cate_3': 0.5787426081543728, 'Acc_cate_3': 0.5787426081543728, 'AP_cate_3': 0.7745321028316892, 'MacroF1_over_categories': 0.49472078821409976, 'MicroF1_over_categories': 0.4956718798630563, 'MacroAP_over_categories': 0.6123756780775904, 'MacroAcc_over_categories': 0.4956718798630563, 'MacroF1_mask_1': 0.35313326421855806, 'MicroF1_mask_1': 0.4136479450537277, 'Acc_mask_1': 0.4136479450537277, 'AP_mask_1': 0.08949610067592184, 'MacroF1_mask_2': 0.4248379426855212, 'MicroF1_mask_2': 0.43672988321011463, 'Acc_mask_2': 0.43672988321011463, 'AP_mask_2': 0.3775030397297463, 'MacroF1_mask_3': 0.4831959681030551, 'MicroF1_mask_3': 0.6030215364834458, 'Acc_mask_3': 0.6030215364834458, 'AP_mask_3': 0.6474352846742937, 'MacroF1_mask_4': 0.4936379625890679, 'MicroF1_mask_4': 0.8540126433086896, 'Acc_mask_4': 0.8540126433086896, 'AP_mask_4': 0.9265420202799393, 'MacroF1_cate_0_mask_1': 0.33766281487100247, 'MicroF1_cate_0_mask_1': 0.39397240377632536, 'Acc_cate_0_mask_1': 0.39397240377632536, 'AP_cate_0_mask_1': 0.09003524194873563, 'MacroF1_cate_0_mask_2': 0.405802103394965, 'MicroF1_cate_0_mask_2': 0.43137254901960786, 'Acc_cate_0_mask_2': 0.43137254901960786, 'AP_cate_0_mask_2': 0.38538296001060834, 'MacroF1_cate_0_mask_3': 0.44695162967039687, 'MicroF1_cate_0_mask_3': 0.6136528685548294, 'Acc_cate_0_mask_3': 0.6136528685548294, 'AP_cate_0_mask_3': 0.6510952373894299, 'MacroF1_cate_0_mask_4': 0.4571185511528871, 'MicroF1_cate_0_mask_4': 0.7706476530005941, 'Acc_cate_0_mask_4': 0.7706476530005941, 'AP_cate_0_mask_4': 0.7972572086538137, 'MacroF1_cate_1_mask_1': 0.3853258713162765, 'MicroF1_cate_1_mask_1': 0.4568160597572362, 'Acc_cate_1_mask_1': 0.4568160597572362, 'AP_cate_1_mask_1': 0.1093353646918295, 'MacroF1_cate_1_mask_2': 0.4557010900234637, 'MicroF1_cate_1_mask_2': 0.46078431372549017, 'Acc_cate_1_mask_2': 0.46078431372549017, 'AP_cate_1_mask_2': 0.3925406419746642, 'MacroF1_cate_1_mask_3': 0.43884318471754274, 'MicroF1_cate_1_mask_3': 0.6530920060331825, 'Acc_cate_1_mask_3': 0.6530920060331825, 'AP_cate_1_mask_3': 0.6722266532262722, 'MacroF1_cate_1_mask_4': 0.4986614840048112, 'MicroF1_cate_1_mask_4': 0.8985112563543937, 'Acc_cate_1_mask_4': 0.8985112563543937, 'AP_cate_1_mask_4': 0.9466198504356601, 'MacroF1_cate_2_mask_1': 0.34405942911060394, 'MicroF1_cate_2_mask_1': 0.4013071895424837, 'Acc_cate_2_mask_1': 0.4013071895424837, 'AP_cate_2_mask_1': 0.07834273199020424, 'MacroF1_cate_2_mask_2': 0.4070472300560796, 'MicroF1_cate_2_mask_2': 0.4139433551198257, 'Acc_cate_2_mask_2': 0.4139433551198257, 'AP_cate_2_mask_2': 0.365074636542813, 'MacroF1_cate_2_mask_3': 0.4934667853637492, 'MicroF1_cate_2_mask_3': 0.5639070442992011, 'Acc_cate_2_mask_3': 0.5639070442992011, 'AP_cate_2_mask_3': 0.6323857662652452, 'MacroF1_cate_2_mask_4': 0.47639538620862054, 'MicroF1_cate_2_mask_4': 0.7995642701525054, 'Acc_cate_2_mask_4': 0.7995642701525054, 'AP_cate_2_mask_4': 0.8426227897189312, 'MacroF1_cate_3_mask_1': 0.3500002403105366, 'MicroF1_cate_3_mask_1': 0.40822440087145967, 'Acc_cate_3_mask_1': 0.40822440087145967, 'AP_cate_3_mask_1': 0.09291258506722719, 'MacroF1_cate_3_mask_2': 0.43453322624349955, 'MicroF1_cate_3_mask_2': 0.4417211328976035, 'Acc_cate_3_mask_2': 0.4417211328976035, 'AP_cate_3_mask_2': 0.36599378618813916, 'MacroF1_cate_3_mask_3': 0.5157921387429585, 'MicroF1_cate_3_mask_3': 0.5915032679738562, 'Acc_cate_3_mask_3': 0.5915032679 ...
# Total time spent: 4.7074
# Detected seed folders under /home/jovyan/STHSL/Save/CHI_3km
#
# Checkpoint move completed (CHI_3km / baseline)
#   Mode     : seed-aware
#   Moved    : 1
#   Skipped  : 0
# Found 1 checkpoints under Logs/baseline/CHI_3km (seed folders) (sorted by seed, epoch).
#
# [seed 10 epoch 1] Running: /opt/conda/bin/python test.py --data CHI_3km --use_ode_option baseline --checkpoint Logs/baseline/CHI_3km/seed_10/_seed_10_epoch_1_MAE_1.32_MAPE_0.52_MicroF1_0.4957.pth --batch 16 --eval_metrics all
# [seed 10 epoch 1] Writing: tests_validation/baseline/CHI_3km/seed_10_epoch_1_main.txt
# [seed 10 epoch 1] OK
# \n$ python /home/jovyan/STHSL/metrics_extraction.py /home/jovyan/STHSL/tests_validation/baseline/CHI_3km --city chicago
#
# Reading folder: /home/jovyan/STHSL/tests_validation/baseline/CHI_3km
#
# City: chicago — using category map: {'0': 'ASSAULT', '1': 'BATTERY', '2': 'CRIMINAL DAMAGE', '3': 'THEFT'}
# Processing seed10_epoch1: seed_10_epoch_1_main.txt
#
# Created: /home/jovyan/STHSL/tests_validation/baseline/CHI_3km/metrics_all_epochs_pivot.csv
#
#                       seed10_epoch1  seed_avg_seed10  all_seeds_avg
# MacroF1                      0.4955           0.4955         0.4955
# MicroF1                      0.4957           0.4957         0.4957
# AP                           0.6659           0.6659         0.6659
# Acc                          0.4957           0.4957         0.4957
# MacroF1_ASSAULT              0.4046           0.4046         0.4046
# ...                             ...              ...            ...
# MAPE_sparsity_<=0.75         0.4898           0.4898         0.4898
# RMSE_sparsity_<=1.0          2.2928           2.2928         2.2928
# MAE_sparsity_<=1.0           1.6762           1.6762         1.6762
# MAPE_sparsity_<=1.0          0.5481           0.5481         0.5481
# epochLoss                   36.3581          36.3581        36.3581
#
# [67 rows x 3 columns]
#
# Running: python /home/jovyan/STHSL/analyse_metrics.py /home/jovyan/STHSL/tests_validation/baseline/CHI_3km/metrics_all_epochs_pivot.csv
#
# ==============================
# BEST (SEED, EPOCH) PER METRIC (across all seeds/epochs)
# ==============================
#
#                   Metric  BestSeed  BestEpoch  BestValue Goal(min/max)
#                  MacroF1        10          1     0.4955           max
#                  MicroF1        10          1     0.4957           max
#                       AP        10          1     0.6659           max
#                      Acc        10          1     0.4957           max
#          MacroF1_ASSAULT        10          1     0.4046           min
#          MicroF1_ASSAULT        10          1     0.4079           min
#              Acc_ASSAULT        10          1     0.4079           max
#               AP_ASSAULT        10          1     0.3483           max
#          MacroF1_BATTERY        10          1     0.5303           min
#          MicroF1_BATTERY        10          1     0.5305           min
#              Acc_BATTERY        10          1     0.5305           max
#               AP_BATTERY        10          1     0.7812           max
#  MacroF1_CRIMINAL DAMAGE        10          1     0.4652           min
#  MicroF1_CRIMINAL DAMAGE        10          1     0.4656           min
#      Acc_CRIMINAL DAMAGE        10          1     0.4656           max
#       AP_CRIMINAL DAMAGE        10          1     0.5455           max
#            MacroF1_THEFT        10          1     0.5787           min
#            MicroF1_THEFT        10          1     0.5787           min
#                Acc_THEFT        10          1     0.5787           max
#                 AP_THEFT        10          1     0.7745           max
#  MacroF1_over_categories        10          1     0.4947           max
#  MacroAP_over_categories        10          1     0.6124           max
# MacroAcc_over_categories        10          1     0.4957           max
#  MacroF1_sparsity_<=0.25        10          1     0.3531           min
#  MicroF1_sparsity_<=0.25        10          1     0.4136           min
#      Acc_sparsity_<=0.25        10          1     0.4136           max
#       AP_sparsity_<=0.25        10          1     0.0895           max
#   MacroF1_sparsity_<=0.5        10          1     0.4248           min
#   MicroF1_sparsity_<=0.5        10          1     0.4367           min
#       Acc_sparsity_<=0.5        10          1     0.4367           max
#        AP_sparsity_<=0.5        10          1     0.3775           max
#  MacroF1_sparsity_<=0.75        10          1     0.4832           min
#  MicroF1_sparsity_<=0.75        10          1     0.6030           min
#      Acc_sparsity_<=0.75        10          1     0.6030           max
#       AP_sparsity_<=0.75        10          1     0.6474           max
#   MacroF1_sparsity_<=1.0        10          1     0.4936           min
#   MicroF1_sparsity_<=1.0        10          1     0.8540           min
#       Acc_sparsity_<=1.0        10          1     0.8540           max
#        AP_sparsity_<=1.0        10          1     0.9265           max
#                     RMSE        10          1     1.9136           min
#                      MAE        10          1     1.3247           min
#                     MAPE        10          1     0.5189           min
#             RMSE_ASSAULT        10          1     1.2210           min
#              MAE_ASSAULT        10          1     0.8483           min
#             MAPE_ASSAULT        10          1     0.4503           min
#             RMSE_BATTERY        10          1     1.9822           min
#              MAE_BATTERY        10          1     1.4054           min
#             MAPE_BATTERY        10          1     0.5278           min
#     RMSE_CRIMINAL DAMAGE        10          1     1.6631           min
#      MAE_CRIMINAL DAMAGE        10          1     1.1755           min
#     MAPE_CRIMINAL DAMAGE        10          1     0.5279           min
#               RMSE_THEFT        10          1     2.3220           min
#                MAE_THEFT        10          1     1.6471           min
#               MAPE_THEFT        10          1     0.5439           min
#     RMSE_sparsity_<=0.25        10          1     0.7438           min
#      MAE_sparsity_<=0.25        10          1     0.5507           min
#     MAPE_sparsity_<=0.25        10          1     0.4693           min
#      RMSE_sparsity_<=0.5        10          1     0.9182           min
#       MAE_sparsity_<=0.5        10          1     0.6691           min
#      MAPE_sparsity_<=0.5        10          1     0.4536           min
#     RMSE_sparsity_<=0.75        10          1     1.3163           min
#      MAE_sparsity_<=0.75        10          1     0.9432           min
#     MAPE_sparsity_<=0.75        10          1     0.4898           min
#      RMSE_sparsity_<=1.0        10          1     2.2928           min
#       MAE_sparsity_<=1.0        10          1     1.6762           min
#      MAPE_sparsity_<=1.0        10          1     0.5481           min
#                epochLoss        10          1    36.3581           min
#
# ==============================
# OVERALL BEST (SEED, EPOCH) BY 'MOST METRICS WON'
# ==============================
# Best (seed, epoch) overall: seed=10 epoch=1 (wins 67 metrics)
#
#
# ==============================
# OVERALL BEST EPOCH WITHIN EACH SEED (wins across metrics)
# ==============================
#
#  Seed  OverallBestEpochWithinSeed  WinsCount
#    10                           1         67
#
# ==============================
# BEST SEED BY AVERAGE-OVER-EPOCHS (per metric)
# ==============================
#
#                   Metric  BestSeedByAvgEpochs  BestValueByAvgEpochs Goal(min/max)
#                  MacroF1                   10                0.4955           max
#                  MicroF1                   10                0.4957           max
#                       AP                   10                0.6659           max
#                      Acc                   10                0.4957           max
#          MacroF1_ASSAULT                   10                0.4046           min
#          MicroF1_ASSAULT                   10                0.4079           min
#              Acc_ASSAULT                   10                0.4079           max
#               AP_ASSAULT                   10                0.3483           max
#          MacroF1_BATTERY                   10                0.5303           min
#          MicroF1_BATTERY                   10                0.5305           min
#              Acc_BATTERY                   10                0.5305           max
#               AP_BATTERY                   10                0.7812           max
#  MacroF1_CRIMINAL DAMAGE                   10                0.4652           min
#  MicroF1_CRIMINAL DAMAGE                   10                0.4656           min
#      Acc_CRIMINAL DAMAGE                   10                0.4656           max
#       AP_CRIMINAL DAMAGE                   10                0.5455           max
#            MacroF1_THEFT                   10                0.5787           min
#            MicroF1_THEFT                   10                0.5787           min
#                Acc_THEFT                   10                0.5787           max
#                 AP_THEFT                   10                0.7745           max
#  MacroF1_over_categories                   10                0.4947           max
#  MacroAP_over_categories                   10                0.6124           max
# MacroAcc_over_categories                   10                0.4957           max
#  MacroF1_sparsity_<=0.25                   10                0.3531           min
#  MicroF1_sparsity_<=0.25                   10                0.4136           min
#      Acc_sparsity_<=0.25                   10                0.4136           max
#       AP_sparsity_<=0.25                   10                0.0895           max
#   MacroF1_sparsity_<=0.5                   10                0.4248           min
#   MicroF1_sparsity_<=0.5                   10                0.4367           min
#       Acc_sparsity_<=0.5                   10                0.4367           max
#        AP_sparsity_<=0.5                   10                0.3775           max
#  MacroF1_sparsity_<=0.75                   10                0.4832           min
#  MicroF1_sparsity_<=0.75                   10                0.6030           min
#      Acc_sparsity_<=0.75                   10                0.6030           max
#       AP_sparsity_<=0.75                   10                0.6474           max
#   MacroF1_sparsity_<=1.0                   10                0.4936           min
#   MicroF1_sparsity_<=1.0                   10                0.8540           min
#       Acc_sparsity_<=1.0                   10                0.8540           max
#        AP_sparsity_<=1.0                   10                0.9265           max
#                     RMSE                   10                1.9136           min
#                      MAE                   10                1.3247           min
#                     MAPE                   10                0.5189           min
#             RMSE_ASSAULT                   10                1.2210           min
#              MAE_ASSAULT                   10                0.8483           min
#             MAPE_ASSAULT                   10                0.4503           min
#             RMSE_BATTERY                   10                1.9822           min
#              MAE_BATTERY                   10                1.4054           min
#             MAPE_BATTERY                   10                0.5278           min
#     RMSE_CRIMINAL DAMAGE                   10                1.6631           min
#      MAE_CRIMINAL DAMAGE                   10                1.1755           min
#     MAPE_CRIMINAL DAMAGE                   10                0.5279           min
#               RMSE_THEFT                   10                2.3220           min
#                MAE_THEFT                   10                1.6471           min
#               MAPE_THEFT                   10                0.5439           min
#     RMSE_sparsity_<=0.25                   10                0.7438           min
#      MAE_sparsity_<=0.25                   10                0.5507           min
#     MAPE_sparsity_<=0.25                   10                0.4693           min
#      RMSE_sparsity_<=0.5                   10                0.9182           min
#       MAE_sparsity_<=0.5                   10                0.6691           min
#      MAPE_sparsity_<=0.5                   10                0.4536           min
#     RMSE_sparsity_<=0.75                   10                1.3163           min
#      MAE_sparsity_<=0.75                   10                0.9432           min
#     MAPE_sparsity_<=0.75                   10                0.4898           min
#      RMSE_sparsity_<=1.0                   10                2.2928           min
#       MAE_sparsity_<=1.0                   10                1.6762           min
#      MAPE_sparsity_<=1.0                   10                0.5481           min
#                epochLoss                   10               36.3581           min
#
# Saved: /home/jovyan/STHSL/tests_validation/baseline/CHI_3km/metrics_all_epochs_pivot_ranking_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/CHI_3km/metrics_all_epochs_pivot_ranking_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/CHI_3km/metrics_all_epochs_pivot_summary_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/CHI_3km/metrics_all_epochs_pivot_summary_overall_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/CHI_3km/metrics_all_epochs_pivot_ranking_best_seed_by_avg.csv

# %%
# !python train.py --data CHI_3km --use_ode_option option1 --device cuda --eval_metrics all --batch 16 --n_traj_samples 2 --ode_method dopri5 --odeint_atol 0.01 --odeint_rtol 0.0001 --gen_layers 2 --gen_dim 64 --gcn_step 2 --horizon 12
step_move_checkpoints("CHI_3km", "option1", on_conflict="overwrite")
# !python metrics_generation.py --data CHI_3km --use_ode_option option1 --device cuda --eval_metrics all --batch 16 --n_traj_samples 2 --ode_method dopri5 --odeint_atol 0.01 --odeint_rtol 0.0001 --gen_layers 2 --gen_dim 64 --gcn_step 2 --horizon 12 --out-dir tests_validation/option1/CHI_3km --save-root Logs/option1/
step_metrics_extraction("CHI_3km", "option1")
step_analyse("CHI_3km", "option1")
# Out:
# self.predir Datasets/common_data/CHI_crime_3km/
# (168, 153, 4)
# Row: 14 , Col: 12
# Sparsity: 0.25770436145207626
# use_ode_option: option1
# ODE option 1 is enabled, STHSL model with option1 components is initialized
# ODE setting --latent 16 --samples 2 --method dopri5                 --atol 0.010000 --rtol 0.000100 --gen_layer 2 --gen_dim 64 --num_nodes 168
# DEBUG SHAPES status: True
#
# ===== SEED 10 =====
# start training...
# ===== TRAINING ARGS =====
# lr: 0.001
# weight_decay: 0.0001
# cr: 0.8
# ir: 1
# t: 0.05
# batch: 16
# epoch: 1
# latdim: 16
# temporalRange: 30
# cateNum: 4
# data: CHI_3km
# kernelSize: 3
# border: 0.5
# hyperNum: 128
# dropRateL: 0.2
# dropRateG: 0.1
# use_ode_option: option1
# n_traj_samples: 2
# ode_method: dopri5
# odeint_atol: 0.01
# odeint_rtol: 0.0001
# gen_layers: 2
# gen_dim: 64
# save_latent: false
# gcn_step: 2
# rnn_units: 64
# horizon: 12
# filter_type: 2
# device: cuda
# tstEpoch: 1
# save: ./Save/
# checkpoint: ./Save/NYC/
# eval_metrics: all
# f1_label_threshold: 0.0
# f1_pred_threshold: 0.5
# seeds: [10]
# row: 14
# col: 12
# offNum: 4
# areaNum: 168
# trnDays: 547
# valDays: 31
# tstDays: 153
# decay_step: 34
# ==========================
# time grid: torch.Size([12])
# n_traj_samples: 2
# Decoder input Z_t shape: torch.Size([16, 672, 64])
# Labels shape: torch.Size([16, 168, 4])
# Epoch  1 Training Time 8.181s
# Epoch 1/1, Train Loss =  8.5010,  preLoss =  7.0214
# Val (MicroF1+MacroF1) increase from -1.0000 to 1.6886
# Epoch 1/1, Test: MacroF1 = 0.8295, MicroF1 = 0.8562, AP = 0.8316, Acc = 0.8562, MacroF1_cate_0 = 0.7468, MicroF1_cate_0 = 0.8127, Acc_cate_0 = 0.8127, AP_cate_0 = 0.5798, MacroF1_cate_1 = 0.8667, MicroF1_cate_1 = 0.8855, Acc_cate_1 = 0.8855, AP_cate_1 = 0.8839, MacroF1_cate_2 = 0.8256, MicroF1_cate_2 = 0.8539, Acc_cate_2 = 0.8539, AP_cate_2 = 0.7702, MacroF1_cate_3 = 0.8605, MicroF1_cate_3 = 0.8727, Acc_cate_3 = 0.8727, AP_cate_3 = 0.8963, MacroF1_over_categories = 0.8249, MicroF1_over_categories = 0.8562, MacroAP_over_categories = 0.7826, MacroAcc_over_categories = 0.8562, MacroF1_mask_1 = 0.5124, MicroF1_mask_1 = 0.8415, Acc_mask_1 = 0.8415, AP_mask_1 = 0.1016, MacroF1_mask_2 = 0.5214, MicroF1_mask_2 = 0.5303, Acc_mask_2 = 0.5303, AP_mask_2 = 0.4022, MacroF1_mask_3 = 0.4749, MicroF1_mask_3 = 0.6153, Acc_mask_3 = 0.6153, AP_mask_3 = 0.6632, MacroF1_mask_4 = 0.4706, MicroF1_mask_4 = 0.8769, Acc_mask_4 = 0.8769, AP_mask_4 = 0.9377, MacroF1_cate_0_mask_1 = 0.5047, MicroF1_cate_0_mask_1 = 0.8186, Acc_cate_0_mask_1 = 0.8186, AP_cate_0_mask_1 = 0.1057, MacroF1_cate_0_mask_2 = 0.5047, MicroF1_cate_0_mask_2 = 0.5047, Acc_cate_0_mask_2 = 0.5047, AP_cate_0_mask_2 = 0.4086, MacroF1_cate_0_mask_3 = 0.4777, MicroF1_cate_0_mask_3 = 0.6235, Acc_cate_0_mask_3 = 0.6235, AP_cate_0_mask_3 = 0.6543, MacroF1_cate_0_mask_4 = 0.4514, MicroF1_cate_0_mask_4 = 0.8033, Acc_cate_0_mask_4 = 0.8033, AP_cate_0_mask_4 = 0.8106, MacroF1_cate_1_mask_1 = 0.5279, MicroF1_cate_1_mask_1 = 0.8866, Acc_cate_1_mask_1 = 0.8866, AP_cate_1_mask_1 = 0.1072, MacroF1_cate_1_mask_2 = 0.5174, MicroF1_cate_1_mask_2 = 0.5542, Acc_cate_1_mask_2 = 0.5542, AP_cate_1_mask_2 = 0.4091, MacroF1_cate_1_mask_3 = 0.4544, MicroF1_cate_1_mask_3 = 0.6425, Acc_cate_1_mask_3 = 0.6425, AP_cate_1_mask_3 = 0.6978, MacroF1_cate_1_mask_4 = 0.4781, MicroF1_cate_1_mask_4 = 0.9087, Acc_cate_1_mask_4 = 0.9087, AP_cate_1_mask_4 = 0.9585, MacroF1_cate_2_mask_1 = 0.5128, MicroF1_cate_2_mask_1 = 0.8606, Acc_cate_2_mask_1 = 0.8606, AP_cate_2_mask_1 = 0.1000, MacroF1_cate_2_mask_2 = 0.5029, MicroF1_cate_2_mask_2 = 0.5044, Acc_cate_2_mask_2 = 0.5044, AP_cate_2_mask_2 = 0.4162, MacroF1_cate_2_mask_3 = 0.4674, MicroF1_cate_2_mask_3 = 0.6140, Acc_cate_2_mask_3 = 0.6140, AP_cate_2_mask_3 = 0.6500, MacroF1_cate_2_mask_4 = 0.4519, MicroF1_cate_2_mask_4 = 0.8246, Acc_cate_2_mask_4 = 0.8246, AP_cate_2_mask_4 = 0.8525, MacroF1_cate_3_mask_1 = 0.5031, MicroF1_cate_3_mask_1 = 0.7993, Acc_cate_3_mask_1 = 0.7993, AP_cate_3_mask_1 = 0.1000, MacroF1_cate_3_mask_2 = 0.5298, MicroF1_cate_3_mask_2 = 0.5773, Acc_cate_3_mask_2 = 0.5773, AP_cate_3_mask_2 = 0.3803, MacroF1_cate_3_mask_3 = 0.4883, MicroF1_cate_3_mask_3 = 0.5757, Acc_cate_3_mask_3 = 0.5757, AP_cate_3_mask_3 = 0.6484, MacroF1_cate_3_mask_4 = 0.4823, MicroF1_cate_3_mask_4 = 0.9043, Acc_cate_3_mask_4 = 0.9043, AP_cate_3_mask_4 = 0.9582, RMSE = 1.7156, MAE = 1.2318, MAPE = 0.5992, RMSE_cate_0 = 1.1380, MAE_cate_0 = 0.8417, MAPE_cate_0 = 0.5061, RMSE_cate_1 = 1.7874, MAE_cate_1 = 1.3506, MAPE_cate_1 = 0.6702, RMSE_cate_2 = 1.4312, MAE_cate_2 = 1.0360, MAPE_cate_2 = 0.5405, RMSE_cate_3 = 2.0931, MAE_cate_3 = 1.5059, MAPE_cate_3 = 0.6352, RMSE_mask_1 = 0.9969, MAE_mask_1 = 0.8652, MAPE_mask_1 = 0.7685, RMSE_mask_2 = 1.0102, MAE_mask_2 = 0.7848, MAPE_mask_2 = 0.5581, RMSE_mask_3 = 1.2251, MAE_mask_3 = 0.8799, MAPE_mask_3 = 0.4802, RMSE_mask_4 = 2.0152, MAE_mask_4 = 1.4895, MAPE_mask_4 = 0.6349, epochLoss = 2.9244
# MacroF1=0.8295 MicroF1=0.8562 AP=0.8316
#
#   [RUNTIME] Epoch 1: train=8.18s | train+eval=9.70s
#
# ============================================================
# RUNTIME ANALYSIS SUMMARY (STHSL)
# ============================================================
#   Seed:                      10
#   Epochs run:                1
#   Avg train time/epoch:      8.18s (+/- 0.00s)
#   Avg total time/epoch:      9.70s (+/- 0.00s)
#   Per-epoch train times:     ['8.18']
#   Total training time:       9.70s
# ============================================================
#
# Epoch 1/1, Best: MacroF1 = 0.8295, MicroF1 = 0.8562, AP = 0.8316, Acc = 0.8562, MacroF1_cate_0 = 0.7468, MicroF1_cate_0 = 0.8127, Acc_cate_0 = 0.8127, AP_cate_0 = 0.5798, MacroF1_cate_1 = 0.8667, MicroF1_cate_1 = 0.8855, Acc_cate_1 = 0.8855, AP_cate_1 = 0.8839, MacroF1_cate_2 = 0.8256, MicroF1_cate_2 = 0.8539, Acc_cate_2 = 0.8539, AP_cate_2 = 0.7702, MacroF1_cate_3 = 0.8605, MicroF1_cate_3 = 0.8727, Acc_cate_3 = 0.8727, AP_cate_3 = 0.8963, MacroF1_over_categories = 0.8249, MicroF1_over_categories = 0.8562, MacroAP_over_categories = 0.7826, MacroAcc_over_categories = 0.8562, MacroF1_mask_1 = 0.5124, MicroF1_mask_1 = 0.8415, Acc_mask_1 = 0.8415, AP_mask_1 = 0.1016, MacroF1_mask_2 = 0.5214, MicroF1_mask_2 = 0.5303, Acc_mask_2 = 0.5303, AP_mask_2 = 0.4022, MacroF1_mask_3 = 0.4749, MicroF1_mask_3 = 0.6153, Acc_mask_3 = 0.6153, AP_mask_3 = 0.6632, MacroF1_mask_4 = 0.4706, MicroF1_mask_4 = 0.8769, Acc_mask_4 = 0.8769, AP_mask_4 = 0.9377, MacroF1_cate_0_mask_1 = 0.5047, MicroF1_cate_0_mask_1 = 0.8186, Acc_cate_0_mask_1 = 0.8186, AP_cate_0_mask_1 = 0.1057, MacroF1_cate_0_mask_2 = 0.5047, MicroF1_cate_0_mask_2 = 0.5047, Acc_cate_0_mask_2 = 0.5047, AP_cate_0_mask_2 = 0.4086, MacroF1_cate_0_mask_3 = 0.4777, MicroF1_cate_0_mask_3 = 0.6235, Acc_cate_0_mask_3 = 0.6235, AP_cate_0_mask_3 = 0.6543, MacroF1_cate_0_mask_4 = 0.4514, MicroF1_cate_0_mask_4 = 0.8033, Acc_cate_0_mask_4 = 0.8033, AP_cate_0_mask_4 = 0.8106, MacroF1_cate_1_mask_1 = 0.5279, MicroF1_cate_1_mask_1 = 0.8866, Acc_cate_1_mask_1 = 0.8866, AP_cate_1_mask_1 = 0.1072, MacroF1_cate_1_mask_2 = 0.5174, MicroF1_cate_1_mask_2 = 0.5542, Acc_cate_1_mask_2 = 0.5542, AP_cate_1_mask_2 = 0.4091, MacroF1_cate_1_mask_3 = 0.4544, MicroF1_cate_1_mask_3 = 0.6425, Acc_cate_1_mask_3 = 0.6425, AP_cate_1_mask_3 = 0.6978, MacroF1_cate_1_mask_4 = 0.4781, MicroF1_cate_1_mask_4 = 0.9087, Acc_cate_1_mask_4 = 0.9087, AP_cate_1_mask_4 = 0.9585, MacroF1_cate_2_mask_1 = 0.5128, MicroF1_cate_2_mask_1 = 0.8606, Acc_cate_2_mask_1 = 0.8606, AP_cate_2_mask_1 = 0.1000, MacroF1_cate_2_mask_2 = 0.5029, MicroF1_cate_2_mask_2 = 0.5044, Acc_cate_2_mask_2 = 0.5044, AP_cate_2_mask_2 = 0.4162, MacroF1_cate_2_mask_3 = 0.4674, MicroF1_cate_2_mask_3 = 0.6140, Acc_cate_2_mask_3 = 0.6140, AP_cate_2_mask_3 = 0.6500, MacroF1_cate_2_mask_4 = 0.4519, MicroF1_cate_2_mask_4 = 0.8246, Acc_cate_2_mask_4 = 0.8246, AP_cate_2_mask_4 = 0.8525, MacroF1_cate_3_mask_1 = 0.5031, MicroF1_cate_3_mask_1 = 0.7993, Acc_cate_3_mask_1 = 0.7993, AP_cate_3_mask_1 = 0.1000, MacroF1_cate_3_mask_2 = 0.5298, MicroF1_cate_3_mask_2 = 0.5773, Acc_cate_3_mask_2 = 0.5773, AP_cate_3_mask_2 = 0.3803, MacroF1_cate_3_mask_3 = 0.4883, MicroF1_cate_3_mask_3 = 0.5757, Acc_cate_3_mask_3 = 0.5757, AP_cate_3_mask_3 = 0.6484, MacroF1_cate_3_mask_4 = 0.4823, MicroF1_cate_3_mask_4 = 0.9043, Acc_cate_3_mask_4 = 0.9043, AP_cate_3_mask_4 = 0.9582, RMSE = 1.7156, MAE = 1.2318, MAPE = 0.5992, RMSE_cate_0 = 1.1380, MAE_cate_0 = 0.8417, MAPE_cate_0 = 0.5061, RMSE_cate_1 = 1.7874, MAE_cate_1 = 1.3506, MAPE_cate_1 = 0.6702, RMSE_cate_2 = 1.4312, MAE_cate_2 = 1.0360, MAPE_cate_2 = 0.5405, RMSE_cate_3 = 2.0931, MAE_cate_3 = 1.5059, MAPE_cate_3 = 0.6352, RMSE_mask_1 = 0.9969, MAE_mask_1 = 0.8652, MAPE_mask_1 = 0.7685, RMSE_mask_2 = 1.0102, MAE_mask_2 = 0.7848, MAPE_mask_2 = 0.5581, RMSE_mask_3 = 1.2251, MAE_mask_3 = 0.8799, MAPE_mask_3 = 0.4802, RMSE_mask_4 = 2.0152, MAE_mask_4 = 1.4895, MAPE_mask_4 = 0.6349, epochLoss = 2.9244
#
# ===== SUMMARY: best result per seed =====
# seed=10: {'MacroF1': 0.8294773019130985, 'MicroF1': 0.8561994242141301, 'AP': 0.831637607342195, 'Acc': 0.8561994242141301, 'MacroF1_cate_0': 0.7468363757828942, 'MicroF1_cate_0': 0.8127139744786803, 'Acc_cate_0': 0.8127139744786803, 'AP_cate_0': 0.5797920032411252, 'MacroF1_cate_1': 0.8667323118943007, 'MicroF1_cate_1': 0.8855042016806722, 'Acc_cate_1': 0.8855042016806722, 'AP_cate_1': 0.8839370373743252, 'MacroF1_cate_2': 0.8256371712716378, 'MicroF1_cate_2': 0.853874883286648, 'Acc_cate_2': 0.853874883286648, 'AP_cate_2': 0.7702013254643476, 'MacroF1_cate_3': 0.8605170335869612, 'MicroF1_cate_3': 0.8727046374105197, 'Acc_cate_3': 0.8727046374105197, 'AP_cate_3': 0.8963310194582256, 'MacroF1_over_categories': 0.8249307231339484, 'MicroF1_over_categories': 0.8561994242141301, 'MacroAP_over_categories': 0.7825653463845059, 'MacroAcc_over_categories': 0.8561994242141301, 'MacroF1_mask_1': 0.5123519644806487, 'MicroF1_mask_1': 0.8414755732801595, 'Acc_mask_1': 0.8414755732801595, 'AP_mask_1': 0.10162884556878977, 'MacroF1_mask_2': 0.5214211604279516, 'MicroF1_mask_2': 0.5302689381763634, 'Acc_mask_2': 0.5302689381763634, 'AP_mask_2': 0.4021889801397074, 'MacroF1_mask_3': 0.47487671804825204, 'MicroF1_mask_3': 0.6153434051216115, 'Acc_mask_3': 0.6153434051216115, 'AP_mask_3': 0.6632192937873627, 'MacroF1_mask_4': 0.47064552009873867, 'MicroF1_mask_4': 0.8768884603021536, 'Acc_mask_4': 0.8768884603021536, 'AP_mask_4': 0.9376738108925174, 'MacroF1_cate_0_mask_1': 0.5047190152800595, 'MicroF1_cate_0_mask_1': 0.8186274509803921, 'Acc_cate_0_mask_1': 0.8186274509803921, 'AP_cate_0_mask_1': 0.10570912702711217, 'MacroF1_cate_0_mask_2': 0.5046873921180297, 'MicroF1_cate_0_mask_2': 0.5046888320545609, 'Acc_cate_0_mask_2': 0.5046888320545609, 'AP_cate_0_mask_2': 0.40864459620409677, 'MacroF1_cate_0_mask_3': 0.47765839943769456, 'MicroF1_cate_0_mask_3': 0.6234567901234568, 'Acc_cate_0_mask_3': 0.6234567901234568, 'AP_cate_0_mask_3': 0.6542662839281115, 'MacroF1_cate_0_mask_4': 0.4513677078152622, 'MicroF1_cate_0_mask_4': 0.8033273915626857, 'Acc_cate_0_mask_4': 0.8033273915626857, 'AP_cate_0_mask_4': 0.8105707684408341, 'MacroF1_cate_1_mask_1': 0.5278750085035941, 'MicroF1_cate_1_mask_1': 0.8865546218487395, 'Acc_cate_1_mask_1': 0.8865546218487395, 'AP_cate_1_mask_1': 0.10717092721838171, 'MacroF1_cate_1_mask_2': 0.5174176781949396, 'MicroF1_cate_1_mask_2': 0.554154995331466, 'Acc_cate_1_mask_2': 0.554154995331466, 'AP_cate_1_mask_2': 0.409117849515635, 'MacroF1_cate_1_mask_3': 0.45438456852259174, 'MicroF1_cate_1_mask_3': 0.6425339366515838, 'Acc_cate_1_mask_3': 0.6425339366515838, 'AP_cate_1_mask_3': 0.6977811798046902, 'MacroF1_cate_1_mask_4': 0.47805288377757954, 'MicroF1_cate_1_mask_4': 0.9086782861292665, 'Acc_cate_1_mask_4': 0.9086782861292665, 'AP_cate_1_mask_4': 0.9584616483349332, 'MacroF1_cate_2_mask_1': 0.5127724732369847, 'MicroF1_cate_2_mask_1': 0.8605664488017429, 'Acc_cate_2_mask_1': 0.8605664488017429, 'AP_cate_2_mask_1': 0.09995122465442532, 'MacroF1_cate_2_mask_2': 0.5028825646494268, 'MicroF1_cate_2_mask_2': 0.5043572984749455, 'Acc_cate_2_mask_2': 0.5043572984749455, 'AP_cate_2_mask_2': 0.4162052504563182, 'MacroF1_cate_2_mask_3': 0.4673871020620247, 'MicroF1_cate_2_mask_3': 0.6140159767610748, 'Acc_cate_2_mask_3': 0.6140159767610748, 'AP_cate_2_mask_3': 0.6499624956427501, 'MacroF1_cate_2_mask_4': 0.4519402985074627, 'MicroF1_cate_2_mask_4': 0.8246187363834423, 'Acc_cate_2_mask_4': 0.8246187363834423, 'AP_cate_2_mask_4': 0.8525084374881009, 'MacroF1_cate_3_mask_1': 0.5031058363945528, 'MicroF1_cate_3_mask_1': 0.7992919389978214, 'Acc_cate_3_mask_1': 0.7992919389978214, 'AP_cate_3_mask_1': 0.09995502163551771, 'MacroF1_cate_3_mask_2': 0.5297652681329708, 'MicroF1_cate_3_mask_2': 0.5773420479302832, 'Acc_cate_3_mask_2': 0.5773420479302832, 'AP_cate_3_mask_2': 0.3803428414072546, 'MacroF1_cate_3_mask_3': 0.48825092179625484, 'MicroF1_cate_3_mask_3': 0.5757080610021786, 'Acc_cate_3_mask_3': 0.5757080610021786, 'AP_cate_3_ ...
# Total time spent: 10.6694
# Detected seed folders under /home/jovyan/STHSL/Save/CHI_3km
#
# Checkpoint move completed (CHI_3km / option1)
#   Mode     : seed-aware
#   Moved    : 1
#   Skipped  : 0
# Found 1 checkpoints under Logs/option1/CHI_3km (seed folders) (sorted by seed, epoch).
#
# [seed 10 epoch 1] Running: /opt/conda/bin/python test.py --data CHI_3km --use_ode_option option1 --checkpoint Logs/option1/CHI_3km/seed_10/_seed_10_epoch_1_MAE_1.23_MAPE_0.6_MicroF1_0.8562.pth --batch 16 --eval_metrics all --n_traj_samples 2 --ode_method dopri5 --odeint_atol 0.01 --odeint_rtol 0.0001 --gen_layers 2 --gen_dim 64 --gcn_step 2 --rnn_units 64 --horizon 12 --filter_type 2
# [seed 10 epoch 1] Writing: tests_validation/option1/CHI_3km/seed_10_epoch_1_main.txt
# [seed 10 epoch 1] OK
# \n$ python /home/jovyan/STHSL/metrics_extraction.py /home/jovyan/STHSL/tests_validation/option1/CHI_3km --city chicago
#
# Reading folder: /home/jovyan/STHSL/tests_validation/option1/CHI_3km
#
# City: chicago — using category map: {'0': 'ASSAULT', '1': 'BATTERY', '2': 'CRIMINAL DAMAGE', '3': 'THEFT'}
# Processing seed10_epoch1: seed_10_epoch_1_main.txt
#
# Created: /home/jovyan/STHSL/tests_validation/option1/CHI_3km/metrics_all_epochs_pivot.csv
#
#                       seed10_epoch1  seed_avg_seed10  all_seeds_avg
# MacroF1                      0.8295           0.8295         0.8295
# MicroF1                      0.8562           0.8562         0.8562
# AP                           0.8316           0.8316         0.8316
# Acc                          0.8562           0.8562         0.8562
# MacroF1_ASSAULT              0.7468           0.7468         0.7468
# ...                             ...              ...            ...
# MAPE_sparsity_<=0.75         0.4802           0.4802         0.4802
# RMSE_sparsity_<=1.0          2.0152           2.0152         2.0152
# MAE_sparsity_<=1.0           1.4895           1.4895         1.4895
# MAPE_sparsity_<=1.0          0.6349           0.6349         0.6349
# epochLoss                   29.2444          29.2444        29.2444
#
# [67 rows x 3 columns]
#
# Running: python /home/jovyan/STHSL/analyse_metrics.py /home/jovyan/STHSL/tests_validation/option1/CHI_3km/metrics_all_epochs_pivot.csv
#
# ==============================
# BEST (SEED, EPOCH) PER METRIC (across all seeds/epochs)
# ==============================
#
#                   Metric  BestSeed  BestEpoch  BestValue Goal(min/max)
#                  MacroF1        10          1     0.8295           max
#                  MicroF1        10          1     0.8562           max
#                       AP        10          1     0.8316           max
#                      Acc        10          1     0.8562           max
#          MacroF1_ASSAULT        10          1     0.7468           min
#          MicroF1_ASSAULT        10          1     0.8127           min
#              Acc_ASSAULT        10          1     0.8127           max
#               AP_ASSAULT        10          1     0.5798           max
#          MacroF1_BATTERY        10          1     0.8667           min
#          MicroF1_BATTERY        10          1     0.8855           min
#              Acc_BATTERY        10          1     0.8855           max
#               AP_BATTERY        10          1     0.8839           max
#  MacroF1_CRIMINAL DAMAGE        10          1     0.8256           min
#  MicroF1_CRIMINAL DAMAGE        10          1     0.8539           min
#      Acc_CRIMINAL DAMAGE        10          1     0.8539           max
#       AP_CRIMINAL DAMAGE        10          1     0.7702           max
#            MacroF1_THEFT        10          1     0.8605           min
#            MicroF1_THEFT        10          1     0.8727           min
#                Acc_THEFT        10          1     0.8727           max
#                 AP_THEFT        10          1     0.8963           max
#  MacroF1_over_categories        10          1     0.8249           max
#  MacroAP_over_categories        10          1     0.7826           max
# MacroAcc_over_categories        10          1     0.8562           max
#  MacroF1_sparsity_<=0.25        10          1     0.5124           min
#  MicroF1_sparsity_<=0.25        10          1     0.8415           min
#      Acc_sparsity_<=0.25        10          1     0.8415           max
#       AP_sparsity_<=0.25        10          1     0.1016           max
#   MacroF1_sparsity_<=0.5        10          1     0.5214           min
#   MicroF1_sparsity_<=0.5        10          1     0.5303           min
#       Acc_sparsity_<=0.5        10          1     0.5303           max
#        AP_sparsity_<=0.5        10          1     0.4022           max
#  MacroF1_sparsity_<=0.75        10          1     0.4749           min
#  MicroF1_sparsity_<=0.75        10          1     0.6153           min
#      Acc_sparsity_<=0.75        10          1     0.6153           max
#       AP_sparsity_<=0.75        10          1     0.6632           max
#   MacroF1_sparsity_<=1.0        10          1     0.4706           min
#   MicroF1_sparsity_<=1.0        10          1     0.8769           min
#       Acc_sparsity_<=1.0        10          1     0.8769           max
#        AP_sparsity_<=1.0        10          1     0.9377           max
#                     RMSE        10          1     1.7156           min
#                      MAE        10          1     1.2318           min
#                     MAPE        10          1     0.5992           min
#             RMSE_ASSAULT        10          1     1.1380           min
#              MAE_ASSAULT        10          1     0.8417           min
#             MAPE_ASSAULT        10          1     0.5061           min
#             RMSE_BATTERY        10          1     1.7874           min
#              MAE_BATTERY        10          1     1.3506           min
#             MAPE_BATTERY        10          1     0.6702           min
#     RMSE_CRIMINAL DAMAGE        10          1     1.4312           min
#      MAE_CRIMINAL DAMAGE        10          1     1.0360           min
#     MAPE_CRIMINAL DAMAGE        10          1     0.5405           min
#               RMSE_THEFT        10          1     2.0931           min
#                MAE_THEFT        10          1     1.5059           min
#               MAPE_THEFT        10          1     0.6352           min
#     RMSE_sparsity_<=0.25        10          1     0.9969           min
#      MAE_sparsity_<=0.25        10          1     0.8652           min
#     MAPE_sparsity_<=0.25        10          1     0.7685           min
#      RMSE_sparsity_<=0.5        10          1     1.0102           min
#       MAE_sparsity_<=0.5        10          1     0.7848           min
#      MAPE_sparsity_<=0.5        10          1     0.5581           min
#     RMSE_sparsity_<=0.75        10          1     1.2251           min
#      MAE_sparsity_<=0.75        10          1     0.8799           min
#     MAPE_sparsity_<=0.75        10          1     0.4802           min
#      RMSE_sparsity_<=1.0        10          1     2.0152           min
#       MAE_sparsity_<=1.0        10          1     1.4895           min
#      MAPE_sparsity_<=1.0        10          1     0.6349           min
#                epochLoss        10          1    29.2444           min
#
# ==============================
# OVERALL BEST (SEED, EPOCH) BY 'MOST METRICS WON'
# ==============================
# Best (seed, epoch) overall: seed=10 epoch=1 (wins 67 metrics)
#
#
# ==============================
# OVERALL BEST EPOCH WITHIN EACH SEED (wins across metrics)
# ==============================
#
#  Seed  OverallBestEpochWithinSeed  WinsCount
#    10                           1         67
#
# ==============================
# BEST SEED BY AVERAGE-OVER-EPOCHS (per metric)
# ==============================
#
#                   Metric  BestSeedByAvgEpochs  BestValueByAvgEpochs Goal(min/max)
#                  MacroF1                   10                0.8295           max
#                  MicroF1                   10                0.8562           max
#                       AP                   10                0.8316           max
#                      Acc                   10                0.8562           max
#          MacroF1_ASSAULT                   10                0.7468           min
#          MicroF1_ASSAULT                   10                0.8127           min
#              Acc_ASSAULT                   10                0.8127           max
#               AP_ASSAULT                   10                0.5798           max
#          MacroF1_BATTERY                   10                0.8667           min
#          MicroF1_BATTERY                   10                0.8855           min
#              Acc_BATTERY                   10                0.8855           max
#               AP_BATTERY                   10                0.8839           max
#  MacroF1_CRIMINAL DAMAGE                   10                0.8256           min
#  MicroF1_CRIMINAL DAMAGE                   10                0.8539           min
#      Acc_CRIMINAL DAMAGE                   10                0.8539           max
#       AP_CRIMINAL DAMAGE                   10                0.7702           max
#            MacroF1_THEFT                   10                0.8605           min
#            MicroF1_THEFT                   10                0.8727           min
#                Acc_THEFT                   10                0.8727           max
#                 AP_THEFT                   10                0.8963           max
#  MacroF1_over_categories                   10                0.8249           max
#  MacroAP_over_categories                   10                0.7826           max
# MacroAcc_over_categories                   10                0.8562           max
#  MacroF1_sparsity_<=0.25                   10                0.5124           min
#  MicroF1_sparsity_<=0.25                   10                0.8415           min
#      Acc_sparsity_<=0.25                   10                0.8415           max
#       AP_sparsity_<=0.25                   10                0.1016           max
#   MacroF1_sparsity_<=0.5                   10                0.5214           min
#   MicroF1_sparsity_<=0.5                   10                0.5303           min
#       Acc_sparsity_<=0.5                   10                0.5303           max
#        AP_sparsity_<=0.5                   10                0.4022           max
#  MacroF1_sparsity_<=0.75                   10                0.4749           min
#  MicroF1_sparsity_<=0.75                   10                0.6153           min
#      Acc_sparsity_<=0.75                   10                0.6153           max
#       AP_sparsity_<=0.75                   10                0.6632           max
#   MacroF1_sparsity_<=1.0                   10                0.4706           min
#   MicroF1_sparsity_<=1.0                   10                0.8769           min
#       Acc_sparsity_<=1.0                   10                0.8769           max
#        AP_sparsity_<=1.0                   10                0.9377           max
#                     RMSE                   10                1.7156           min
#                      MAE                   10                1.2318           min
#                     MAPE                   10                0.5992           min
#             RMSE_ASSAULT                   10                1.1380           min
#              MAE_ASSAULT                   10                0.8417           min
#             MAPE_ASSAULT                   10                0.5061           min
#             RMSE_BATTERY                   10                1.7874           min
#              MAE_BATTERY                   10                1.3506           min
#             MAPE_BATTERY                   10                0.6702           min
#     RMSE_CRIMINAL DAMAGE                   10                1.4312           min
#      MAE_CRIMINAL DAMAGE                   10                1.0360           min
#     MAPE_CRIMINAL DAMAGE                   10                0.5405           min
#               RMSE_THEFT                   10                2.0931           min
#                MAE_THEFT                   10                1.5059           min
#               MAPE_THEFT                   10                0.6352           min
#     RMSE_sparsity_<=0.25                   10                0.9969           min
#      MAE_sparsity_<=0.25                   10                0.8652           min
#     MAPE_sparsity_<=0.25                   10                0.7685           min
#      RMSE_sparsity_<=0.5                   10                1.0102           min
#       MAE_sparsity_<=0.5                   10                0.7848           min
#      MAPE_sparsity_<=0.5                   10                0.5581           min
#     RMSE_sparsity_<=0.75                   10                1.2251           min
#      MAE_sparsity_<=0.75                   10                0.8799           min
#     MAPE_sparsity_<=0.75                   10                0.4802           min
#      RMSE_sparsity_<=1.0                   10                2.0152           min
#       MAE_sparsity_<=1.0                   10                1.4895           min
#      MAPE_sparsity_<=1.0                   10                0.6349           min
#                epochLoss                   10               29.2444           min
#
# Saved: /home/jovyan/STHSL/tests_validation/option1/CHI_3km/metrics_all_epochs_pivot_ranking_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/CHI_3km/metrics_all_epochs_pivot_ranking_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/CHI_3km/metrics_all_epochs_pivot_summary_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/CHI_3km/metrics_all_epochs_pivot_summary_overall_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/CHI_3km/metrics_all_epochs_pivot_ranking_best_seed_by_avg.csv

# %%
# !python train.py --data CHI_3km --use_ode_option option2 --device cuda --eval_metrics all --batch 16 --n_traj_samples 1 --ode_method dopri5 --odeint_atol 0.001 --odeint_rtol 0.001 --gen_layers 1 --gen_dim 64 --gcn_step 1 --horizon 12
# step_move_checkpoints("CHI_3km", "option2", on_conflict="overwrite")
# !python metrics_generation.py --data CHI_3km --use_ode_option option2 --device cuda --eval_metrics all --batch 16 --n_traj_samples 1 --ode_method dopri5 --odeint_atol 0.001 --odeint_rtol 0.001 --gen_layers 1 --gen_dim 64 --gcn_step 1 --horizon 12 --out-dir tests_validation/option2/CHI_3km --save-root Logs/option2/
# step_metrics_extraction("CHI_3km", "option2")
# step_analyse("CHI_3km", "option2")

# %% [markdown]
# ### 5km grid

# %%
# !python train.py --data NYC_5km --use_ode_option baseline --device cuda --eval_metrics all --batch 16
step_move_checkpoints("NYC_5km", "baseline", on_conflict="overwrite")
# !python metrics_generation.py --data NYC_5km --use_ode_option baseline --device cuda --eval_metrics all --batch 16 --out-dir tests_validation/baseline/NYC_5km --save-root Logs/baseline
step_metrics_extraction("NYC_5km", "baseline")
step_analyse("NYC_5km", "baseline")
# Out:
# self.predir Datasets/common_data/NYC_crime_5km/
# (100, 153, 4)
# Row: 10 , Col: 10
# Sparsity: 0.041750457038391225
# use_ode_option: baseline
# ODE is not enabled, baseline STHSL model is initialized
# DEBUG SHAPES status: True
#
# ===== SEED 10 =====
# start training...
# ===== TRAINING ARGS =====
# lr: 0.001
# weight_decay: 0.0001
# cr: 0.8
# ir: 1
# t: 0.05
# batch: 16
# epoch: 1
# latdim: 16
# temporalRange: 30
# cateNum: 4
# data: NYC_5km
# kernelSize: 3
# border: 0.5
# hyperNum: 128
# dropRateL: 0.2
# dropRateG: 0.1
# use_ode_option: baseline
# n_traj_samples: 1
# ode_method: dopri5
# odeint_atol: 0.0001
# odeint_rtol: 0.001
# gen_layers: 1
# gen_dim: 64
# save_latent: false
# gcn_step: 2
# rnn_units: 64
# horizon: 12
# filter_type: 2
# device: cuda
# tstEpoch: 1
# save: ./Save/
# checkpoint: ./Save/NYC/
# eval_metrics: all
# f1_label_threshold: 0.0
# f1_pred_threshold: 0.5
# seeds: [10]
# row: 10
# col: 10
# offNum: 4
# areaNum: 100
# trnDays: 547
# valDays: 31
# tstDays: 153
# decay_step: 34
# ==========================
# Epoch  1 Training Time 2.268s
# Epoch 1/1, Train Loss =  6.5995,  preLoss =  5.0244
# Val (MicroF1+MacroF1) increase from -1.0000 to 1.5336
# Epoch 1/1, Test: MacroF1 = 0.5893, MicroF1 = 0.9568, AP = 0.2363, Acc = 0.9568, MacroF1_cate_0 = 0.5032, MicroF1_cate_0 = 0.9739, Acc_cate_0 = 0.9739, AP_cate_0 = 0.0623, MacroF1_cate_1 = 0.5417, MicroF1_cate_1 = 0.9577, Acc_cate_1 = 0.9577, AP_cate_1 = 0.1681, MacroF1_cate_2 = 0.6510, MicroF1_cate_2 = 0.9297, Acc_cate_2 = 0.9297, AP_cate_2 = 0.3883, MacroF1_cate_3 = 0.5170, MicroF1_cate_3 = 0.9661, Acc_cate_3 = 0.9661, AP_cate_3 = 0.0887, MacroF1_over_categories = 0.5532, MicroF1_over_categories = 0.9568, MacroAP_over_categories = 0.1769, MacroAcc_over_categories = 0.9568, MacroF1_mask_1 = 0.4962, MicroF1_mask_1 = 0.9305, Acc_mask_1 = 0.9305, AP_mask_1 = 0.0987, MacroF1_mask_2 = 0.4602, MicroF1_mask_2 = 0.6234, Acc_mask_2 = 0.6234, AP_mask_2 = 0.3562, MacroF1_mask_3 = 0.4333, MicroF1_mask_3 = 0.5882, Acc_mask_3 = 0.5882, AP_mask_3 = 0.6648, MacroF1_mask_4 = 0.4650, MicroF1_mask_4 = 0.8693, Acc_mask_4 = 0.8693, AP_mask_4 = 0.8525, MacroF1_cate_0_mask_1 = 0.4929, MicroF1_cate_0_mask_1 = 0.9346, Acc_cate_0_mask_1 = 0.9346, AP_cate_0_mask_1 = 0.1017, MacroF1_cate_0_mask_2 = nan, MicroF1_cate_0_mask_2 = 0.0000, Acc_cate_0_mask_2 = nan, AP_cate_0_mask_2 = nan, MacroF1_cate_0_mask_3 = nan, MicroF1_cate_0_mask_3 = 0.0000, Acc_cate_0_mask_3 = nan, AP_cate_0_mask_3 = nan, MacroF1_cate_0_mask_4 = nan, MicroF1_cate_0_mask_4 = 0.0000, Acc_cate_0_mask_4 = nan, AP_cate_0_mask_4 = nan, MacroF1_cate_1_mask_1 = 0.4874, MicroF1_cate_1_mask_1 = 0.9261, Acc_cate_1_mask_1 = 0.9261, AP_cate_1_mask_1 = 0.1027, MacroF1_cate_1_mask_2 = 0.4828, MicroF1_cate_1_mask_2 = 0.5752, Acc_cate_1_mask_2 = 0.5752, AP_cate_1_mask_2 = 0.4006, MacroF1_cate_1_mask_3 = nan, MicroF1_cate_1_mask_3 = 0.0000, Acc_cate_1_mask_3 = nan, AP_cate_1_mask_3 = nan, MacroF1_cate_1_mask_4 = nan, MicroF1_cate_1_mask_4 = 0.0000, Acc_cate_1_mask_4 = nan, AP_cate_1_mask_4 = nan, MacroF1_cate_2_mask_1 = 0.4981, MicroF1_cate_2_mask_1 = 0.9230, Acc_cate_2_mask_1 = 0.9230, AP_cate_2_mask_1 = 0.1111, MacroF1_cate_2_mask_2 = 0.4558, MicroF1_cate_2_mask_2 = 0.6281, Acc_cate_2_mask_2 = 0.6281, AP_cate_2_mask_2 = 0.3631, MacroF1_cate_2_mask_3 = 0.4333, MicroF1_cate_2_mask_3 = 0.5882, Acc_cate_2_mask_3 = 0.5882, AP_cate_2_mask_3 = 0.6648, MacroF1_cate_2_mask_4 = 0.4650, MicroF1_cate_2_mask_4 = 0.8693, Acc_cate_2_mask_4 = 0.8693, AP_cate_2_mask_4 = 0.8525, MacroF1_cate_3_mask_1 = 0.5077, MicroF1_cate_3_mask_1 = 0.9379, Acc_cate_3_mask_1 = 0.9379, AP_cate_3_mask_1 = 0.0896, MacroF1_cate_3_mask_2 = 0.4244, MicroF1_cate_3_mask_2 = 0.6558, Acc_cate_3_mask_2 = 0.6558, AP_cate_3_mask_2 = 0.2758, MacroF1_cate_3_mask_3 = nan, MicroF1_cate_3_mask_3 = 0.0000, Acc_cate_3_mask_3 = nan, AP_cate_3_mask_3 = nan, MacroF1_cate_3_mask_4 = nan, MicroF1_cate_3_mask_4 = 0.0000, Acc_cate_3_mask_4 = nan, AP_cate_3_mask_4 = nan, RMSE = 1.0717, MAE = 0.9644, MAPE = 0.8109, RMSE_cate_0 = 1.0073, MAE_cate_0 = 0.9602, MAPE_cate_0 = 0.8887, RMSE_cate_1 = 1.0472, MAE_cate_1 = 0.9533, MAPE_cate_1 = 0.8166, RMSE_cate_2 = 1.1159, MAE_cate_2 = 0.9653, MAPE_cate_2 = 0.7534, RMSE_cate_3 = 1.0433, MAE_cate_3 = 0.9793, MAPE_cate_3 = 0.8791, RMSE_mask_1 = 1.0090, MAE_mask_1 = 0.9626, MAPE_mask_1 = 0.8900, RMSE_mask_2 = 1.0850, MAE_mask_2 = 0.9532, MAPE_mask_2 = 0.7564, RMSE_mask_3 = 0.9762, MAE_mask_3 = 0.6982, MAPE_mask_3 = 0.3878, RMSE_mask_4 = 1.6275, MAE_mask_4 = 1.2427, MAPE_mask_4 = 0.5163, epochLoss = 1.1469
# MacroF1=0.5893 MicroF1=0.9568 AP=0.2363
#
#   [RUNTIME] Epoch 1: train=2.27s | train+eval=2.95s
#
# ============================================================
# RUNTIME ANALYSIS SUMMARY (STHSL)
# ============================================================
#   Seed:                      10
#   Epochs run:                1
#   Avg train time/epoch:      2.27s (+/- 0.00s)
#   Avg total time/epoch:      2.95s (+/- 0.00s)
#   Per-epoch train times:     ['2.27']
#   Total training time:       2.95s
# ============================================================
#
# Epoch 1/1, Best: MacroF1 = 0.5893, MicroF1 = 0.9568, AP = 0.2363, Acc = 0.9568, MacroF1_cate_0 = 0.5032, MicroF1_cate_0 = 0.9739, Acc_cate_0 = 0.9739, AP_cate_0 = 0.0623, MacroF1_cate_1 = 0.5417, MicroF1_cate_1 = 0.9577, Acc_cate_1 = 0.9577, AP_cate_1 = 0.1681, MacroF1_cate_2 = 0.6510, MicroF1_cate_2 = 0.9297, Acc_cate_2 = 0.9297, AP_cate_2 = 0.3883, MacroF1_cate_3 = 0.5170, MicroF1_cate_3 = 0.9661, Acc_cate_3 = 0.9661, AP_cate_3 = 0.0887, MacroF1_over_categories = 0.5532, MicroF1_over_categories = 0.9568, MacroAP_over_categories = 0.1769, MacroAcc_over_categories = 0.9568, MacroF1_mask_1 = 0.4962, MicroF1_mask_1 = 0.9305, Acc_mask_1 = 0.9305, AP_mask_1 = 0.0987, MacroF1_mask_2 = 0.4602, MicroF1_mask_2 = 0.6234, Acc_mask_2 = 0.6234, AP_mask_2 = 0.3562, MacroF1_mask_3 = 0.4333, MicroF1_mask_3 = 0.5882, Acc_mask_3 = 0.5882, AP_mask_3 = 0.6648, MacroF1_mask_4 = 0.4650, MicroF1_mask_4 = 0.8693, Acc_mask_4 = 0.8693, AP_mask_4 = 0.8525, MacroF1_cate_0_mask_1 = 0.4929, MicroF1_cate_0_mask_1 = 0.9346, Acc_cate_0_mask_1 = 0.9346, AP_cate_0_mask_1 = 0.1017, MacroF1_cate_0_mask_2 = nan, MicroF1_cate_0_mask_2 = 0.0000, Acc_cate_0_mask_2 = nan, AP_cate_0_mask_2 = nan, MacroF1_cate_0_mask_3 = nan, MicroF1_cate_0_mask_3 = 0.0000, Acc_cate_0_mask_3 = nan, AP_cate_0_mask_3 = nan, MacroF1_cate_0_mask_4 = nan, MicroF1_cate_0_mask_4 = 0.0000, Acc_cate_0_mask_4 = nan, AP_cate_0_mask_4 = nan, MacroF1_cate_1_mask_1 = 0.4874, MicroF1_cate_1_mask_1 = 0.9261, Acc_cate_1_mask_1 = 0.9261, AP_cate_1_mask_1 = 0.1027, MacroF1_cate_1_mask_2 = 0.4828, MicroF1_cate_1_mask_2 = 0.5752, Acc_cate_1_mask_2 = 0.5752, AP_cate_1_mask_2 = 0.4006, MacroF1_cate_1_mask_3 = nan, MicroF1_cate_1_mask_3 = 0.0000, Acc_cate_1_mask_3 = nan, AP_cate_1_mask_3 = nan, MacroF1_cate_1_mask_4 = nan, MicroF1_cate_1_mask_4 = 0.0000, Acc_cate_1_mask_4 = nan, AP_cate_1_mask_4 = nan, MacroF1_cate_2_mask_1 = 0.4981, MicroF1_cate_2_mask_1 = 0.9230, Acc_cate_2_mask_1 = 0.9230, AP_cate_2_mask_1 = 0.1111, MacroF1_cate_2_mask_2 = 0.4558, MicroF1_cate_2_mask_2 = 0.6281, Acc_cate_2_mask_2 = 0.6281, AP_cate_2_mask_2 = 0.3631, MacroF1_cate_2_mask_3 = 0.4333, MicroF1_cate_2_mask_3 = 0.5882, Acc_cate_2_mask_3 = 0.5882, AP_cate_2_mask_3 = 0.6648, MacroF1_cate_2_mask_4 = 0.4650, MicroF1_cate_2_mask_4 = 0.8693, Acc_cate_2_mask_4 = 0.8693, AP_cate_2_mask_4 = 0.8525, MacroF1_cate_3_mask_1 = 0.5077, MicroF1_cate_3_mask_1 = 0.9379, Acc_cate_3_mask_1 = 0.9379, AP_cate_3_mask_1 = 0.0896, MacroF1_cate_3_mask_2 = 0.4244, MicroF1_cate_3_mask_2 = 0.6558, Acc_cate_3_mask_2 = 0.6558, AP_cate_3_mask_2 = 0.2758, MacroF1_cate_3_mask_3 = nan, MicroF1_cate_3_mask_3 = 0.0000, Acc_cate_3_mask_3 = nan, AP_cate_3_mask_3 = nan, MacroF1_cate_3_mask_4 = nan, MicroF1_cate_3_mask_4 = 0.0000, Acc_cate_3_mask_4 = nan, AP_cate_3_mask_4 = nan, RMSE = 1.0717, MAE = 0.9644, MAPE = 0.8109, RMSE_cate_0 = 1.0073, MAE_cate_0 = 0.9602, MAPE_cate_0 = 0.8887, RMSE_cate_1 = 1.0472, MAE_cate_1 = 0.9533, MAPE_cate_1 = 0.8166, RMSE_cate_2 = 1.1159, MAE_cate_2 = 0.9653, MAPE_cate_2 = 0.7534, RMSE_cate_3 = 1.0433, MAE_cate_3 = 0.9793, MAPE_cate_3 = 0.8791, RMSE_mask_1 = 1.0090, MAE_mask_1 = 0.9626, MAPE_mask_1 = 0.8900, RMSE_mask_2 = 1.0850, MAE_mask_2 = 0.9532, MAPE_mask_2 = 0.7564, RMSE_mask_3 = 0.9762, MAE_mask_3 = 0.6982, MAPE_mask_3 = 0.3878, RMSE_mask_4 = 1.6275, MAE_mask_4 = 1.2427, MAPE_mask_4 = 0.5163, epochLoss = 1.1469
#
# ===== SUMMARY: best result per seed =====
# seed=10: {'MacroF1': 0.589331393948083, 'MicroF1': 0.9568300653594771, 'AP': 0.23627839773962464, 'Acc': 0.9568300653594771, 'MacroF1_cate_0': 0.5031796502384738, 'MicroF1_cate_0': 0.9738562091503268, 'Acc_cate_0': 0.9738562091503268, 'AP_cate_0': 0.06228249816484399, 'MacroF1_cate_1': 0.5417310558351481, 'MicroF1_cate_1': 0.9577124183006536, 'Acc_cate_1': 0.9577124183006536, 'AP_cate_1': 0.16813297877531025, 'MacroF1_cate_2': 0.6509635160746579, 'MicroF1_cate_2': 0.9296732026143791, 'Acc_cate_2': 0.9296732026143791, 'AP_cate_2': 0.38831863382288434, 'MacroF1_cate_3': 0.5169594046252595, 'MicroF1_cate_3': 0.966078431372549, 'Acc_cate_3': 0.966078431372549, 'AP_cate_3': 0.08870527599143924, 'MacroF1_over_categories': 0.5532084066933849, 'MicroF1_over_categories': 0.9568300653594772, 'MacroAP_over_categories': 0.17685984668861948, 'MacroAcc_over_categories': 0.9568300653594772, 'MacroF1_mask_1': 0.4962301629412452, 'MicroF1_mask_1': 0.9305237246413717, 'Acc_mask_1': 0.9305237246413717, 'AP_mask_1': 0.09865783927330588, 'MacroF1_mask_2': 0.4601620478221894, 'MicroF1_mask_2': 0.6233660130718954, 'Acc_mask_2': 0.6233660130718954, 'AP_mask_2': 0.3561765170700398, 'MacroF1_mask_3': 0.4333000176377212, 'MicroF1_mask_3': 0.5882352941176471, 'Acc_mask_3': 0.5882352941176471, 'AP_mask_3': 0.6648415445365097, 'MacroF1_mask_4': 0.46503496503496505, 'MicroF1_mask_4': 0.869281045751634, 'Acc_mask_4': 0.869281045751634, 'AP_mask_4': 0.8524516440330179, 'MacroF1_cate_0_mask_1': 0.4929006085192698, 'MicroF1_cate_0_mask_1': 0.934640522875817, 'Acc_cate_0_mask_1': 0.934640522875817, 'AP_cate_0_mask_1': 0.10173151740930414, 'MacroF1_cate_0_mask_2': nan, 'MicroF1_cate_0_mask_2': 0.0, 'Acc_cate_0_mask_2': nan, 'AP_cate_0_mask_2': nan, 'MacroF1_cate_0_mask_3': nan, 'MicroF1_cate_0_mask_3': 0.0, 'Acc_cate_0_mask_3': nan, 'AP_cate_0_mask_3': nan, 'MacroF1_cate_0_mask_4': nan, 'MicroF1_cate_0_mask_4': 0.0, 'Acc_cate_0_mask_4': nan, 'AP_cate_0_mask_4': nan, 'MacroF1_cate_1_mask_1': 0.4873684155906538, 'MicroF1_cate_1_mask_1': 0.9261437908496732, 'Acc_cate_1_mask_1': 0.9261437908496732, 'AP_cate_1_mask_1': 0.10268434176292388, 'MacroF1_cate_1_mask_2': 0.4827645988037793, 'MicroF1_cate_1_mask_2': 0.5751633986928104, 'Acc_cate_1_mask_2': 0.5751633986928104, 'AP_cate_1_mask_2': 0.4006057130676939, 'MacroF1_cate_1_mask_3': nan, 'MicroF1_cate_1_mask_3': 0.0, 'Acc_cate_1_mask_3': nan, 'AP_cate_1_mask_3': nan, 'MacroF1_cate_1_mask_4': nan, 'MicroF1_cate_1_mask_4': 0.0, 'Acc_cate_1_mask_4': nan, 'AP_cate_1_mask_4': nan, 'MacroF1_cate_2_mask_1': 0.4981364324026957, 'MicroF1_cate_2_mask_1': 0.9230210602759622, 'Acc_cate_2_mask_1': 0.9230210602759622, 'AP_cate_2_mask_1': 0.11105568655356263, 'MacroF1_cate_2_mask_2': 0.45575054436198525, 'MicroF1_cate_2_mask_2': 0.6281045751633987, 'Acc_cate_2_mask_2': 0.6281045751633987, 'AP_cate_2_mask_2': 0.3631483460069206, 'MacroF1_cate_2_mask_3': 0.4333000176377212, 'MicroF1_cate_2_mask_3': 0.5882352941176471, 'Acc_cate_2_mask_3': 0.5882352941176471, 'AP_cate_2_mask_3': 0.6648415445365097, 'MacroF1_cate_2_mask_4': 0.46503496503496505, 'MicroF1_cate_2_mask_4': 0.869281045751634, 'Acc_cate_2_mask_4': 0.869281045751634, 'AP_cate_2_mask_4': 0.8524516440330179, 'MacroF1_cate_3_mask_1': 0.5077008311028995, 'MicroF1_cate_3_mask_1': 0.9379084967320261, 'Acc_cate_3_mask_1': 0.9379084967320261, 'AP_cate_3_mask_1': 0.08958301305710985, 'MacroF1_cate_3_mask_2': 0.42442857142857143, 'MicroF1_cate_3_mask_2': 0.6557734204793029, 'Acc_cate_3_mask_2': 0.6557734204793029, 'AP_cate_3_mask_2': 0.2758206370144507, 'MacroF1_cate_3_mask_3': nan, 'MicroF1_cate_3_mask_3': 0.0, 'Acc_cate_3_mask_3': nan, 'AP_cate_3_mask_3': nan, 'MacroF1_cate_3_mask_4': nan, 'MicroF1_cate_3_mask_4': 0.0, 'Acc_cate_3_mask_4': nan, 'AP_cate_3_mask_4': nan, 'RMSE': 1.071660138186667, 'MAE': 0.964365663184363, 'MAPE': 0.8108959847780863, 'RMSE_cate_0': 1.007349318571372, 'MAE_cate_0': 0.9601997337093455, 'MAPE_cate_0': 0.8886561726709354, 'RMSE_cate_1': 1.0472093982421409, ' ...
# Total time spent: 3.8614
# Detected seed folders under /home/jovyan/STHSL/Save/NYC_5km
#
# Checkpoint move completed (NYC_5km / baseline)
#   Mode     : seed-aware
#   Moved    : 1
#   Skipped  : 0
# Found 1 checkpoints under Logs/baseline/NYC_5km (seed folders) (sorted by seed, epoch).
#
# [seed 10 epoch 1] Running: /opt/conda/bin/python test.py --data NYC_5km --use_ode_option baseline --checkpoint Logs/baseline/NYC_5km/seed_10/_seed_10_epoch_1_MAE_0.96_MAPE_0.81_MicroF1_0.9568.pth --batch 16 --eval_metrics all
# [seed 10 epoch 1] Writing: tests_validation/baseline/NYC_5km/seed_10_epoch_1_main.txt
# [seed 10 epoch 1] OK
# \n$ python /home/jovyan/STHSL/metrics_extraction.py /home/jovyan/STHSL/tests_validation/baseline/NYC_5km --city nyc
#
# Reading folder: /home/jovyan/STHSL/tests_validation/baseline/NYC_5km
#
# City: nyc — using category map: {'0': 'BURGLARY', '1': 'FELONY ASSAULT', '2': 'GRAND LARCENY', '3': 'ROBBERY'}
# Processing seed10_epoch1: seed_10_epoch_1_main.txt
#
# Created: /home/jovyan/STHSL/tests_validation/baseline/NYC_5km/metrics_all_epochs_pivot.csv
#
#                       seed10_epoch1  seed_avg_seed10  all_seeds_avg
# MacroF1                      0.5893           0.5893         0.5893
# MicroF1                      0.9568           0.9568         0.9568
# AP                           0.2363           0.2363         0.2363
# Acc                          0.9568           0.9568         0.9568
# MacroF1_BURGLARY             0.5032           0.5032         0.5032
# ...                             ...              ...            ...
# MAPE_sparsity_<=0.75         0.3878           0.3878         0.3878
# RMSE_sparsity_<=1.0          1.6275           1.6275         1.6275
# MAE_sparsity_<=1.0           1.2427           1.2427         1.2427
# MAPE_sparsity_<=1.0          0.5163           0.5163         0.5163
# epochLoss                   11.4687          11.4687        11.4687
#
# [67 rows x 3 columns]
#
# Running: python /home/jovyan/STHSL/analyse_metrics.py /home/jovyan/STHSL/tests_validation/baseline/NYC_5km/metrics_all_epochs_pivot.csv
#
# ==============================
# BEST (SEED, EPOCH) PER METRIC (across all seeds/epochs)
# ==============================
#
#                   Metric  BestSeed  BestEpoch  BestValue Goal(min/max)
#                  MacroF1        10          1     0.5893           max
#                  MicroF1        10          1     0.9568           max
#                       AP        10          1     0.2363           max
#                      Acc        10          1     0.9568           max
#         MacroF1_BURGLARY        10          1     0.5032           min
#         MicroF1_BURGLARY        10          1     0.9739           min
#             Acc_BURGLARY        10          1     0.9739           max
#              AP_BURGLARY        10          1     0.0623           max
#   MacroF1_FELONY ASSAULT        10          1     0.5417           min
#   MicroF1_FELONY ASSAULT        10          1     0.9577           min
#       Acc_FELONY ASSAULT        10          1     0.9577           max
#        AP_FELONY ASSAULT        10          1     0.1681           max
#    MacroF1_GRAND LARCENY        10          1     0.6510           min
#    MicroF1_GRAND LARCENY        10          1     0.9297           min
#        Acc_GRAND LARCENY        10          1     0.9297           max
#         AP_GRAND LARCENY        10          1     0.3883           max
#          MacroF1_ROBBERY        10          1     0.5170           min
#          MicroF1_ROBBERY        10          1     0.9661           min
#              Acc_ROBBERY        10          1     0.9661           max
#               AP_ROBBERY        10          1     0.0887           max
#  MacroF1_over_categories        10          1     0.5532           max
#  MacroAP_over_categories        10          1     0.1769           max
# MacroAcc_over_categories        10          1     0.9568           max
#  MacroF1_sparsity_<=0.25        10          1     0.4962           min
#  MicroF1_sparsity_<=0.25        10          1     0.9305           min
#      Acc_sparsity_<=0.25        10          1     0.9305           max
#       AP_sparsity_<=0.25        10          1     0.0987           max
#   MacroF1_sparsity_<=0.5        10          1     0.4602           min
#   MicroF1_sparsity_<=0.5        10          1     0.6234           min
#       Acc_sparsity_<=0.5        10          1     0.6234           max
#        AP_sparsity_<=0.5        10          1     0.3562           max
#  MacroF1_sparsity_<=0.75        10          1     0.4333           min
#  MicroF1_sparsity_<=0.75        10          1     0.5882           min
#      Acc_sparsity_<=0.75        10          1     0.5882           max
#       AP_sparsity_<=0.75        10          1     0.6648           max
#   MacroF1_sparsity_<=1.0        10          1     0.4650           min
#   MicroF1_sparsity_<=1.0        10          1     0.8693           min
#       Acc_sparsity_<=1.0        10          1     0.8693           max
#        AP_sparsity_<=1.0        10          1     0.8525           max
#                     RMSE        10          1     1.0717           min
#                      MAE        10          1     0.9644           min
#                     MAPE        10          1     0.8109           min
#            RMSE_BURGLARY        10          1     1.0073           min
#             MAE_BURGLARY        10          1     0.9602           min
#            MAPE_BURGLARY        10          1     0.8887           min
#      RMSE_FELONY ASSAULT        10          1     1.0472           min
#       MAE_FELONY ASSAULT        10          1     0.9533           min
#      MAPE_FELONY ASSAULT        10          1     0.8166           min
#       RMSE_GRAND LARCENY        10          1     1.1159           min
#        MAE_GRAND LARCENY        10          1     0.9653           min
#       MAPE_GRAND LARCENY        10          1     0.7534           min
#             RMSE_ROBBERY        10          1     1.0433           min
#              MAE_ROBBERY        10          1     0.9793           min
#             MAPE_ROBBERY        10          1     0.8791           min
#     RMSE_sparsity_<=0.25        10          1     1.0090           min
#      MAE_sparsity_<=0.25        10          1     0.9626           min
#     MAPE_sparsity_<=0.25        10          1     0.8900           min
#      RMSE_sparsity_<=0.5        10          1     1.0850           min
#       MAE_sparsity_<=0.5        10          1     0.9532           min
#      MAPE_sparsity_<=0.5        10          1     0.7564           min
#     RMSE_sparsity_<=0.75        10          1     0.9762           min
#      MAE_sparsity_<=0.75        10          1     0.6982           min
#     MAPE_sparsity_<=0.75        10          1     0.3878           min
#      RMSE_sparsity_<=1.0        10          1     1.6275           min
#       MAE_sparsity_<=1.0        10          1     1.2427           min
#      MAPE_sparsity_<=1.0        10          1     0.5163           min
#                epochLoss        10          1    11.4687           min
#
# ==============================
# OVERALL BEST (SEED, EPOCH) BY 'MOST METRICS WON'
# ==============================
# Best (seed, epoch) overall: seed=10 epoch=1 (wins 67 metrics)
#
#
# ==============================
# OVERALL BEST EPOCH WITHIN EACH SEED (wins across metrics)
# ==============================
#
#  Seed  OverallBestEpochWithinSeed  WinsCount
#    10                           1         67
#
# ==============================
# BEST SEED BY AVERAGE-OVER-EPOCHS (per metric)
# ==============================
#
#                   Metric  BestSeedByAvgEpochs  BestValueByAvgEpochs Goal(min/max)
#                  MacroF1                   10                0.5893           max
#                  MicroF1                   10                0.9568           max
#                       AP                   10                0.2363           max
#                      Acc                   10                0.9568           max
#         MacroF1_BURGLARY                   10                0.5032           min
#         MicroF1_BURGLARY                   10                0.9739           min
#             Acc_BURGLARY                   10                0.9739           max
#              AP_BURGLARY                   10                0.0623           max
#   MacroF1_FELONY ASSAULT                   10                0.5417           min
#   MicroF1_FELONY ASSAULT                   10                0.9577           min
#       Acc_FELONY ASSAULT                   10                0.9577           max
#        AP_FELONY ASSAULT                   10                0.1681           max
#    MacroF1_GRAND LARCENY                   10                0.6510           min
#    MicroF1_GRAND LARCENY                   10                0.9297           min
#        Acc_GRAND LARCENY                   10                0.9297           max
#         AP_GRAND LARCENY                   10                0.3883           max
#          MacroF1_ROBBERY                   10                0.5170           min
#          MicroF1_ROBBERY                   10                0.9661           min
#              Acc_ROBBERY                   10                0.9661           max
#               AP_ROBBERY                   10                0.0887           max
#  MacroF1_over_categories                   10                0.5532           max
#  MacroAP_over_categories                   10                0.1769           max
# MacroAcc_over_categories                   10                0.9568           max
#  MacroF1_sparsity_<=0.25                   10                0.4962           min
#  MicroF1_sparsity_<=0.25                   10                0.9305           min
#      Acc_sparsity_<=0.25                   10                0.9305           max
#       AP_sparsity_<=0.25                   10                0.0987           max
#   MacroF1_sparsity_<=0.5                   10                0.4602           min
#   MicroF1_sparsity_<=0.5                   10                0.6234           min
#       Acc_sparsity_<=0.5                   10                0.6234           max
#        AP_sparsity_<=0.5                   10                0.3562           max
#  MacroF1_sparsity_<=0.75                   10                0.4333           min
#  MicroF1_sparsity_<=0.75                   10                0.5882           min
#      Acc_sparsity_<=0.75                   10                0.5882           max
#       AP_sparsity_<=0.75                   10                0.6648           max
#   MacroF1_sparsity_<=1.0                   10                0.4650           min
#   MicroF1_sparsity_<=1.0                   10                0.8693           min
#       Acc_sparsity_<=1.0                   10                0.8693           max
#        AP_sparsity_<=1.0                   10                0.8525           max
#                     RMSE                   10                1.0717           min
#                      MAE                   10                0.9644           min
#                     MAPE                   10                0.8109           min
#            RMSE_BURGLARY                   10                1.0073           min
#             MAE_BURGLARY                   10                0.9602           min
#            MAPE_BURGLARY                   10                0.8887           min
#      RMSE_FELONY ASSAULT                   10                1.0472           min
#       MAE_FELONY ASSAULT                   10                0.9533           min
#      MAPE_FELONY ASSAULT                   10                0.8166           min
#       RMSE_GRAND LARCENY                   10                1.1159           min
#        MAE_GRAND LARCENY                   10                0.9653           min
#       MAPE_GRAND LARCENY                   10                0.7534           min
#             RMSE_ROBBERY                   10                1.0433           min
#              MAE_ROBBERY                   10                0.9793           min
#             MAPE_ROBBERY                   10                0.8791           min
#     RMSE_sparsity_<=0.25                   10                1.0090           min
#      MAE_sparsity_<=0.25                   10                0.9626           min
#     MAPE_sparsity_<=0.25                   10                0.8900           min
#      RMSE_sparsity_<=0.5                   10                1.0850           min
#       MAE_sparsity_<=0.5                   10                0.9532           min
#      MAPE_sparsity_<=0.5                   10                0.7564           min
#     RMSE_sparsity_<=0.75                   10                0.9762           min
#      MAE_sparsity_<=0.75                   10                0.6982           min
#     MAPE_sparsity_<=0.75                   10                0.3878           min
#      RMSE_sparsity_<=1.0                   10                1.6275           min
#       MAE_sparsity_<=1.0                   10                1.2427           min
#      MAPE_sparsity_<=1.0                   10                0.5163           min
#                epochLoss                   10               11.4687           min
#
# Saved: /home/jovyan/STHSL/tests_validation/baseline/NYC_5km/metrics_all_epochs_pivot_ranking_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/NYC_5km/metrics_all_epochs_pivot_ranking_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/NYC_5km/metrics_all_epochs_pivot_summary_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/NYC_5km/metrics_all_epochs_pivot_summary_overall_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/NYC_5km/metrics_all_epochs_pivot_ranking_best_seed_by_avg.csv

# %%
# !python train.py --data NYC_5km --use_ode_option option1 --device cuda --eval_metrics all --batch 16 --n_traj_samples 2 --ode_method dopri5 --odeint_atol 0.01 --odeint_rtol 0.0001 --gen_layers 2 --gen_dim 64 --gcn_step 2 --horizon 12
step_move_checkpoints("NYC_5km", "option1", on_conflict="overwrite")
# !python metrics_generation.py --data NYC_5km --use_ode_option option1 --device cuda --eval_metrics all --batch 16 --n_traj_samples 2 --ode_method dopri5 --odeint_atol 0.01 --odeint_rtol 0.0001 --gen_layers 2 --gen_dim 64 --gcn_step 2 --horizon 12 --save-root Logs/option1 --out-dir tests_validation/option1/NYC_5km 
step_metrics_extraction("NYC_5km", "option1")
step_analyse("NYC_5km", "option1")
# Out:
# self.predir Datasets/common_data/NYC_crime_5km/
# (100, 153, 4)
# Row: 10 , Col: 10
# Sparsity: 0.041750457038391225
# use_ode_option: option1
# ODE option 1 is enabled, STHSL model with option1 components is initialized
# ODE setting --latent 16 --samples 2 --method dopri5                 --atol 0.010000 --rtol 0.000100 --gen_layer 2 --gen_dim 64 --num_nodes 100
# DEBUG SHAPES status: True
#
# ===== SEED 10 =====
# start training...
# ===== TRAINING ARGS =====
# lr: 0.001
# weight_decay: 0.0001
# cr: 0.8
# ir: 1
# t: 0.05
# batch: 16
# epoch: 1
# latdim: 16
# temporalRange: 30
# cateNum: 4
# data: NYC_5km
# kernelSize: 3
# border: 0.5
# hyperNum: 128
# dropRateL: 0.2
# dropRateG: 0.1
# use_ode_option: option1
# n_traj_samples: 2
# ode_method: dopri5
# odeint_atol: 0.01
# odeint_rtol: 0.0001
# gen_layers: 2
# gen_dim: 64
# save_latent: false
# gcn_step: 2
# rnn_units: 64
# horizon: 12
# filter_type: 2
# device: cuda
# tstEpoch: 1
# save: ./Save/
# checkpoint: ./Save/NYC/
# eval_metrics: all
# f1_label_threshold: 0.0
# f1_pred_threshold: 0.5
# seeds: [10]
# row: 10
# col: 10
# offNum: 4
# areaNum: 100
# trnDays: 547
# valDays: 31
# tstDays: 153
# decay_step: 34
# ==========================
# time grid: torch.Size([12])
# n_traj_samples: 2
# Decoder input Z_t shape: torch.Size([16, 400, 64])
# Labels shape: torch.Size([16, 100, 4])
# Epoch  1 Training Time 6.265s
# Epoch 1/1, Train Loss =  5.9616,  preLoss =  5.2065
# Val (MicroF1+MacroF1) increase from -1.0000 to 1.5499
# Epoch 1/1, Test: MacroF1 = 0.6050, MicroF1 = 0.9572, AP = 0.2932, Acc = 0.9572, MacroF1_cate_0 = 0.4934, MicroF1_cate_0 = 0.9740, Acc_cate_0 = 0.9740, AP_cate_0 = 0.0631, MacroF1_cate_1 = 0.4948, MicroF1_cate_1 = 0.9605, Acc_cate_1 = 0.9605, AP_cate_1 = 0.1958, MacroF1_cate_2 = 0.6850, MicroF1_cate_2 = 0.9261, Acc_cate_2 = 0.9261, AP_cate_2 = 0.4643, MacroF1_cate_3 = 0.4939, MicroF1_cate_3 = 0.9681, Acc_cate_3 = 0.9681, AP_cate_3 = 0.1223, MacroF1_over_categories = 0.5418, MicroF1_over_categories = 0.9572, MacroAP_over_categories = 0.2114, MacroAcc_over_categories = 0.9572, MacroF1_mask_1 = 0.4867, MicroF1_mask_1 = 0.9319, Acc_mask_1 = 0.9319, AP_mask_1 = 0.1141, MacroF1_mask_2 = 0.5051, MicroF1_mask_2 = 0.6193, Acc_mask_2 = 0.6193, AP_mask_2 = 0.3922, MacroF1_mask_3 = 0.4040, MicroF1_mask_3 = 0.5752, Acc_mask_3 = 0.5752, AP_mask_3 = 0.6077, MacroF1_mask_4 = 0.4669, MicroF1_mask_4 = 0.8758, Acc_mask_4 = 0.8758, AP_mask_4 = 0.8593, MacroF1_cate_0_mask_1 = 0.4832, MicroF1_cate_0_mask_1 = 0.9350, Acc_cate_0_mask_1 = 0.9350, AP_cate_0_mask_1 = 0.1017, MacroF1_cate_0_mask_2 = nan, MicroF1_cate_0_mask_2 = 0.0000, Acc_cate_0_mask_2 = nan, AP_cate_0_mask_2 = nan, MacroF1_cate_0_mask_3 = nan, MicroF1_cate_0_mask_3 = 0.0000, Acc_cate_0_mask_3 = nan, AP_cate_0_mask_3 = nan, MacroF1_cate_0_mask_4 = nan, MicroF1_cate_0_mask_4 = 0.0000, Acc_cate_0_mask_4 = nan, AP_cate_0_mask_4 = nan, MacroF1_cate_1_mask_1 = 0.4818, MicroF1_cate_1_mask_1 = 0.9296, Acc_cate_1_mask_1 = 0.9296, AP_cate_1_mask_1 = 0.1099, MacroF1_cate_1_mask_2 = 0.3997, MicroF1_cate_1_mask_2 = 0.6231, Acc_cate_1_mask_2 = 0.6231, AP_cate_1_mask_2 = 0.4226, MacroF1_cate_1_mask_3 = nan, MicroF1_cate_1_mask_3 = 0.0000, Acc_cate_1_mask_3 = nan, AP_cate_1_mask_3 = nan, MacroF1_cate_1_mask_4 = nan, MicroF1_cate_1_mask_4 = 0.0000, Acc_cate_1_mask_4 = nan, AP_cate_1_mask_4 = nan, MacroF1_cate_2_mask_1 = 0.4956, MicroF1_cate_2_mask_1 = 0.9223, Acc_cate_2_mask_1 = 0.9223, AP_cate_2_mask_1 = 0.1445, MacroF1_cate_2_mask_2 = 0.5278, MicroF1_cate_2_mask_2 = 0.5954, Acc_cate_2_mask_2 = 0.5954, AP_cate_2_mask_2 = 0.4055, MacroF1_cate_2_mask_3 = 0.4040, MicroF1_cate_2_mask_3 = 0.5752, Acc_cate_2_mask_3 = 0.5752, AP_cate_2_mask_3 = 0.6077, MacroF1_cate_2_mask_4 = 0.4669, MicroF1_cate_2_mask_4 = 0.8758, Acc_cate_2_mask_4 = 0.8758, AP_cate_2_mask_4 = 0.8593, MacroF1_cate_3_mask_1 = 0.4846, MicroF1_cate_3_mask_1 = 0.9401, Acc_cate_3_mask_1 = 0.9401, AP_cate_3_mask_1 = 0.1079, MacroF1_cate_3_mask_2 = 0.4168, MicroF1_cate_3_mask_2 = 0.6950, Acc_cate_3_mask_2 = 0.6950, AP_cate_3_mask_2 = 0.3246, MacroF1_cate_3_mask_3 = nan, MicroF1_cate_3_mask_3 = 0.0000, Acc_cate_3_mask_3 = nan, AP_cate_3_mask_3 = nan, MacroF1_cate_3_mask_4 = nan, MicroF1_cate_3_mask_4 = 0.0000, Acc_cate_3_mask_4 = nan, AP_cate_3_mask_4 = nan, RMSE = 1.0883, MAE = 0.9705, MAPE = 0.8095, RMSE_cate_0 = 1.0712, MAE_cate_0 = 1.0272, MAPE_cate_0 = 0.9518, RMSE_cate_1 = 1.1304, MAE_cate_1 = 1.0507, MAPE_cate_1 = 0.9070, RMSE_cate_2 = 1.0800, MAE_cate_2 = 0.8930, MAPE_cate_2 = 0.6706, RMSE_cate_3 = 1.0687, MAE_cate_3 = 1.0115, MAPE_cate_3 = 0.9074, RMSE_mask_1 = 1.0316, MAE_mask_1 = 0.9880, MAPE_mask_1 = 0.9137, RMSE_mask_2 = 1.0451, MAE_mask_2 = 0.9006, MAPE_mask_2 = 0.7094, RMSE_mask_3 = 1.0901, MAE_mask_3 = 0.8076, MAPE_mask_3 = 0.4477, RMSE_mask_4 = 1.7861, MAE_mask_4 = 1.3200, MAPE_mask_4 = 0.4631, epochLoss = 1.1802
# MacroF1=0.6050 MicroF1=0.9572 AP=0.2932
#
#   [RUNTIME] Epoch 1: train=6.26s | train+eval=7.45s
#
# ============================================================
# RUNTIME ANALYSIS SUMMARY (STHSL)
# ============================================================
#   Seed:                      10
#   Epochs run:                1
#   Avg train time/epoch:      6.26s (+/- 0.00s)
#   Avg total time/epoch:      7.45s (+/- 0.00s)
#   Per-epoch train times:     ['6.26']
#   Total training time:       7.45s
# ============================================================
#
# Epoch 1/1, Best: MacroF1 = 0.6050, MicroF1 = 0.9572, AP = 0.2932, Acc = 0.9572, MacroF1_cate_0 = 0.4934, MicroF1_cate_0 = 0.9740, Acc_cate_0 = 0.9740, AP_cate_0 = 0.0631, MacroF1_cate_1 = 0.4948, MicroF1_cate_1 = 0.9605, Acc_cate_1 = 0.9605, AP_cate_1 = 0.1958, MacroF1_cate_2 = 0.6850, MicroF1_cate_2 = 0.9261, Acc_cate_2 = 0.9261, AP_cate_2 = 0.4643, MacroF1_cate_3 = 0.4939, MicroF1_cate_3 = 0.9681, Acc_cate_3 = 0.9681, AP_cate_3 = 0.1223, MacroF1_over_categories = 0.5418, MicroF1_over_categories = 0.9572, MacroAP_over_categories = 0.2114, MacroAcc_over_categories = 0.9572, MacroF1_mask_1 = 0.4867, MicroF1_mask_1 = 0.9319, Acc_mask_1 = 0.9319, AP_mask_1 = 0.1141, MacroF1_mask_2 = 0.5051, MicroF1_mask_2 = 0.6193, Acc_mask_2 = 0.6193, AP_mask_2 = 0.3922, MacroF1_mask_3 = 0.4040, MicroF1_mask_3 = 0.5752, Acc_mask_3 = 0.5752, AP_mask_3 = 0.6077, MacroF1_mask_4 = 0.4669, MicroF1_mask_4 = 0.8758, Acc_mask_4 = 0.8758, AP_mask_4 = 0.8593, MacroF1_cate_0_mask_1 = 0.4832, MicroF1_cate_0_mask_1 = 0.9350, Acc_cate_0_mask_1 = 0.9350, AP_cate_0_mask_1 = 0.1017, MacroF1_cate_0_mask_2 = nan, MicroF1_cate_0_mask_2 = 0.0000, Acc_cate_0_mask_2 = nan, AP_cate_0_mask_2 = nan, MacroF1_cate_0_mask_3 = nan, MicroF1_cate_0_mask_3 = 0.0000, Acc_cate_0_mask_3 = nan, AP_cate_0_mask_3 = nan, MacroF1_cate_0_mask_4 = nan, MicroF1_cate_0_mask_4 = 0.0000, Acc_cate_0_mask_4 = nan, AP_cate_0_mask_4 = nan, MacroF1_cate_1_mask_1 = 0.4818, MicroF1_cate_1_mask_1 = 0.9296, Acc_cate_1_mask_1 = 0.9296, AP_cate_1_mask_1 = 0.1099, MacroF1_cate_1_mask_2 = 0.3997, MicroF1_cate_1_mask_2 = 0.6231, Acc_cate_1_mask_2 = 0.6231, AP_cate_1_mask_2 = 0.4226, MacroF1_cate_1_mask_3 = nan, MicroF1_cate_1_mask_3 = 0.0000, Acc_cate_1_mask_3 = nan, AP_cate_1_mask_3 = nan, MacroF1_cate_1_mask_4 = nan, MicroF1_cate_1_mask_4 = 0.0000, Acc_cate_1_mask_4 = nan, AP_cate_1_mask_4 = nan, MacroF1_cate_2_mask_1 = 0.4956, MicroF1_cate_2_mask_1 = 0.9223, Acc_cate_2_mask_1 = 0.9223, AP_cate_2_mask_1 = 0.1445, MacroF1_cate_2_mask_2 = 0.5278, MicroF1_cate_2_mask_2 = 0.5954, Acc_cate_2_mask_2 = 0.5954, AP_cate_2_mask_2 = 0.4055, MacroF1_cate_2_mask_3 = 0.4040, MicroF1_cate_2_mask_3 = 0.5752, Acc_cate_2_mask_3 = 0.5752, AP_cate_2_mask_3 = 0.6077, MacroF1_cate_2_mask_4 = 0.4669, MicroF1_cate_2_mask_4 = 0.8758, Acc_cate_2_mask_4 = 0.8758, AP_cate_2_mask_4 = 0.8593, MacroF1_cate_3_mask_1 = 0.4846, MicroF1_cate_3_mask_1 = 0.9401, Acc_cate_3_mask_1 = 0.9401, AP_cate_3_mask_1 = 0.1079, MacroF1_cate_3_mask_2 = 0.4168, MicroF1_cate_3_mask_2 = 0.6950, Acc_cate_3_mask_2 = 0.6950, AP_cate_3_mask_2 = 0.3246, MacroF1_cate_3_mask_3 = nan, MicroF1_cate_3_mask_3 = 0.0000, Acc_cate_3_mask_3 = nan, AP_cate_3_mask_3 = nan, MacroF1_cate_3_mask_4 = nan, MicroF1_cate_3_mask_4 = 0.0000, Acc_cate_3_mask_4 = nan, AP_cate_3_mask_4 = nan, RMSE = 1.0883, MAE = 0.9705, MAPE = 0.8095, RMSE_cate_0 = 1.0712, MAE_cate_0 = 1.0272, MAPE_cate_0 = 0.9518, RMSE_cate_1 = 1.1304, MAE_cate_1 = 1.0507, MAPE_cate_1 = 0.9070, RMSE_cate_2 = 1.0800, MAE_cate_2 = 0.8930, MAPE_cate_2 = 0.6706, RMSE_cate_3 = 1.0687, MAE_cate_3 = 1.0115, MAPE_cate_3 = 0.9074, RMSE_mask_1 = 1.0316, MAE_mask_1 = 0.9880, MAPE_mask_1 = 0.9137, RMSE_mask_2 = 1.0451, MAE_mask_2 = 0.9006, MAPE_mask_2 = 0.7094, RMSE_mask_3 = 1.0901, MAE_mask_3 = 0.8076, MAPE_mask_3 = 0.4477, RMSE_mask_4 = 1.7861, MAE_mask_4 = 1.3200, MAPE_mask_4 = 0.4631, epochLoss = 1.1802
#
# ===== SUMMARY: best result per seed =====
# seed=10: {'MacroF1': 0.6050131475262469, 'MicroF1': 0.9571732026143791, 'AP': 0.29322679414496267, 'Acc': 0.9571732026143791, 'MacroF1_cate_0': 0.49341103238196143, 'MicroF1_cate_0': 0.9739869281045752, 'Acc_cate_0': 0.9739869281045752, 'AP_cate_0': 0.0630813320113044, 'MacroF1_cate_1': 0.4948480094457715, 'MicroF1_cate_1': 0.9605228758169935, 'Acc_cate_1': 0.9605228758169935, 'AP_cate_1': 0.1958341655972707, 'MacroF1_cate_2': 0.6849856025952192, 'MicroF1_cate_2': 0.926078431372549, 'Acc_cate_2': 0.926078431372549, 'AP_cate_2': 0.46428298255987216, 'MacroF1_cate_3': 0.4939371962667498, 'MicroF1_cate_3': 0.9681045751633987, 'Acc_cate_3': 0.9681045751633987, 'AP_cate_3': 0.12228983246899304, 'MacroF1_over_categories': 0.5417954601724255, 'MicroF1_over_categories': 0.957173202614379, 'MacroAP_over_categories': 0.21137207815936007, 'MacroAcc_over_categories': 0.957173202614379, 'MacroF1_mask_1': 0.4866882318995279, 'MicroF1_mask_1': 0.9318818436465496, 'Acc_mask_1': 0.9318818436465496, 'AP_mask_1': 0.11405814083105373, 'MacroF1_mask_2': 0.5050606022741472, 'MicroF1_mask_2': 0.619281045751634, 'Acc_mask_2': 0.619281045751634, 'AP_mask_2': 0.3921524051354406, 'MacroF1_mask_3': 0.40395564878633505, 'MicroF1_mask_3': 0.5751633986928104, 'Acc_mask_3': 0.5751633986928104, 'AP_mask_3': 0.6076881692450624, 'MacroF1_mask_4': 0.46689895470383275, 'MicroF1_mask_4': 0.8758169934640523, 'Acc_mask_4': 0.8758169934640523, 'AP_mask_4': 0.8592962996261029, 'MacroF1_cate_0_mask_1': 0.4831954061813883, 'MicroF1_cate_0_mask_1': 0.9349673202614379, 'Acc_cate_0_mask_1': 0.9349673202614379, 'AP_cate_0_mask_1': 0.1016942568296805, 'MacroF1_cate_0_mask_2': nan, 'MicroF1_cate_0_mask_2': 0.0, 'Acc_cate_0_mask_2': nan, 'AP_cate_0_mask_2': nan, 'MacroF1_cate_0_mask_3': nan, 'MicroF1_cate_0_mask_3': 0.0, 'Acc_cate_0_mask_3': nan, 'AP_cate_0_mask_3': nan, 'MacroF1_cate_0_mask_4': nan, 'MicroF1_cate_0_mask_4': 0.0, 'Acc_cate_0_mask_4': nan, 'AP_cate_0_mask_4': nan, 'MacroF1_cate_1_mask_1': 0.4817512067067491, 'MicroF1_cate_1_mask_1': 0.9295751633986928, 'Acc_cate_1_mask_1': 0.9295751633986928, 'AP_cate_1_mask_1': 0.10986295516756008, 'MacroF1_cate_1_mask_2': 0.39970970887731416, 'MicroF1_cate_1_mask_2': 0.6230936819172114, 'Acc_cate_1_mask_2': 0.6230936819172114, 'AP_cate_1_mask_2': 0.42260524565894764, 'MacroF1_cate_1_mask_3': nan, 'MicroF1_cate_1_mask_3': 0.0, 'Acc_cate_1_mask_3': nan, 'AP_cate_1_mask_3': nan, 'MacroF1_cate_1_mask_4': nan, 'MicroF1_cate_1_mask_4': 0.0, 'Acc_cate_1_mask_4': nan, 'AP_cate_1_mask_4': nan, 'MacroF1_cate_2_mask_1': 0.4955987836638489, 'MicroF1_cate_2_mask_1': 0.9222948438634713, 'Acc_cate_2_mask_1': 0.9222948438634713, 'AP_cate_2_mask_1': 0.14445419627408937, 'MacroF1_cate_2_mask_2': 0.5278010868248292, 'MicroF1_cate_2_mask_2': 0.5954248366013072, 'Acc_cate_2_mask_2': 0.5954248366013072, 'AP_cate_2_mask_2': 0.40546576575776705, 'MacroF1_cate_2_mask_3': 0.40395564878633505, 'MicroF1_cate_2_mask_3': 0.5751633986928104, 'Acc_cate_2_mask_3': 0.5751633986928104, 'AP_cate_2_mask_3': 0.6076881692450624, 'MacroF1_cate_2_mask_4': 0.46689895470383275, 'MicroF1_cate_2_mask_4': 0.8758169934640523, 'Acc_cate_2_mask_4': 0.8758169934640523, 'AP_cate_2_mask_4': 0.8592962996261029, 'MacroF1_cate_3_mask_1': 0.4845744680851064, 'MicroF1_cate_3_mask_1': 0.9401444788441693, 'Acc_cate_3_mask_1': 0.9401444788441693, 'AP_cate_3_mask_1': 0.10788274516683102, 'MacroF1_cate_3_mask_2': 0.41683606795411643, 'MicroF1_cate_3_mask_2': 0.6949891067538126, 'Acc_cate_3_mask_2': 0.6949891067538126, 'AP_cate_3_mask_2': 0.3245636891061064, 'MacroF1_cate_3_mask_3': nan, 'MicroF1_cate_3_mask_3': 0.0, 'Acc_cate_3_mask_3': nan, 'AP_cate_3_mask_3': nan, 'MacroF1_cate_3_mask_4': nan, 'MicroF1_cate_3_mask_4': 0.0, 'Acc_cate_3_mask_4': nan, 'AP_cate_3_mask_4': nan, 'RMSE': 1.0883071439370353, 'MAE': 0.970473597613593, 'MAPE': 0.8094711254509795, 'RMSE_cate_0': 1.0712285182988774, 'MAE_cate_0': 1.0272455582881916, 'MAPE_cate_0': 0.9517707956395012, 'RMSE_cate_1': 1.130410467967 ...
# Total time spent: 8.2629
# Detected seed folders under /home/jovyan/STHSL/Save/NYC_5km
#
# Checkpoint move completed (NYC_5km / option1)
#   Mode     : seed-aware
#   Moved    : 1
#   Skipped  : 0
# Found 1 checkpoints under Logs/option1/NYC_5km (seed folders) (sorted by seed, epoch).
#
# [seed 10 epoch 1] Running: /opt/conda/bin/python test.py --data NYC_5km --use_ode_option option1 --checkpoint Logs/option1/NYC_5km/seed_10/_seed_10_epoch_1_MAE_0.97_MAPE_0.81_MicroF1_0.9572.pth --batch 16 --eval_metrics all --n_traj_samples 2 --ode_method dopri5 --odeint_atol 0.01 --odeint_rtol 0.0001 --gen_layers 2 --gen_dim 64 --gcn_step 2 --rnn_units 64 --horizon 12 --filter_type 2
# [seed 10 epoch 1] Writing: tests_validation/option1/NYC_5km/seed_10_epoch_1_main.txt
# [seed 10 epoch 1] OK
# \n$ python /home/jovyan/STHSL/metrics_extraction.py /home/jovyan/STHSL/tests_validation/option1/NYC_5km --city nyc
#
# Reading folder: /home/jovyan/STHSL/tests_validation/option1/NYC_5km
#
# City: nyc — using category map: {'0': 'BURGLARY', '1': 'FELONY ASSAULT', '2': 'GRAND LARCENY', '3': 'ROBBERY'}
# Processing seed10_epoch1: seed_10_epoch_1_main.txt
#
# Created: /home/jovyan/STHSL/tests_validation/option1/NYC_5km/metrics_all_epochs_pivot.csv
#
#                       seed10_epoch1  seed_avg_seed10  all_seeds_avg
# MacroF1                      0.6050           0.6050         0.6050
# MicroF1                      0.9572           0.9572         0.9572
# AP                           0.2932           0.2932         0.2932
# Acc                          0.9572           0.9572         0.9572
# MacroF1_BURGLARY             0.4934           0.4934         0.4934
# ...                             ...              ...            ...
# MAPE_sparsity_<=0.75         0.4477           0.4477         0.4477
# RMSE_sparsity_<=1.0          1.7861           1.7861         1.7861
# MAE_sparsity_<=1.0           1.3200           1.3200         1.3200
# MAPE_sparsity_<=1.0          0.4631           0.4631         0.4631
# epochLoss                   11.8023          11.8023        11.8023
#
# [67 rows x 3 columns]
#
# Running: python /home/jovyan/STHSL/analyse_metrics.py /home/jovyan/STHSL/tests_validation/option1/NYC_5km/metrics_all_epochs_pivot.csv
#
# ==============================
# BEST (SEED, EPOCH) PER METRIC (across all seeds/epochs)
# ==============================
#
#                   Metric  BestSeed  BestEpoch  BestValue Goal(min/max)
#                  MacroF1        10          1     0.6050           max
#                  MicroF1        10          1     0.9572           max
#                       AP        10          1     0.2932           max
#                      Acc        10          1     0.9572           max
#         MacroF1_BURGLARY        10          1     0.4934           min
#         MicroF1_BURGLARY        10          1     0.9740           min
#             Acc_BURGLARY        10          1     0.9740           max
#              AP_BURGLARY        10          1     0.0631           max
#   MacroF1_FELONY ASSAULT        10          1     0.4948           min
#   MicroF1_FELONY ASSAULT        10          1     0.9605           min
#       Acc_FELONY ASSAULT        10          1     0.9605           max
#        AP_FELONY ASSAULT        10          1     0.1958           max
#    MacroF1_GRAND LARCENY        10          1     0.6850           min
#    MicroF1_GRAND LARCENY        10          1     0.9261           min
#        Acc_GRAND LARCENY        10          1     0.9261           max
#         AP_GRAND LARCENY        10          1     0.4643           max
#          MacroF1_ROBBERY        10          1     0.4939           min
#          MicroF1_ROBBERY        10          1     0.9681           min
#              Acc_ROBBERY        10          1     0.9681           max
#               AP_ROBBERY        10          1     0.1223           max
#  MacroF1_over_categories        10          1     0.5418           max
#  MacroAP_over_categories        10          1     0.2114           max
# MacroAcc_over_categories        10          1     0.9572           max
#  MacroF1_sparsity_<=0.25        10          1     0.4867           min
#  MicroF1_sparsity_<=0.25        10          1     0.9319           min
#      Acc_sparsity_<=0.25        10          1     0.9319           max
#       AP_sparsity_<=0.25        10          1     0.1141           max
#   MacroF1_sparsity_<=0.5        10          1     0.5051           min
#   MicroF1_sparsity_<=0.5        10          1     0.6193           min
#       Acc_sparsity_<=0.5        10          1     0.6193           max
#        AP_sparsity_<=0.5        10          1     0.3922           max
#  MacroF1_sparsity_<=0.75        10          1     0.4040           min
#  MicroF1_sparsity_<=0.75        10          1     0.5752           min
#      Acc_sparsity_<=0.75        10          1     0.5752           max
#       AP_sparsity_<=0.75        10          1     0.6077           max
#   MacroF1_sparsity_<=1.0        10          1     0.4669           min
#   MicroF1_sparsity_<=1.0        10          1     0.8758           min
#       Acc_sparsity_<=1.0        10          1     0.8758           max
#        AP_sparsity_<=1.0        10          1     0.8593           max
#                     RMSE        10          1     1.0883           min
#                      MAE        10          1     0.9705           min
#                     MAPE        10          1     0.8095           min
#            RMSE_BURGLARY        10          1     1.0712           min
#             MAE_BURGLARY        10          1     1.0272           min
#            MAPE_BURGLARY        10          1     0.9518           min
#      RMSE_FELONY ASSAULT        10          1     1.1304           min
#       MAE_FELONY ASSAULT        10          1     1.0507           min
#      MAPE_FELONY ASSAULT        10          1     0.9070           min
#       RMSE_GRAND LARCENY        10          1     1.0800           min
#        MAE_GRAND LARCENY        10          1     0.8930           min
#       MAPE_GRAND LARCENY        10          1     0.6706           min
#             RMSE_ROBBERY        10          1     1.0687           min
#              MAE_ROBBERY        10          1     1.0115           min
#             MAPE_ROBBERY        10          1     0.9074           min
#     RMSE_sparsity_<=0.25        10          1     1.0316           min
#      MAE_sparsity_<=0.25        10          1     0.9880           min
#     MAPE_sparsity_<=0.25        10          1     0.9137           min
#      RMSE_sparsity_<=0.5        10          1     1.0451           min
#       MAE_sparsity_<=0.5        10          1     0.9006           min
#      MAPE_sparsity_<=0.5        10          1     0.7094           min
#     RMSE_sparsity_<=0.75        10          1     1.0901           min
#      MAE_sparsity_<=0.75        10          1     0.8076           min
#     MAPE_sparsity_<=0.75        10          1     0.4477           min
#      RMSE_sparsity_<=1.0        10          1     1.7861           min
#       MAE_sparsity_<=1.0        10          1     1.3200           min
#      MAPE_sparsity_<=1.0        10          1     0.4631           min
#                epochLoss        10          1    11.8023           min
#
# ==============================
# OVERALL BEST (SEED, EPOCH) BY 'MOST METRICS WON'
# ==============================
# Best (seed, epoch) overall: seed=10 epoch=1 (wins 67 metrics)
#
#
# ==============================
# OVERALL BEST EPOCH WITHIN EACH SEED (wins across metrics)
# ==============================
#
#  Seed  OverallBestEpochWithinSeed  WinsCount
#    10                           1         67
#
# ==============================
# BEST SEED BY AVERAGE-OVER-EPOCHS (per metric)
# ==============================
#
#                   Metric  BestSeedByAvgEpochs  BestValueByAvgEpochs Goal(min/max)
#                  MacroF1                   10                0.6050           max
#                  MicroF1                   10                0.9572           max
#                       AP                   10                0.2932           max
#                      Acc                   10                0.9572           max
#         MacroF1_BURGLARY                   10                0.4934           min
#         MicroF1_BURGLARY                   10                0.9740           min
#             Acc_BURGLARY                   10                0.9740           max
#              AP_BURGLARY                   10                0.0631           max
#   MacroF1_FELONY ASSAULT                   10                0.4948           min
#   MicroF1_FELONY ASSAULT                   10                0.9605           min
#       Acc_FELONY ASSAULT                   10                0.9605           max
#        AP_FELONY ASSAULT                   10                0.1958           max
#    MacroF1_GRAND LARCENY                   10                0.6850           min
#    MicroF1_GRAND LARCENY                   10                0.9261           min
#        Acc_GRAND LARCENY                   10                0.9261           max
#         AP_GRAND LARCENY                   10                0.4643           max
#          MacroF1_ROBBERY                   10                0.4939           min
#          MicroF1_ROBBERY                   10                0.9681           min
#              Acc_ROBBERY                   10                0.9681           max
#               AP_ROBBERY                   10                0.1223           max
#  MacroF1_over_categories                   10                0.5418           max
#  MacroAP_over_categories                   10                0.2114           max
# MacroAcc_over_categories                   10                0.9572           max
#  MacroF1_sparsity_<=0.25                   10                0.4867           min
#  MicroF1_sparsity_<=0.25                   10                0.9319           min
#      Acc_sparsity_<=0.25                   10                0.9319           max
#       AP_sparsity_<=0.25                   10                0.1141           max
#   MacroF1_sparsity_<=0.5                   10                0.5051           min
#   MicroF1_sparsity_<=0.5                   10                0.6193           min
#       Acc_sparsity_<=0.5                   10                0.6193           max
#        AP_sparsity_<=0.5                   10                0.3922           max
#  MacroF1_sparsity_<=0.75                   10                0.4040           min
#  MicroF1_sparsity_<=0.75                   10                0.5752           min
#      Acc_sparsity_<=0.75                   10                0.5752           max
#       AP_sparsity_<=0.75                   10                0.6077           max
#   MacroF1_sparsity_<=1.0                   10                0.4669           min
#   MicroF1_sparsity_<=1.0                   10                0.8758           min
#       Acc_sparsity_<=1.0                   10                0.8758           max
#        AP_sparsity_<=1.0                   10                0.8593           max
#                     RMSE                   10                1.0883           min
#                      MAE                   10                0.9705           min
#                     MAPE                   10                0.8095           min
#            RMSE_BURGLARY                   10                1.0712           min
#             MAE_BURGLARY                   10                1.0272           min
#            MAPE_BURGLARY                   10                0.9518           min
#      RMSE_FELONY ASSAULT                   10                1.1304           min
#       MAE_FELONY ASSAULT                   10                1.0507           min
#      MAPE_FELONY ASSAULT                   10                0.9070           min
#       RMSE_GRAND LARCENY                   10                1.0800           min
#        MAE_GRAND LARCENY                   10                0.8930           min
#       MAPE_GRAND LARCENY                   10                0.6706           min
#             RMSE_ROBBERY                   10                1.0687           min
#              MAE_ROBBERY                   10                1.0115           min
#             MAPE_ROBBERY                   10                0.9074           min
#     RMSE_sparsity_<=0.25                   10                1.0316           min
#      MAE_sparsity_<=0.25                   10                0.9880           min
#     MAPE_sparsity_<=0.25                   10                0.9137           min
#      RMSE_sparsity_<=0.5                   10                1.0451           min
#       MAE_sparsity_<=0.5                   10                0.9006           min
#      MAPE_sparsity_<=0.5                   10                0.7094           min
#     RMSE_sparsity_<=0.75                   10                1.0901           min
#      MAE_sparsity_<=0.75                   10                0.8076           min
#     MAPE_sparsity_<=0.75                   10                0.4477           min
#      RMSE_sparsity_<=1.0                   10                1.7861           min
#       MAE_sparsity_<=1.0                   10                1.3200           min
#      MAPE_sparsity_<=1.0                   10                0.4631           min
#                epochLoss                   10               11.8023           min
#
# Saved: /home/jovyan/STHSL/tests_validation/option1/NYC_5km/metrics_all_epochs_pivot_ranking_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/NYC_5km/metrics_all_epochs_pivot_ranking_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/NYC_5km/metrics_all_epochs_pivot_summary_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/NYC_5km/metrics_all_epochs_pivot_summary_overall_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/NYC_5km/metrics_all_epochs_pivot_ranking_best_seed_by_avg.csv

# %%
# !python train.py --data NYC_5km --use_ode_option option2 --device cuda --eval_metrics all --batch 16 --n_traj_samples 1 --ode_method dopri5 --odeint_atol 0.001 --odeint_rtol 0.001 --gen_layers 1 --gen_dim 64 --gcn_step 1 --horizon 12
# step_move_checkpoints("NYC_5km", "option2", on_conflict="overwrite")
# !python metrics_generation.py --data NYC_5km --use_ode_option option2 --device cuda --eval_metrics all --batch 16 --n_traj_samples 1 --ode_method dopri5 --odeint_atol 0.001 --odeint_rtol 0.001 --gen_layers 1 --gen_dim 64 --gcn_step 1 --horizon 12 --out-dir tests_validation/option2/NYC_5km --save-root Logs/option2
# step_metrics_extraction("NYC_5km", "option2")
# step_analyse("NYC_5km", "option2")

# %%
# !python train.py --data CHI_5km --use_ode_option baseline --device cuda --eval_metrics all --batch 16
step_move_checkpoints("CHI_5km", "baseline", on_conflict="overwrite")
# !python metrics_generation.py --data CHI_5km --use_ode_option baseline --device cuda --eval_metrics all --batch 16 --out-dir tests_validation/baseline/CHI_5km --save-root Logs/baseline
step_metrics_extraction("CHI_5km", "baseline")
step_analyse("CHI_5km", "baseline")
# Out:
# self.predir Datasets/common_data/CHI_crime_5km/
# (63, 153, 4)
# Row: 9 , Col: 7
# Sparsity: 0.39399611154638575
# use_ode_option: baseline
# ODE is not enabled, baseline STHSL model is initialized
# DEBUG SHAPES status: True
#
# ===== SEED 10 =====
# start training...
# ===== TRAINING ARGS =====
# lr: 0.001
# weight_decay: 0.0001
# cr: 0.8
# ir: 1
# t: 0.05
# batch: 16
# epoch: 1
# latdim: 16
# temporalRange: 30
# cateNum: 4
# data: CHI_5km
# kernelSize: 3
# border: 0.5
# hyperNum: 128
# dropRateL: 0.2
# dropRateG: 0.1
# use_ode_option: baseline
# n_traj_samples: 1
# ode_method: dopri5
# odeint_atol: 0.0001
# odeint_rtol: 0.001
# gen_layers: 1
# gen_dim: 64
# save_latent: false
# gcn_step: 2
# rnn_units: 64
# horizon: 12
# filter_type: 2
# device: cuda
# tstEpoch: 1
# save: ./Save/
# checkpoint: ./Save/NYC/
# eval_metrics: all
# f1_label_threshold: 0.0
# f1_pred_threshold: 0.5
# seeds: [10]
# row: 9
# col: 7
# offNum: 4
# areaNum: 63
# trnDays: 547
# valDays: 31
# tstDays: 153
# decay_step: 34
# ==========================
# Epoch  1 Training Time 2.148s
# Epoch 1/1, Train Loss =  22.2314,  preLoss =  11.0614
# Val (MicroF1+MacroF1) increase from -1.0000 to 1.3464
# Epoch 1/1, Test: MacroF1 = 0.6692, MicroF1 = 0.6710, AP = 0.8850, Acc = 0.6710, MacroF1_cate_0 = 0.5907, MicroF1_cate_0 = 0.5912, Acc_cate_0 = 0.5912, AP_cate_0 = 0.6961, MacroF1_cate_1 = 0.6642, MicroF1_cate_1 = 0.6711, Acc_cate_1 = 0.6711, AP_cate_1 = 0.9205, MacroF1_cate_2 = 0.7357, MicroF1_cate_2 = 0.7358, Acc_cate_2 = 0.7358, AP_cate_2 = 0.9020, MacroF1_cate_3 = 0.6756, MicroF1_cate_3 = 0.6859, Acc_cate_3 = 0.6859, AP_cate_3 = 0.9444, MacroF1_over_categories = 0.6665, MicroF1_over_categories = 0.6710, MacroAP_over_categories = 0.8657, MacroAcc_over_categories = 0.6710, MacroF1_mask_1 = 0.4109, MicroF1_mask_1 = 0.5206, Acc_mask_1 = 0.5206, AP_mask_1 = 0.0909, MacroF1_mask_2 = 0.4701, MicroF1_mask_2 = 0.4701, Acc_mask_2 = 0.4701, AP_mask_2 = 0.3701, MacroF1_mask_3 = 0.4900, MicroF1_mask_3 = 0.6247, Acc_mask_3 = 0.6247, AP_mask_3 = 0.6799, MacroF1_mask_4 = 0.5344, MicroF1_mask_4 = 0.9241, Acc_mask_4 = 0.9241, AP_mask_4 = 0.9824, MacroF1_cate_0_mask_1 = 0.3221, MicroF1_cate_0_mask_1 = 0.3796, Acc_cate_0_mask_1 = 0.3796, AP_cate_0_mask_1 = 0.0840, MacroF1_cate_0_mask_2 = 0.4462, MicroF1_cate_0_mask_2 = 0.4869, Acc_cate_0_mask_2 = 0.4869, AP_cate_0_mask_2 = 0.5029, MacroF1_cate_0_mask_3 = 0.4761, MicroF1_cate_0_mask_3 = 0.5995, Acc_cate_0_mask_3 = 0.5995, AP_cate_0_mask_3 = 0.6702, MacroF1_cate_0_mask_4 = 0.5617, MicroF1_cate_0_mask_4 = 0.8421, Acc_cate_0_mask_4 = 0.8421, AP_cate_0_mask_4 = 0.9447, MacroF1_cate_1_mask_1 = 0.4202, MicroF1_cate_1_mask_1 = 0.5217, Acc_cate_1_mask_1 = 0.5217, AP_cate_1_mask_1 = 0.1030, MacroF1_cate_1_mask_2 = 0.4369, MicroF1_cate_1_mask_2 = 0.4532, Acc_cate_1_mask_2 = 0.4532, AP_cate_1_mask_2 = 0.4334, MacroF1_cate_1_mask_3 = nan, MicroF1_cate_1_mask_3 = 0.0000, Acc_cate_1_mask_3 = nan, AP_cate_1_mask_3 = nan, MacroF1_cate_1_mask_4 = 0.5263, MicroF1_cate_1_mask_4 = 0.9321, Acc_cate_1_mask_4 = 0.9321, AP_cate_1_mask_4 = 0.9867, MacroF1_cate_2_mask_1 = 0.5102, MicroF1_cate_2_mask_1 = 0.7026, Acc_cate_2_mask_1 = 0.7026, AP_cate_2_mask_1 = 0.1515, MacroF1_cate_2_mask_2 = 0.4881, MicroF1_cate_2_mask_2 = 0.5049, Acc_cate_2_mask_2 = 0.5049, AP_cate_2_mask_2 = 0.3070, MacroF1_cate_2_mask_3 = 0.4224, MicroF1_cate_2_mask_3 = 0.6771, Acc_cate_2_mask_3 = 0.6771, AP_cate_2_mask_3 = 0.7122, MacroF1_cate_2_mask_4 = 0.4927, MicroF1_cate_2_mask_4 = 0.9166, Acc_cate_2_mask_4 = 0.9166, AP_cate_2_mask_4 = 0.9704, MacroF1_cate_3_mask_1 = 0.4097, MicroF1_cate_3_mask_1 = 0.5207, Acc_cate_3_mask_1 = 0.5207, AP_cate_3_mask_1 = 0.0832, MacroF1_cate_3_mask_2 = 0.4232, MicroF1_cate_3_mask_2 = 0.4395, Acc_cate_3_mask_2 = 0.4395, AP_cate_3_mask_2 = 0.3521, MacroF1_cate_3_mask_3 = 0.5715, MicroF1_cate_3_mask_3 = 0.6296, Acc_cate_3_mask_3 = 0.6296, AP_cate_3_mask_3 = 0.6771, MacroF1_cate_3_mask_4 = 0.4983, MicroF1_cate_3_mask_4 = 0.9647, Acc_cate_3_mask_4 = 0.9647, AP_cate_3_mask_4 = 0.9932, RMSE = 2.5563, MAE = 1.7954, MAPE = 0.5354, RMSE_cate_0 = 1.7390, MAE_cate_0 = 1.2809, MAPE_cate_0 = 0.5953, RMSE_cate_1 = 2.6011, MAE_cate_1 = 1.9083, MAPE_cate_1 = 0.5365, RMSE_cate_2 = 2.3379, MAE_cate_2 = 1.6683, MAPE_cate_2 = 0.5323, RMSE_cate_3 = 3.1432, MAE_cate_3 = 2.1828, MAPE_cate_3 = 0.4924, RMSE_mask_1 = 0.9050, MAE_mask_1 = 0.7387, MAPE_mask_1 = 0.6398, RMSE_mask_2 = 1.0045, MAE_mask_2 = 0.7585, MAPE_mask_2 = 0.5240, RMSE_mask_3 = 1.2571, MAE_mask_3 = 0.9435, MAPE_mask_3 = 0.5520, RMSE_mask_4 = 2.8165, MAE_mask_4 = 2.0447, MAPE_mask_4 = 0.5284, epochLoss = 6.5181
# MacroF1=0.6692 MicroF1=0.6710 AP=0.8850
#
#   [RUNTIME] Epoch 1: train=2.15s | train+eval=2.81s
#
# ============================================================
# RUNTIME ANALYSIS SUMMARY (STHSL)
# ============================================================
#   Seed:                      10
#   Epochs run:                1
#   Avg train time/epoch:      2.15s (+/- 0.00s)
#   Avg total time/epoch:      2.81s (+/- 0.00s)
#   Per-epoch train times:     ['2.15']
#   Total training time:       2.81s
# ============================================================
#
# Epoch 1/1, Best: MacroF1 = 0.6692, MicroF1 = 0.6710, AP = 0.8850, Acc = 0.6710, MacroF1_cate_0 = 0.5907, MicroF1_cate_0 = 0.5912, Acc_cate_0 = 0.5912, AP_cate_0 = 0.6961, MacroF1_cate_1 = 0.6642, MicroF1_cate_1 = 0.6711, Acc_cate_1 = 0.6711, AP_cate_1 = 0.9205, MacroF1_cate_2 = 0.7357, MicroF1_cate_2 = 0.7358, Acc_cate_2 = 0.7358, AP_cate_2 = 0.9020, MacroF1_cate_3 = 0.6756, MicroF1_cate_3 = 0.6859, Acc_cate_3 = 0.6859, AP_cate_3 = 0.9444, MacroF1_over_categories = 0.6665, MicroF1_over_categories = 0.6710, MacroAP_over_categories = 0.8657, MacroAcc_over_categories = 0.6710, MacroF1_mask_1 = 0.4109, MicroF1_mask_1 = 0.5206, Acc_mask_1 = 0.5206, AP_mask_1 = 0.0909, MacroF1_mask_2 = 0.4701, MicroF1_mask_2 = 0.4701, Acc_mask_2 = 0.4701, AP_mask_2 = 0.3701, MacroF1_mask_3 = 0.4900, MicroF1_mask_3 = 0.6247, Acc_mask_3 = 0.6247, AP_mask_3 = 0.6799, MacroF1_mask_4 = 0.5344, MicroF1_mask_4 = 0.9241, Acc_mask_4 = 0.9241, AP_mask_4 = 0.9824, MacroF1_cate_0_mask_1 = 0.3221, MicroF1_cate_0_mask_1 = 0.3796, Acc_cate_0_mask_1 = 0.3796, AP_cate_0_mask_1 = 0.0840, MacroF1_cate_0_mask_2 = 0.4462, MicroF1_cate_0_mask_2 = 0.4869, Acc_cate_0_mask_2 = 0.4869, AP_cate_0_mask_2 = 0.5029, MacroF1_cate_0_mask_3 = 0.4761, MicroF1_cate_0_mask_3 = 0.5995, Acc_cate_0_mask_3 = 0.5995, AP_cate_0_mask_3 = 0.6702, MacroF1_cate_0_mask_4 = 0.5617, MicroF1_cate_0_mask_4 = 0.8421, Acc_cate_0_mask_4 = 0.8421, AP_cate_0_mask_4 = 0.9447, MacroF1_cate_1_mask_1 = 0.4202, MicroF1_cate_1_mask_1 = 0.5217, Acc_cate_1_mask_1 = 0.5217, AP_cate_1_mask_1 = 0.1030, MacroF1_cate_1_mask_2 = 0.4369, MicroF1_cate_1_mask_2 = 0.4532, Acc_cate_1_mask_2 = 0.4532, AP_cate_1_mask_2 = 0.4334, MacroF1_cate_1_mask_3 = nan, MicroF1_cate_1_mask_3 = 0.0000, Acc_cate_1_mask_3 = nan, AP_cate_1_mask_3 = nan, MacroF1_cate_1_mask_4 = 0.5263, MicroF1_cate_1_mask_4 = 0.9321, Acc_cate_1_mask_4 = 0.9321, AP_cate_1_mask_4 = 0.9867, MacroF1_cate_2_mask_1 = 0.5102, MicroF1_cate_2_mask_1 = 0.7026, Acc_cate_2_mask_1 = 0.7026, AP_cate_2_mask_1 = 0.1515, MacroF1_cate_2_mask_2 = 0.4881, MicroF1_cate_2_mask_2 = 0.5049, Acc_cate_2_mask_2 = 0.5049, AP_cate_2_mask_2 = 0.3070, MacroF1_cate_2_mask_3 = 0.4224, MicroF1_cate_2_mask_3 = 0.6771, Acc_cate_2_mask_3 = 0.6771, AP_cate_2_mask_3 = 0.7122, MacroF1_cate_2_mask_4 = 0.4927, MicroF1_cate_2_mask_4 = 0.9166, Acc_cate_2_mask_4 = 0.9166, AP_cate_2_mask_4 = 0.9704, MacroF1_cate_3_mask_1 = 0.4097, MicroF1_cate_3_mask_1 = 0.5207, Acc_cate_3_mask_1 = 0.5207, AP_cate_3_mask_1 = 0.0832, MacroF1_cate_3_mask_2 = 0.4232, MicroF1_cate_3_mask_2 = 0.4395, Acc_cate_3_mask_2 = 0.4395, AP_cate_3_mask_2 = 0.3521, MacroF1_cate_3_mask_3 = 0.5715, MicroF1_cate_3_mask_3 = 0.6296, Acc_cate_3_mask_3 = 0.6296, AP_cate_3_mask_3 = 0.6771, MacroF1_cate_3_mask_4 = 0.4983, MicroF1_cate_3_mask_4 = 0.9647, Acc_cate_3_mask_4 = 0.9647, AP_cate_3_mask_4 = 0.9932, RMSE = 2.5563, MAE = 1.7954, MAPE = 0.5354, RMSE_cate_0 = 1.7390, MAE_cate_0 = 1.2809, MAPE_cate_0 = 0.5953, RMSE_cate_1 = 2.6011, MAE_cate_1 = 1.9083, MAPE_cate_1 = 0.5365, RMSE_cate_2 = 2.3379, MAE_cate_2 = 1.6683, MAPE_cate_2 = 0.5323, RMSE_cate_3 = 3.1432, MAE_cate_3 = 2.1828, MAPE_cate_3 = 0.4924, RMSE_mask_1 = 0.9050, MAE_mask_1 = 0.7387, MAPE_mask_1 = 0.6398, RMSE_mask_2 = 1.0045, MAE_mask_2 = 0.7585, MAPE_mask_2 = 0.5240, RMSE_mask_3 = 1.2571, MAE_mask_3 = 0.9435, MAPE_mask_3 = 0.5520, RMSE_mask_4 = 2.8165, MAE_mask_4 = 2.0447, MAPE_mask_4 = 0.5284, epochLoss = 6.5181
#
# ===== SUMMARY: best result per seed =====
# seed=10: {'MacroF1': 0.6691738872954389, 'MicroF1': 0.6709980288411661, 'AP': 0.8850431014695516, 'Acc': 0.6709980288411661, 'MacroF1_cate_0': 0.5906569440371361, 'MicroF1_cate_0': 0.5912439049693952, 'Acc_cate_0': 0.5912439049693952, 'AP_cate_0': 0.696099561763501, 'MacroF1_cate_1': 0.6642355056681548, 'MicroF1_cate_1': 0.6711277103433966, 'Acc_cate_1': 0.6711277103433966, 'AP_cate_1': 0.9205247306335318, 'MacroF1_cate_2': 0.7357128983332415, 'MicroF1_cate_2': 0.7357609710550888, 'Acc_cate_2': 0.7357609710550888, 'AP_cate_2': 0.901961108209773, 'MacroF1_cate_3': 0.6755650526767722, 'MicroF1_cate_3': 0.6858595289967839, 'Acc_cate_3': 0.6858595289967839, 'AP_cate_3': 0.9443976449013111, 'MacroF1_over_categories': 0.6665426001788262, 'MicroF1_over_categories': 0.6709980288411661, 'MacroAP_over_categories': 0.8657457613770292, 'MacroAcc_over_categories': 0.6709980288411661, 'MacroF1_mask_1': 0.41089692851213344, 'MicroF1_mask_1': 0.5205958352333181, 'Acc_mask_1': 0.5205958352333181, 'AP_mask_1': 0.0909311394507808, 'MacroF1_mask_2': 0.47006283190493714, 'MicroF1_mask_2': 0.4700854700854701, 'Acc_mask_2': 0.4700854700854701, 'AP_mask_2': 0.370071043964988, 'MacroF1_mask_3': 0.48999286496844235, 'MicroF1_mask_3': 0.6246990024079807, 'Acc_mask_3': 0.6246990024079807, 'AP_mask_3': 0.6799218205328916, 'MacroF1_mask_4': 0.5343836524740383, 'MicroF1_mask_4': 0.9241061130334487, 'Acc_mask_4': 0.9241061130334487, 'AP_mask_4': 0.9823588178057949, 'MacroF1_cate_0_mask_1': 0.3221465500099423, 'MicroF1_cate_0_mask_1': 0.379587732528909, 'Acc_cate_0_mask_1': 0.379587732528909, 'AP_cate_0_mask_1': 0.08395825345888203, 'MacroF1_cate_0_mask_2': 0.4461825769190866, 'MicroF1_cate_0_mask_2': 0.4869281045751634, 'Acc_cate_0_mask_2': 0.4869281045751634, 'AP_cate_0_mask_2': 0.5029044934707196, 'MacroF1_cate_0_mask_3': 0.47605450346420325, 'MicroF1_cate_0_mask_3': 0.5995246583481878, 'Acc_cate_0_mask_3': 0.5995246583481878, 'AP_cate_0_mask_3': 0.6702277939318557, 'MacroF1_cate_0_mask_4': 0.5616728895876028, 'MicroF1_cate_0_mask_4': 0.8421317244846657, 'Acc_cate_0_mask_4': 0.8421317244846657, 'AP_cate_0_mask_4': 0.9446735715163694, 'MacroF1_cate_1_mask_1': 0.4202444891100201, 'MicroF1_cate_1_mask_1': 0.5216874628639334, 'Acc_cate_1_mask_1': 0.5216874628639334, 'AP_cate_1_mask_1': 0.10301024743574222, 'MacroF1_cate_1_mask_2': 0.43689790172876436, 'MicroF1_cate_1_mask_2': 0.4531590413943355, 'Acc_cate_1_mask_2': 0.4531590413943355, 'AP_cate_1_mask_2': 0.43341266721707716, 'MacroF1_cate_1_mask_3': nan, 'MicroF1_cate_1_mask_3': 0.0, 'Acc_cate_1_mask_3': nan, 'AP_cate_1_mask_3': nan, 'MacroF1_cate_1_mask_4': 0.5262948980311905, 'MicroF1_cate_1_mask_4': 0.9321266968325792, 'Acc_cate_1_mask_4': 0.9321266968325792, 'AP_cate_1_mask_4': 0.9866909458395354, 'MacroF1_cate_2_mask_1': 0.5101740125906, 'MicroF1_cate_2_mask_1': 0.7026143790849673, 'Acc_cate_2_mask_1': 0.7026143790849673, 'AP_cate_2_mask_1': 0.15150886670209082, 'MacroF1_cate_2_mask_2': 0.4880612219544314, 'MicroF1_cate_2_mask_2': 0.5049019607843137, 'Acc_cate_2_mask_2': 0.5049019607843137, 'AP_cate_2_mask_2': 0.30701255036726416, 'MacroF1_cate_2_mask_3': 0.4224403275451536, 'MicroF1_cate_2_mask_3': 0.677124183006536, 'Acc_cate_2_mask_3': 0.677124183006536, 'AP_cate_2_mask_3': 0.7121504605870411, 'MacroF1_cate_2_mask_4': 0.49270413573700955, 'MicroF1_cate_2_mask_4': 0.9165888577653284, 'Acc_cate_2_mask_4': 0.9165888577653284, 'AP_cate_2_mask_4': 0.9704286945580786, 'MacroF1_cate_3_mask_1': 0.4097498246434417, 'MicroF1_cate_3_mask_1': 0.5206971677559913, 'Acc_cate_3_mask_1': 0.5206971677559913, 'AP_cate_3_mask_1': 0.08315010702399303, 'MacroF1_cate_3_mask_2': 0.42320469314575404, 'MicroF1_cate_3_mask_2': 0.4395424836601307, 'Acc_cate_3_mask_2': 0.4395424836601307, 'AP_cate_3_mask_2': 0.3520971736320847, 'MacroF1_cate_3_mask_3': 0.5715462332528003, 'MicroF1_cate_3_mask_3': 0.6296296296296297, 'Acc_cate_3_mask_3': 0.6296296296296297, 'AP_cate_3_mask_3': 0.6771100148784004, 'MacroF1_cate_3_mask_4': 0.4983148 ...
# Total time spent: 3.6559
# Detected seed folders under /home/jovyan/STHSL/Save/CHI_5km
#
# Checkpoint move completed (CHI_5km / baseline)
#   Mode     : seed-aware
#   Moved    : 1
#   Skipped  : 0
# Found 1 checkpoints under Logs/baseline/CHI_5km (seed folders) (sorted by seed, epoch).
#
# [seed 10 epoch 1] Running: /opt/conda/bin/python test.py --data CHI_5km --use_ode_option baseline --checkpoint Logs/baseline/CHI_5km/seed_10/_seed_10_epoch_1_MAE_1.8_MAPE_0.54_MicroF1_0.671.pth --batch 16 --eval_metrics all
# [seed 10 epoch 1] Writing: tests_validation/baseline/CHI_5km/seed_10_epoch_1_main.txt
# [seed 10 epoch 1] OK
# \n$ python /home/jovyan/STHSL/metrics_extraction.py /home/jovyan/STHSL/tests_validation/baseline/CHI_5km --city chicago
#
# Reading folder: /home/jovyan/STHSL/tests_validation/baseline/CHI_5km
#
# City: chicago — using category map: {'0': 'ASSAULT', '1': 'BATTERY', '2': 'CRIMINAL DAMAGE', '3': 'THEFT'}
# Processing seed10_epoch1: seed_10_epoch_1_main.txt
#
# Created: /home/jovyan/STHSL/tests_validation/baseline/CHI_5km/metrics_all_epochs_pivot.csv
#
#                       seed10_epoch1  seed_avg_seed10  all_seeds_avg
# MacroF1                      0.6692           0.6692         0.6692
# MicroF1                      0.6710           0.6710         0.6710
# AP                           0.8850           0.8850         0.8850
# Acc                          0.6710           0.6710         0.6710
# MacroF1_ASSAULT              0.5907           0.5907         0.5907
# ...                             ...              ...            ...
# MAPE_sparsity_<=0.75         0.5520           0.5520         0.5520
# RMSE_sparsity_<=1.0          2.8165           2.8165         2.8165
# MAE_sparsity_<=1.0           2.0447           2.0447         2.0447
# MAPE_sparsity_<=1.0          0.5284           0.5284         0.5284
# epochLoss                   65.1810          65.1810        65.1810
#
# [67 rows x 3 columns]
#
# Running: python /home/jovyan/STHSL/analyse_metrics.py /home/jovyan/STHSL/tests_validation/baseline/CHI_5km/metrics_all_epochs_pivot.csv
#
# ==============================
# BEST (SEED, EPOCH) PER METRIC (across all seeds/epochs)
# ==============================
#
#                   Metric  BestSeed  BestEpoch  BestValue Goal(min/max)
#                  MacroF1        10          1     0.6692           max
#                  MicroF1        10          1     0.6710           max
#                       AP        10          1     0.8850           max
#                      Acc        10          1     0.6710           max
#          MacroF1_ASSAULT        10          1     0.5907           min
#          MicroF1_ASSAULT        10          1     0.5912           min
#              Acc_ASSAULT        10          1     0.5912           max
#               AP_ASSAULT        10          1     0.6961           max
#          MacroF1_BATTERY        10          1     0.6642           min
#          MicroF1_BATTERY        10          1     0.6711           min
#              Acc_BATTERY        10          1     0.6711           max
#               AP_BATTERY        10          1     0.9205           max
#  MacroF1_CRIMINAL DAMAGE        10          1     0.7357           min
#  MicroF1_CRIMINAL DAMAGE        10          1     0.7358           min
#      Acc_CRIMINAL DAMAGE        10          1     0.7358           max
#       AP_CRIMINAL DAMAGE        10          1     0.9020           max
#            MacroF1_THEFT        10          1     0.6756           min
#            MicroF1_THEFT        10          1     0.6859           min
#                Acc_THEFT        10          1     0.6859           max
#                 AP_THEFT        10          1     0.9444           max
#  MacroF1_over_categories        10          1     0.6665           max
#  MacroAP_over_categories        10          1     0.8657           max
# MacroAcc_over_categories        10          1     0.6710           max
#  MacroF1_sparsity_<=0.25        10          1     0.4109           min
#  MicroF1_sparsity_<=0.25        10          1     0.5206           min
#      Acc_sparsity_<=0.25        10          1     0.5206           max
#       AP_sparsity_<=0.25        10          1     0.0909           max
#   MacroF1_sparsity_<=0.5        10          1     0.4701           min
#   MicroF1_sparsity_<=0.5        10          1     0.4701           min
#       Acc_sparsity_<=0.5        10          1     0.4701           max
#        AP_sparsity_<=0.5        10          1     0.3701           max
#  MacroF1_sparsity_<=0.75        10          1     0.4900           min
#  MicroF1_sparsity_<=0.75        10          1     0.6247           min
#      Acc_sparsity_<=0.75        10          1     0.6247           max
#       AP_sparsity_<=0.75        10          1     0.6799           max
#   MacroF1_sparsity_<=1.0        10          1     0.5344           min
#   MicroF1_sparsity_<=1.0        10          1     0.9241           min
#       Acc_sparsity_<=1.0        10          1     0.9241           max
#        AP_sparsity_<=1.0        10          1     0.9824           max
#                     RMSE        10          1     2.5563           min
#                      MAE        10          1     1.7954           min
#                     MAPE        10          1     0.5354           min
#             RMSE_ASSAULT        10          1     1.7390           min
#              MAE_ASSAULT        10          1     1.2809           min
#             MAPE_ASSAULT        10          1     0.5953           min
#             RMSE_BATTERY        10          1     2.6011           min
#              MAE_BATTERY        10          1     1.9083           min
#             MAPE_BATTERY        10          1     0.5365           min
#     RMSE_CRIMINAL DAMAGE        10          1     2.3379           min
#      MAE_CRIMINAL DAMAGE        10          1     1.6683           min
#     MAPE_CRIMINAL DAMAGE        10          1     0.5323           min
#               RMSE_THEFT        10          1     3.1432           min
#                MAE_THEFT        10          1     2.1828           min
#               MAPE_THEFT        10          1     0.4924           min
#     RMSE_sparsity_<=0.25        10          1     0.9050           min
#      MAE_sparsity_<=0.25        10          1     0.7387           min
#     MAPE_sparsity_<=0.25        10          1     0.6398           min
#      RMSE_sparsity_<=0.5        10          1     1.0045           min
#       MAE_sparsity_<=0.5        10          1     0.7585           min
#      MAPE_sparsity_<=0.5        10          1     0.5240           min
#     RMSE_sparsity_<=0.75        10          1     1.2571           min
#      MAE_sparsity_<=0.75        10          1     0.9435           min
#     MAPE_sparsity_<=0.75        10          1     0.5520           min
#      RMSE_sparsity_<=1.0        10          1     2.8165           min
#       MAE_sparsity_<=1.0        10          1     2.0447           min
#      MAPE_sparsity_<=1.0        10          1     0.5284           min
#                epochLoss        10          1    65.1810           min
#
# ==============================
# OVERALL BEST (SEED, EPOCH) BY 'MOST METRICS WON'
# ==============================
# Best (seed, epoch) overall: seed=10 epoch=1 (wins 67 metrics)
#
#
# ==============================
# OVERALL BEST EPOCH WITHIN EACH SEED (wins across metrics)
# ==============================
#
#  Seed  OverallBestEpochWithinSeed  WinsCount
#    10                           1         67
#
# ==============================
# BEST SEED BY AVERAGE-OVER-EPOCHS (per metric)
# ==============================
#
#                   Metric  BestSeedByAvgEpochs  BestValueByAvgEpochs Goal(min/max)
#                  MacroF1                   10                0.6692           max
#                  MicroF1                   10                0.6710           max
#                       AP                   10                0.8850           max
#                      Acc                   10                0.6710           max
#          MacroF1_ASSAULT                   10                0.5907           min
#          MicroF1_ASSAULT                   10                0.5912           min
#              Acc_ASSAULT                   10                0.5912           max
#               AP_ASSAULT                   10                0.6961           max
#          MacroF1_BATTERY                   10                0.6642           min
#          MicroF1_BATTERY                   10                0.6711           min
#              Acc_BATTERY                   10                0.6711           max
#               AP_BATTERY                   10                0.9205           max
#  MacroF1_CRIMINAL DAMAGE                   10                0.7357           min
#  MicroF1_CRIMINAL DAMAGE                   10                0.7358           min
#      Acc_CRIMINAL DAMAGE                   10                0.7358           max
#       AP_CRIMINAL DAMAGE                   10                0.9020           max
#            MacroF1_THEFT                   10                0.6756           min
#            MicroF1_THEFT                   10                0.6859           min
#                Acc_THEFT                   10                0.6859           max
#                 AP_THEFT                   10                0.9444           max
#  MacroF1_over_categories                   10                0.6665           max
#  MacroAP_over_categories                   10                0.8657           max
# MacroAcc_over_categories                   10                0.6710           max
#  MacroF1_sparsity_<=0.25                   10                0.4109           min
#  MicroF1_sparsity_<=0.25                   10                0.5206           min
#      Acc_sparsity_<=0.25                   10                0.5206           max
#       AP_sparsity_<=0.25                   10                0.0909           max
#   MacroF1_sparsity_<=0.5                   10                0.4701           min
#   MicroF1_sparsity_<=0.5                   10                0.4701           min
#       Acc_sparsity_<=0.5                   10                0.4701           max
#        AP_sparsity_<=0.5                   10                0.3701           max
#  MacroF1_sparsity_<=0.75                   10                0.4900           min
#  MicroF1_sparsity_<=0.75                   10                0.6247           min
#      Acc_sparsity_<=0.75                   10                0.6247           max
#       AP_sparsity_<=0.75                   10                0.6799           max
#   MacroF1_sparsity_<=1.0                   10                0.5344           min
#   MicroF1_sparsity_<=1.0                   10                0.9241           min
#       Acc_sparsity_<=1.0                   10                0.9241           max
#        AP_sparsity_<=1.0                   10                0.9824           max
#                     RMSE                   10                2.5563           min
#                      MAE                   10                1.7954           min
#                     MAPE                   10                0.5354           min
#             RMSE_ASSAULT                   10                1.7390           min
#              MAE_ASSAULT                   10                1.2809           min
#             MAPE_ASSAULT                   10                0.5953           min
#             RMSE_BATTERY                   10                2.6011           min
#              MAE_BATTERY                   10                1.9083           min
#             MAPE_BATTERY                   10                0.5365           min
#     RMSE_CRIMINAL DAMAGE                   10                2.3379           min
#      MAE_CRIMINAL DAMAGE                   10                1.6683           min
#     MAPE_CRIMINAL DAMAGE                   10                0.5323           min
#               RMSE_THEFT                   10                3.1432           min
#                MAE_THEFT                   10                2.1828           min
#               MAPE_THEFT                   10                0.4924           min
#     RMSE_sparsity_<=0.25                   10                0.9050           min
#      MAE_sparsity_<=0.25                   10                0.7387           min
#     MAPE_sparsity_<=0.25                   10                0.6398           min
#      RMSE_sparsity_<=0.5                   10                1.0045           min
#       MAE_sparsity_<=0.5                   10                0.7585           min
#      MAPE_sparsity_<=0.5                   10                0.5240           min
#     RMSE_sparsity_<=0.75                   10                1.2571           min
#      MAE_sparsity_<=0.75                   10                0.9435           min
#     MAPE_sparsity_<=0.75                   10                0.5520           min
#      RMSE_sparsity_<=1.0                   10                2.8165           min
#       MAE_sparsity_<=1.0                   10                2.0447           min
#      MAPE_sparsity_<=1.0                   10                0.5284           min
#                epochLoss                   10               65.1810           min
#
# Saved: /home/jovyan/STHSL/tests_validation/baseline/CHI_5km/metrics_all_epochs_pivot_ranking_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/CHI_5km/metrics_all_epochs_pivot_ranking_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/CHI_5km/metrics_all_epochs_pivot_summary_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/CHI_5km/metrics_all_epochs_pivot_summary_overall_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/baseline/CHI_5km/metrics_all_epochs_pivot_ranking_best_seed_by_avg.csv

# %%
# !python train.py --data CHI_5km --use_ode_option option1 --device cuda --eval_metrics all --batch 16 --n_traj_samples 2 --ode_method dopri5 --odeint_atol 0.01 --odeint_rtol 0.0001 --gen_layers 2 --gen_dim 64 --gcn_step 2 --horizon 12
step_move_checkpoints("CHI_5km", "option1", on_conflict="overwrite")
# !python metrics_generation.py --data CHI_5km --use_ode_option option1 --device cuda --eval_metrics all --batch 16 --n_traj_samples 2 --ode_method dopri5 --odeint_atol 0.01 --odeint_rtol 0.0001 --gen_layers 2 --gen_dim 64 --gcn_step 2 --horizon 12 --out-dir tests_validation/option1/CHI_5km --save-root Logs/option1/
step_metrics_extraction("CHI_5km", "option1")
step_analyse("CHI_5km", "option1")
# Out:
# self.predir Datasets/common_data/CHI_crime_5km/
# (63, 153, 4)
# Row: 9 , Col: 7
# Sparsity: 0.39399611154638575
# use_ode_option: option1
# ODE option 1 is enabled, STHSL model with option1 components is initialized
# ODE setting --latent 16 --samples 2 --method dopri5                 --atol 0.010000 --rtol 0.000100 --gen_layer 2 --gen_dim 64 --num_nodes 63
# DEBUG SHAPES status: True
#
# ===== SEED 10 =====
# start training...
# ===== TRAINING ARGS =====
# lr: 0.001
# weight_decay: 0.0001
# cr: 0.8
# ir: 1
# t: 0.05
# batch: 16
# epoch: 1
# latdim: 16
# temporalRange: 30
# cateNum: 4
# data: CHI_5km
# kernelSize: 3
# border: 0.5
# hyperNum: 128
# dropRateL: 0.2
# dropRateG: 0.1
# use_ode_option: option1
# n_traj_samples: 2
# ode_method: dopri5
# odeint_atol: 0.01
# odeint_rtol: 0.0001
# gen_layers: 2
# gen_dim: 64
# save_latent: false
# gcn_step: 2
# rnn_units: 64
# horizon: 12
# filter_type: 2
# device: cuda
# tstEpoch: 1
# save: ./Save/
# checkpoint: ./Save/NYC/
# eval_metrics: all
# f1_label_threshold: 0.0
# f1_pred_threshold: 0.5
# seeds: [10]
# row: 9
# col: 7
# offNum: 4
# areaNum: 63
# trnDays: 547
# valDays: 31
# tstDays: 153
# decay_step: 34
# ==========================
# time grid: torch.Size([12])
# n_traj_samples: 2
# Decoder input Z_t shape: torch.Size([16, 252, 64])
# Labels shape: torch.Size([16, 63, 4])
# Epoch  1 Training Time 5.457s
# Epoch 1/1, Train Loss =  12.9557,  preLoss =  8.8581
# Val (MicroF1+MacroF1) increase from -1.0000 to 1.6407
# Epoch 1/1, Test: MacroF1 = 0.8223, MicroF1 = 0.8244, AP = 0.9243, Acc = 0.8244, MacroF1_cate_0 = 0.7671, MicroF1_cate_0 = 0.7762, Acc_cate_0 = 0.7762, AP_cate_0 = 0.8309, MacroF1_cate_1 = 0.8614, MicroF1_cate_1 = 0.8631, Acc_cate_1 = 0.8631, AP_cate_1 = 0.9447, MacroF1_cate_2 = 0.7826, MicroF1_cate_2 = 0.7831, Acc_cate_2 = 0.7831, AP_cate_2 = 0.9144, MacroF1_cate_3 = 0.8745, MicroF1_cate_3 = 0.8752, Acc_cate_3 = 0.8752, AP_cate_3 = 0.9559, MacroF1_over_categories = 0.8214, MicroF1_over_categories = 0.8244, MacroAP_over_categories = 0.9115, MacroAcc_over_categories = 0.8244, MacroF1_mask_1 = 0.5150, MicroF1_mask_1 = 0.7779, Acc_mask_1 = 0.7779, AP_mask_1 = 0.1074, MacroF1_mask_2 = 0.4768, MicroF1_mask_2 = 0.5646, Acc_mask_2 = 0.5646, AP_mask_2 = 0.3728, MacroF1_mask_3 = 0.5085, MicroF1_mask_3 = 0.6123, Acc_mask_3 = 0.6123, AP_mask_3 = 0.6949, MacroF1_mask_4 = 0.5340, MicroF1_mask_4 = 0.9236, Acc_mask_4 = 0.9236, AP_mask_4 = 0.9862, MacroF1_cate_0_mask_1 = 0.4745, MicroF1_cate_0_mask_1 = 0.9030, Acc_cate_0_mask_1 = 0.9030, AP_cate_0_mask_1 = 0.0944, MacroF1_cate_0_mask_2 = 0.4985, MicroF1_cate_0_mask_2 = 0.5294, Acc_cate_0_mask_2 = 0.5294, AP_cate_0_mask_2 = 0.4807, MacroF1_cate_0_mask_3 = 0.4915, MicroF1_cate_0_mask_3 = 0.6209, Acc_cate_0_mask_3 = 0.6209, AP_cate_0_mask_3 = 0.6874, MacroF1_cate_0_mask_4 = 0.4744, MicroF1_cate_0_mask_4 = 0.9025, Acc_cate_0_mask_4 = 0.9025, AP_cate_0_mask_4 = 0.9595, MacroF1_cate_1_mask_1 = 0.5146, MicroF1_cate_1_mask_1 = 0.7035, Acc_cate_1_mask_1 = 0.7035, AP_cate_1_mask_1 = 0.1552, MacroF1_cate_1_mask_2 = 0.4200, MicroF1_cate_1_mask_2 = 0.5839, Acc_cate_1_mask_2 = 0.5839, AP_cate_1_mask_2 = 0.4314, MacroF1_cate_1_mask_3 = nan, MicroF1_cate_1_mask_3 = 0.0000, Acc_cate_1_mask_3 = nan, AP_cate_1_mask_3 = nan, MacroF1_cate_1_mask_4 = 0.5464, MicroF1_cate_1_mask_4 = 0.8999, Acc_cate_1_mask_4 = 0.8999, AP_cate_1_mask_4 = 0.9889, MacroF1_cate_2_mask_1 = 0.4950, MicroF1_cate_2_mask_1 = 0.7288, Acc_cate_2_mask_1 = 0.7288, AP_cate_2_mask_1 = 0.0927, MacroF1_cate_2_mask_2 = 0.4956, MicroF1_cate_2_mask_2 = 0.5180, Acc_cate_2_mask_2 = 0.5180, AP_cate_2_mask_2 = 0.3155, MacroF1_cate_2_mask_3 = 0.4595, MicroF1_cate_2_mask_3 = 0.6575, Acc_cate_2_mask_3 = 0.6575, AP_cate_2_mask_3 = 0.7205, MacroF1_cate_2_mask_4 = 0.5533, MicroF1_cate_2_mask_4 = 0.9185, Acc_cate_2_mask_4 = 0.9185, AP_cate_2_mask_4 = 0.9802, MacroF1_cate_3_mask_1 = 0.5027, MicroF1_cate_3_mask_1 = 0.7429, Acc_cate_3_mask_1 = 0.7429, AP_cate_3_mask_1 = 0.0974, MacroF1_cate_3_mask_2 = 0.3997, MicroF1_cate_3_mask_2 = 0.6144, Acc_cate_3_mask_2 = 0.6144, AP_cate_3_mask_2 = 0.3808, MacroF1_cate_3_mask_3 = 0.5041, MicroF1_cate_3_mask_3 = 0.5054, Acc_cate_3_mask_3 = 0.5054, AP_cate_3_mask_3 = 0.6536, MacroF1_cate_3_mask_4 = 0.5114, MicroF1_cate_3_mask_4 = 0.9637, Acc_cate_3_mask_4 = 0.9637, AP_cate_3_mask_4 = 0.9942, RMSE = 2.4281, MAE = 1.7438, MAPE = 0.5764, RMSE_cate_0 = 1.5393, MAE_cate_0 = 1.1518, MAPE_cate_0 = 0.5689, RMSE_cate_1 = 2.5554, MAE_cate_1 = 1.9189, MAPE_cate_1 = 0.5873, RMSE_cate_2 = 2.1361, MAE_cate_2 = 1.5846, MAPE_cate_2 = 0.6046, RMSE_cate_3 = 3.0158, MAE_cate_3 = 2.1572, MAPE_cate_3 = 0.5466, RMSE_mask_1 = 0.8792, MAE_mask_1 = 0.7650, MAPE_mask_1 = 0.6627, RMSE_mask_2 = 1.1799, MAE_mask_2 = 0.9625, MAPE_mask_2 = 0.6786, RMSE_mask_3 = 1.2617, MAE_mask_3 = 0.9556, MAPE_mask_3 = 0.5391, RMSE_mask_4 = 2.6646, MAE_mask_4 = 1.9637, MAPE_mask_4 = 0.5718, epochLoss = 5.8967
# MacroF1=0.8223 MicroF1=0.8244 AP=0.9243
#
#   [RUNTIME] Epoch 1: train=5.46s | train+eval=6.63s
#
# ============================================================
# RUNTIME ANALYSIS SUMMARY (STHSL)
# ============================================================
#   Seed:                      10
#   Epochs run:                1
#   Avg train time/epoch:      5.46s (+/- 0.00s)
#   Avg total time/epoch:      6.63s (+/- 0.00s)
#   Per-epoch train times:     ['5.46']
#   Total training time:       6.63s
# ============================================================
#
# Epoch 1/1, Best: MacroF1 = 0.8223, MicroF1 = 0.8244, AP = 0.9243, Acc = 0.8244, MacroF1_cate_0 = 0.7671, MicroF1_cate_0 = 0.7762, Acc_cate_0 = 0.7762, AP_cate_0 = 0.8309, MacroF1_cate_1 = 0.8614, MicroF1_cate_1 = 0.8631, Acc_cate_1 = 0.8631, AP_cate_1 = 0.9447, MacroF1_cate_2 = 0.7826, MicroF1_cate_2 = 0.7831, Acc_cate_2 = 0.7831, AP_cate_2 = 0.9144, MacroF1_cate_3 = 0.8745, MicroF1_cate_3 = 0.8752, Acc_cate_3 = 0.8752, AP_cate_3 = 0.9559, MacroF1_over_categories = 0.8214, MicroF1_over_categories = 0.8244, MacroAP_over_categories = 0.9115, MacroAcc_over_categories = 0.8244, MacroF1_mask_1 = 0.5150, MicroF1_mask_1 = 0.7779, Acc_mask_1 = 0.7779, AP_mask_1 = 0.1074, MacroF1_mask_2 = 0.4768, MicroF1_mask_2 = 0.5646, Acc_mask_2 = 0.5646, AP_mask_2 = 0.3728, MacroF1_mask_3 = 0.5085, MicroF1_mask_3 = 0.6123, Acc_mask_3 = 0.6123, AP_mask_3 = 0.6949, MacroF1_mask_4 = 0.5340, MicroF1_mask_4 = 0.9236, Acc_mask_4 = 0.9236, AP_mask_4 = 0.9862, MacroF1_cate_0_mask_1 = 0.4745, MicroF1_cate_0_mask_1 = 0.9030, Acc_cate_0_mask_1 = 0.9030, AP_cate_0_mask_1 = 0.0944, MacroF1_cate_0_mask_2 = 0.4985, MicroF1_cate_0_mask_2 = 0.5294, Acc_cate_0_mask_2 = 0.5294, AP_cate_0_mask_2 = 0.4807, MacroF1_cate_0_mask_3 = 0.4915, MicroF1_cate_0_mask_3 = 0.6209, Acc_cate_0_mask_3 = 0.6209, AP_cate_0_mask_3 = 0.6874, MacroF1_cate_0_mask_4 = 0.4744, MicroF1_cate_0_mask_4 = 0.9025, Acc_cate_0_mask_4 = 0.9025, AP_cate_0_mask_4 = 0.9595, MacroF1_cate_1_mask_1 = 0.5146, MicroF1_cate_1_mask_1 = 0.7035, Acc_cate_1_mask_1 = 0.7035, AP_cate_1_mask_1 = 0.1552, MacroF1_cate_1_mask_2 = 0.4200, MicroF1_cate_1_mask_2 = 0.5839, Acc_cate_1_mask_2 = 0.5839, AP_cate_1_mask_2 = 0.4314, MacroF1_cate_1_mask_3 = nan, MicroF1_cate_1_mask_3 = 0.0000, Acc_cate_1_mask_3 = nan, AP_cate_1_mask_3 = nan, MacroF1_cate_1_mask_4 = 0.5464, MicroF1_cate_1_mask_4 = 0.8999, Acc_cate_1_mask_4 = 0.8999, AP_cate_1_mask_4 = 0.9889, MacroF1_cate_2_mask_1 = 0.4950, MicroF1_cate_2_mask_1 = 0.7288, Acc_cate_2_mask_1 = 0.7288, AP_cate_2_mask_1 = 0.0927, MacroF1_cate_2_mask_2 = 0.4956, MicroF1_cate_2_mask_2 = 0.5180, Acc_cate_2_mask_2 = 0.5180, AP_cate_2_mask_2 = 0.3155, MacroF1_cate_2_mask_3 = 0.4595, MicroF1_cate_2_mask_3 = 0.6575, Acc_cate_2_mask_3 = 0.6575, AP_cate_2_mask_3 = 0.7205, MacroF1_cate_2_mask_4 = 0.5533, MicroF1_cate_2_mask_4 = 0.9185, Acc_cate_2_mask_4 = 0.9185, AP_cate_2_mask_4 = 0.9802, MacroF1_cate_3_mask_1 = 0.5027, MicroF1_cate_3_mask_1 = 0.7429, Acc_cate_3_mask_1 = 0.7429, AP_cate_3_mask_1 = 0.0974, MacroF1_cate_3_mask_2 = 0.3997, MicroF1_cate_3_mask_2 = 0.6144, Acc_cate_3_mask_2 = 0.6144, AP_cate_3_mask_2 = 0.3808, MacroF1_cate_3_mask_3 = 0.5041, MicroF1_cate_3_mask_3 = 0.5054, Acc_cate_3_mask_3 = 0.5054, AP_cate_3_mask_3 = 0.6536, MacroF1_cate_3_mask_4 = 0.5114, MicroF1_cate_3_mask_4 = 0.9637, Acc_cate_3_mask_4 = 0.9637, AP_cate_3_mask_4 = 0.9942, RMSE = 2.4281, MAE = 1.7438, MAPE = 0.5764, RMSE_cate_0 = 1.5393, MAE_cate_0 = 1.1518, MAPE_cate_0 = 0.5689, RMSE_cate_1 = 2.5554, MAE_cate_1 = 1.9189, MAPE_cate_1 = 0.5873, RMSE_cate_2 = 2.1361, MAE_cate_2 = 1.5846, MAPE_cate_2 = 0.6046, RMSE_cate_3 = 3.0158, MAE_cate_3 = 2.1572, MAPE_cate_3 = 0.5466, RMSE_mask_1 = 0.8792, MAE_mask_1 = 0.7650, MAPE_mask_1 = 0.6627, RMSE_mask_2 = 1.1799, MAE_mask_2 = 0.9625, MAPE_mask_2 = 0.6786, RMSE_mask_3 = 1.2617, MAE_mask_3 = 0.9556, MAPE_mask_3 = 0.5391, RMSE_mask_4 = 2.6646, MAE_mask_4 = 1.9637, MAPE_mask_4 = 0.5718, epochLoss = 5.8967
#
# ===== SUMMARY: best result per seed =====
# seed=10: {'MacroF1': 0.8222936319283056, 'MicroF1': 0.8243853096794274, 'AP': 0.9243320480364241, 'Acc': 0.8243853096794274, 'MacroF1_cate_0': 0.7670559460496911, 'MicroF1_cate_0': 0.7762215997510116, 'Acc_cate_0': 0.7762215997510116, 'AP_cate_0': 0.8309179208040539, 'MacroF1_cate_1': 0.861351004646958, 'MicroF1_cate_1': 0.8630563336445689, 'Acc_cate_1': 0.8630563336445689, 'AP_cate_1': 0.9447018634677049, 'MacroF1_cate_2': 0.7825649326919109, 'MicroF1_cate_2': 0.783068783068783, 'Acc_cate_2': 0.783068783068783, 'AP_cate_2': 0.9144384357588303, 'MacroF1_cate_3': 0.8744585935314478, 'MicroF1_cate_3': 0.8751945222533458, 'Acc_cate_3': 0.8751945222533458, 'AP_cate_3': 0.9558598534067964, 'MacroF1_over_categories': 0.8213576192300018, 'MicroF1_over_categories': 0.8243853096794274, 'MacroAP_over_categories': 0.9114795183593465, 'MacroAcc_over_categories': 0.8243853096794274, 'MacroF1_mask_1': 0.5150126104343302, 'MicroF1_mask_1': 0.7779297765617875, 'Acc_mask_1': 0.7779297765617875, 'AP_mask_1': 0.10737005078347221, 'MacroF1_mask_2': 0.4767532145608488, 'MicroF1_mask_2': 0.5646053293112117, 'Acc_mask_2': 0.5646053293112117, 'AP_mask_2': 0.37278190437631253, 'MacroF1_mask_3': 0.5085042905130148, 'MicroF1_mask_3': 0.6123151014791882, 'Acc_mask_3': 0.6123151014791882, 'AP_mask_3': 0.6948503032893354, 'MacroF1_mask_4': 0.5339661940889187, 'MicroF1_mask_4': 0.9236447520184544, 'Acc_mask_4': 0.9236447520184544, 'AP_mask_4': 0.9862045504015591, 'MacroF1_cate_0_mask_1': 0.4745046235138705, 'MicroF1_cate_0_mask_1': 0.9029663147310206, 'Acc_cate_0_mask_1': 0.9029663147310206, 'AP_cate_0_mask_1': 0.09442305712742752, 'MacroF1_cate_0_mask_2': 0.49847484634646033, 'MicroF1_cate_0_mask_2': 0.5294117647058824, 'Acc_cate_0_mask_2': 0.5294117647058824, 'AP_cate_0_mask_2': 0.4807325482436108, 'MacroF1_cate_0_mask_3': 0.49151863343448465, 'MicroF1_cate_0_mask_3': 0.6209150326797386, 'Acc_cate_0_mask_3': 0.6209150326797386, 'AP_cate_0_mask_3': 0.6873676615205178, 'MacroF1_cate_0_mask_4': 0.47436575052854124, 'MicroF1_cate_0_mask_4': 0.9024635495223731, 'Acc_cate_0_mask_4': 0.9024635495223731, 'AP_cate_0_mask_4': 0.9594806419649701, 'MacroF1_cate_1_mask_1': 0.5145535607451839, 'MicroF1_cate_1_mask_1': 0.7035056446821153, 'Acc_cate_1_mask_1': 0.7035056446821153, 'AP_cate_1_mask_1': 0.15522688170551344, 'MacroF1_cate_1_mask_2': 0.41996758079989416, 'MicroF1_cate_1_mask_2': 0.5838779956427015, 'Acc_cate_1_mask_2': 0.5838779956427015, 'AP_cate_1_mask_2': 0.4314194758874584, 'MacroF1_cate_1_mask_3': nan, 'MicroF1_cate_1_mask_3': 0.0, 'Acc_cate_1_mask_3': nan, 'AP_cate_1_mask_3': nan, 'MacroF1_cate_1_mask_4': 0.5463926150460987, 'MicroF1_cate_1_mask_4': 0.8999497234791353, 'Acc_cate_1_mask_4': 0.8999497234791353, 'AP_cate_1_mask_4': 0.9888760791162045, 'MacroF1_cate_2_mask_1': 0.4949567259164871, 'MicroF1_cate_2_mask_1': 0.7287581699346405, 'Acc_cate_2_mask_1': 0.7287581699346405, 'AP_cate_2_mask_1': 0.09273125892825945, 'MacroF1_cate_2_mask_2': 0.4955616465913949, 'MicroF1_cate_2_mask_2': 0.5179738562091504, 'Acc_cate_2_mask_2': 0.5179738562091504, 'AP_cate_2_mask_2': 0.315511812669021, 'MacroF1_cate_2_mask_3': 0.4595476411329465, 'MicroF1_cate_2_mask_3': 0.657516339869281, 'Acc_cate_2_mask_3': 0.657516339869281, 'AP_cate_2_mask_3': 0.7204999335939033, 'MacroF1_cate_2_mask_4': 0.5532630984576065, 'MicroF1_cate_2_mask_4': 0.9184562713974479, 'Acc_cate_2_mask_4': 0.9184562713974479, 'AP_cate_2_mask_4': 0.9801956432074852, 'MacroF1_cate_3_mask_1': 0.5027359529930224, 'MicroF1_cate_3_mask_1': 0.7429193899782135, 'Acc_cate_3_mask_1': 0.7429193899782135, 'AP_cate_3_mask_1': 0.09739633393195435, 'MacroF1_cate_3_mask_2': 0.39967080652401615, 'MicroF1_cate_3_mask_2': 0.6143790849673203, 'Acc_cate_3_mask_2': 0.6143790849673203, 'AP_cate_3_mask_2': 0.3807799505664283, 'MacroF1_cate_3_mask_3': 0.5040908117369887, 'MicroF1_cate_3_mask_3': 0.5054466230936819, 'Acc_cate_3_mask_3': 0.5054466230936819, 'AP_cate_3_mask_3': 0.6536197838052482, 'MacroF1_cate_3_mask_4': 0.51142 ...
# Total time spent: 7.3848
# Detected seed folders under /home/jovyan/STHSL/Save/CHI_5km
#
# Checkpoint move completed (CHI_5km / option1)
#   Mode     : seed-aware
#   Moved    : 1
#   Skipped  : 0
# Found 1 checkpoints under Logs/option1/CHI_5km (seed folders) (sorted by seed, epoch).
#
# [seed 10 epoch 1] Running: /opt/conda/bin/python test.py --data CHI_5km --use_ode_option option1 --checkpoint Logs/option1/CHI_5km/seed_10/_seed_10_epoch_1_MAE_1.74_MAPE_0.58_MicroF1_0.8244.pth --batch 16 --eval_metrics all --n_traj_samples 2 --ode_method dopri5 --odeint_atol 0.01 --odeint_rtol 0.0001 --gen_layers 2 --gen_dim 64 --gcn_step 2 --rnn_units 64 --horizon 12 --filter_type 2
# [seed 10 epoch 1] Writing: tests_validation/option1/CHI_5km/seed_10_epoch_1_main.txt
# [seed 10 epoch 1] OK
# \n$ python /home/jovyan/STHSL/metrics_extraction.py /home/jovyan/STHSL/tests_validation/option1/CHI_5km --city chicago
#
# Reading folder: /home/jovyan/STHSL/tests_validation/option1/CHI_5km
#
# City: chicago — using category map: {'0': 'ASSAULT', '1': 'BATTERY', '2': 'CRIMINAL DAMAGE', '3': 'THEFT'}
# Processing seed10_epoch1: seed_10_epoch_1_main.txt
#
# Created: /home/jovyan/STHSL/tests_validation/option1/CHI_5km/metrics_all_epochs_pivot.csv
#
#                       seed10_epoch1  seed_avg_seed10  all_seeds_avg
# MacroF1                      0.8223           0.8223         0.8223
# MicroF1                      0.8244           0.8244         0.8244
# AP                           0.9243           0.9243         0.9243
# Acc                          0.8244           0.8244         0.8244
# MacroF1_ASSAULT              0.7671           0.7671         0.7671
# ...                             ...              ...            ...
# MAPE_sparsity_<=0.75         0.5391           0.5391         0.5391
# RMSE_sparsity_<=1.0          2.6646           2.6646         2.6646
# MAE_sparsity_<=1.0           1.9637           1.9637         1.9637
# MAPE_sparsity_<=1.0          0.5718           0.5718         0.5718
# epochLoss                   58.9665          58.9665        58.9665
#
# [67 rows x 3 columns]
#
# Running: python /home/jovyan/STHSL/analyse_metrics.py /home/jovyan/STHSL/tests_validation/option1/CHI_5km/metrics_all_epochs_pivot.csv
#
# ==============================
# BEST (SEED, EPOCH) PER METRIC (across all seeds/epochs)
# ==============================
#
#                   Metric  BestSeed  BestEpoch  BestValue Goal(min/max)
#                  MacroF1        10          1     0.8223           max
#                  MicroF1        10          1     0.8244           max
#                       AP        10          1     0.9243           max
#                      Acc        10          1     0.8244           max
#          MacroF1_ASSAULT        10          1     0.7671           min
#          MicroF1_ASSAULT        10          1     0.7762           min
#              Acc_ASSAULT        10          1     0.7762           max
#               AP_ASSAULT        10          1     0.8309           max
#          MacroF1_BATTERY        10          1     0.8614           min
#          MicroF1_BATTERY        10          1     0.8631           min
#              Acc_BATTERY        10          1     0.8631           max
#               AP_BATTERY        10          1     0.9447           max
#  MacroF1_CRIMINAL DAMAGE        10          1     0.7826           min
#  MicroF1_CRIMINAL DAMAGE        10          1     0.7831           min
#      Acc_CRIMINAL DAMAGE        10          1     0.7831           max
#       AP_CRIMINAL DAMAGE        10          1     0.9144           max
#            MacroF1_THEFT        10          1     0.8745           min
#            MicroF1_THEFT        10          1     0.8752           min
#                Acc_THEFT        10          1     0.8752           max
#                 AP_THEFT        10          1     0.9559           max
#  MacroF1_over_categories        10          1     0.8214           max
#  MacroAP_over_categories        10          1     0.9115           max
# MacroAcc_over_categories        10          1     0.8244           max
#  MacroF1_sparsity_<=0.25        10          1     0.5150           min
#  MicroF1_sparsity_<=0.25        10          1     0.7779           min
#      Acc_sparsity_<=0.25        10          1     0.7779           max
#       AP_sparsity_<=0.25        10          1     0.1074           max
#   MacroF1_sparsity_<=0.5        10          1     0.4768           min
#   MicroF1_sparsity_<=0.5        10          1     0.5646           min
#       Acc_sparsity_<=0.5        10          1     0.5646           max
#        AP_sparsity_<=0.5        10          1     0.3728           max
#  MacroF1_sparsity_<=0.75        10          1     0.5085           min
#  MicroF1_sparsity_<=0.75        10          1     0.6123           min
#      Acc_sparsity_<=0.75        10          1     0.6123           max
#       AP_sparsity_<=0.75        10          1     0.6949           max
#   MacroF1_sparsity_<=1.0        10          1     0.5340           min
#   MicroF1_sparsity_<=1.0        10          1     0.9236           min
#       Acc_sparsity_<=1.0        10          1     0.9236           max
#        AP_sparsity_<=1.0        10          1     0.9862           max
#                     RMSE        10          1     2.4281           min
#                      MAE        10          1     1.7438           min
#                     MAPE        10          1     0.5764           min
#             RMSE_ASSAULT        10          1     1.5393           min
#              MAE_ASSAULT        10          1     1.1518           min
#             MAPE_ASSAULT        10          1     0.5689           min
#             RMSE_BATTERY        10          1     2.5554           min
#              MAE_BATTERY        10          1     1.9189           min
#             MAPE_BATTERY        10          1     0.5873           min
#     RMSE_CRIMINAL DAMAGE        10          1     2.1361           min
#      MAE_CRIMINAL DAMAGE        10          1     1.5846           min
#     MAPE_CRIMINAL DAMAGE        10          1     0.6046           min
#               RMSE_THEFT        10          1     3.0158           min
#                MAE_THEFT        10          1     2.1572           min
#               MAPE_THEFT        10          1     0.5466           min
#     RMSE_sparsity_<=0.25        10          1     0.8792           min
#      MAE_sparsity_<=0.25        10          1     0.7650           min
#     MAPE_sparsity_<=0.25        10          1     0.6627           min
#      RMSE_sparsity_<=0.5        10          1     1.1799           min
#       MAE_sparsity_<=0.5        10          1     0.9625           min
#      MAPE_sparsity_<=0.5        10          1     0.6786           min
#     RMSE_sparsity_<=0.75        10          1     1.2617           min
#      MAE_sparsity_<=0.75        10          1     0.9556           min
#     MAPE_sparsity_<=0.75        10          1     0.5391           min
#      RMSE_sparsity_<=1.0        10          1     2.6646           min
#       MAE_sparsity_<=1.0        10          1     1.9637           min
#      MAPE_sparsity_<=1.0        10          1     0.5718           min
#                epochLoss        10          1    58.9665           min
#
# ==============================
# OVERALL BEST (SEED, EPOCH) BY 'MOST METRICS WON'
# ==============================
# Best (seed, epoch) overall: seed=10 epoch=1 (wins 67 metrics)
#
#
# ==============================
# OVERALL BEST EPOCH WITHIN EACH SEED (wins across metrics)
# ==============================
#
#  Seed  OverallBestEpochWithinSeed  WinsCount
#    10                           1         67
#
# ==============================
# BEST SEED BY AVERAGE-OVER-EPOCHS (per metric)
# ==============================
#
#                   Metric  BestSeedByAvgEpochs  BestValueByAvgEpochs Goal(min/max)
#                  MacroF1                   10                0.8223           max
#                  MicroF1                   10                0.8244           max
#                       AP                   10                0.9243           max
#                      Acc                   10                0.8244           max
#          MacroF1_ASSAULT                   10                0.7671           min
#          MicroF1_ASSAULT                   10                0.7762           min
#              Acc_ASSAULT                   10                0.7762           max
#               AP_ASSAULT                   10                0.8309           max
#          MacroF1_BATTERY                   10                0.8614           min
#          MicroF1_BATTERY                   10                0.8631           min
#              Acc_BATTERY                   10                0.8631           max
#               AP_BATTERY                   10                0.9447           max
#  MacroF1_CRIMINAL DAMAGE                   10                0.7826           min
#  MicroF1_CRIMINAL DAMAGE                   10                0.7831           min
#      Acc_CRIMINAL DAMAGE                   10                0.7831           max
#       AP_CRIMINAL DAMAGE                   10                0.9144           max
#            MacroF1_THEFT                   10                0.8745           min
#            MicroF1_THEFT                   10                0.8752           min
#                Acc_THEFT                   10                0.8752           max
#                 AP_THEFT                   10                0.9559           max
#  MacroF1_over_categories                   10                0.8214           max
#  MacroAP_over_categories                   10                0.9115           max
# MacroAcc_over_categories                   10                0.8244           max
#  MacroF1_sparsity_<=0.25                   10                0.5150           min
#  MicroF1_sparsity_<=0.25                   10                0.7779           min
#      Acc_sparsity_<=0.25                   10                0.7779           max
#       AP_sparsity_<=0.25                   10                0.1074           max
#   MacroF1_sparsity_<=0.5                   10                0.4768           min
#   MicroF1_sparsity_<=0.5                   10                0.5646           min
#       Acc_sparsity_<=0.5                   10                0.5646           max
#        AP_sparsity_<=0.5                   10                0.3728           max
#  MacroF1_sparsity_<=0.75                   10                0.5085           min
#  MicroF1_sparsity_<=0.75                   10                0.6123           min
#      Acc_sparsity_<=0.75                   10                0.6123           max
#       AP_sparsity_<=0.75                   10                0.6949           max
#   MacroF1_sparsity_<=1.0                   10                0.5340           min
#   MicroF1_sparsity_<=1.0                   10                0.9236           min
#       Acc_sparsity_<=1.0                   10                0.9236           max
#        AP_sparsity_<=1.0                   10                0.9862           max
#                     RMSE                   10                2.4281           min
#                      MAE                   10                1.7438           min
#                     MAPE                   10                0.5764           min
#             RMSE_ASSAULT                   10                1.5393           min
#              MAE_ASSAULT                   10                1.1518           min
#             MAPE_ASSAULT                   10                0.5689           min
#             RMSE_BATTERY                   10                2.5554           min
#              MAE_BATTERY                   10                1.9189           min
#             MAPE_BATTERY                   10                0.5873           min
#     RMSE_CRIMINAL DAMAGE                   10                2.1361           min
#      MAE_CRIMINAL DAMAGE                   10                1.5846           min
#     MAPE_CRIMINAL DAMAGE                   10                0.6046           min
#               RMSE_THEFT                   10                3.0158           min
#                MAE_THEFT                   10                2.1572           min
#               MAPE_THEFT                   10                0.5466           min
#     RMSE_sparsity_<=0.25                   10                0.8792           min
#      MAE_sparsity_<=0.25                   10                0.7650           min
#     MAPE_sparsity_<=0.25                   10                0.6627           min
#      RMSE_sparsity_<=0.5                   10                1.1799           min
#       MAE_sparsity_<=0.5                   10                0.9625           min
#      MAPE_sparsity_<=0.5                   10                0.6786           min
#     RMSE_sparsity_<=0.75                   10                1.2617           min
#      MAE_sparsity_<=0.75                   10                0.9556           min
#     MAPE_sparsity_<=0.75                   10                0.5391           min
#      RMSE_sparsity_<=1.0                   10                2.6646           min
#       MAE_sparsity_<=1.0                   10                1.9637           min
#      MAPE_sparsity_<=1.0                   10                0.5718           min
#                epochLoss                   10               58.9665           min
#
# Saved: /home/jovyan/STHSL/tests_validation/option1/CHI_5km/metrics_all_epochs_pivot_ranking_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/CHI_5km/metrics_all_epochs_pivot_ranking_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/CHI_5km/metrics_all_epochs_pivot_summary_per_seed.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/CHI_5km/metrics_all_epochs_pivot_summary_overall_seed_epoch.csv
# Saved: /home/jovyan/STHSL/tests_validation/option1/CHI_5km/metrics_all_epochs_pivot_ranking_best_seed_by_avg.csv

# %%
# !python train.py --data CHI_5km --use_ode_option option2 --device cuda --eval_metrics all --batch 16 --n_traj_samples 1 --ode_method dopri5 --odeint_atol 0.001 --odeint_rtol 0.001 --gen_layers 1 --gen_dim 64 --gcn_step 1 --horizon 12
# step_move_checkpoints("CHI_5km", "option2", on_conflict="overwrite")
# !python metrics_generation.py --data CHI_5km --use_ode_option option2 --device cuda --eval_metrics all --batch 16 --n_traj_samples 1 --ode_method dopri5 --odeint_atol 0.001 --odeint_rtol 0.001 --gen_layers 1 --gen_dim 64 --gcn_step 1 --horizon 12 --out-dir tests_validation/option2/CHI_5km --save-root Logs/option2/
# step_metrics_extraction("CHI_5km", "option2")
# step_analyse("CHI_5km", "option2")

# %% [markdown]
# ## Evaluation of model with default parameters

# %% [markdown]
# ### Evaluation using different seeds 3km

# %%
# step_train("NYC", "baseline")
# step_move_checkpoints("NYC", "baseline", on_conflict="overwrite")
# step_test_metrics_generation("NYC", "baseline")
# step_metrics_extraction("NYC", "baseline")
# step_analyse("NYC", "baseline")

# %%
# step_train("NYC", "option1")
# step_move_checkpoints("NYC", "option1", on_conflict="overwrite")
# step_test_metrics_generation("NYC", "option1")
# step_metrics_extraction("NYC", "option1")
# step_analyse("NYC", "option1")

# %%
# step_train("NYC", "option2")
# step_move_checkpoints("NYC", "option2", on_conflict="overwrite")
# step_test_metrics_generation("NYC", "option2")
# step_metrics_extraction("NYC", "option2")
# step_analyse("NYC", "option2")

# %%
# step_train("CHI", "baseline")
# step_move_checkpoints("CHI", "baseline", on_conflict="overwrite")
# step_test_metrics_generation("CHI", "baseline")
# step_metrics_extraction("CHI", "baseline")
# step_analyse("CHI", "baseline")

# %%
# step_train("CHI", "option1")
# step_move_checkpoints("CHI", "option1", on_conflict="overwrite")
# step_test_metrics_generation("CHI", "option1")
# step_metrics_extraction("CHI", "option1")
# step_analyse("CHI", "option1")

# %%
# step_train("CHI", "option2")
# step_move_checkpoints("CHI", "option2", on_conflict="overwrite")
# step_test_metrics_generation("CHI", "option2")
# step_metrics_extraction("CHI", "option2")
# step_analyse("CHI", "option2")

# %% [markdown]
# ### Evaluation using different seeds 5km

# %%
# step_train("NYC_5km", "baseline")
# step_move_checkpoints("NYC_5km", "baseline", on_conflict="overwrite")
# step_test_metrics_generation("NYC_5km", "baseline")
# step_metrics_extraction("NYC_5km", "baseline")
# step_analyse("NYC_5km", "baseline")

# %%
# step_train("NYC_5km", "option1")
# step_move_checkpoints("NYC_5km", "option1", on_conflict="overwrite")
# step_test_metrics_generation("NYC_5km", "option1")
# step_metrics_extraction("NYC_5km", "option1")
# step_analyse("NYC_5km", "option1")

# %%
# step_train("NYC_5km", "option2")
# step_move_checkpoints("NYC_5km", "option2", on_conflict="overwrite")
# step_test_metrics_generation("NYC_5km", "option2")
# step_metrics_extraction("NYC_5km", "option2")
# step_analyse("NYC_5km", "option2")

# %%
# step_train("CHI_5km", "baseline")
# step_move_checkpoints("CHI_5km", "baseline", on_conflict="overwrite")
# step_test_metrics_generation("CHI_5km", "baseline")
# step_metrics_extraction("CHI_5km", "baseline")
# step_analyse("CHI_5km", "baseline")

# %%
# step_train("CHI_5km", "option1")
# step_move_checkpoints("CHI_5km", "option1", on_conflict="overwrite")
# step_test_metrics_generation("CHI_5km", "option1")
# step_metrics_extraction("CHI_5km", "option1")
# step_analyse("CHI_5km", "option1")

# %%
# step_train("CHI_5km", "option2")
# step_move_checkpoints("CHI_5km", "option2", on_conflict="overwrite")
# step_test_metrics_generation("CHI_5km", "option2")
# step_metrics_extraction("CHI_5km", "option2")
# step_analyse("CHI_5km", "option2")

# %% [markdown]
# # other datasets evaluations

# %% [markdown]
# ## Evaluation of error and accuracy metrics separately for all datasets

# %% [markdown]
# ### SEATTLE dataset

# %%
# !python train.py --data SEA --use_ode_option baseline --device cuda --eval_metrics error
# step_move_checkpoints("SEA", "baseline", on_conflict="overwrite")
# step_test_metrics_generation("SEA", "baseline")
# step_metrics_extraction("SEA", "baseline")
# step_analyse("SEA", "baseline")

# %%
# !python train.py --data SEA --use_ode_option option1 --device cuda --eval_metrics error
# step_move_checkpoints("SEA", "option1", on_conflict="overwrite")
# step_test_metrics_generation("SEA", "option1")
# step_metrics_extraction("SEA", "option1")
# step_analyse("SEA", "option1")

# %%
# !python train.py --data SEA --use_ode_option option2 --device cuda --eval_metrics error
# step_move_checkpoints("SEA", "option2", on_conflict="overwrite")
# step_test_metrics_generation("SEA", "option2")
# step_metrics_extraction("SEA", "option2")
# step_analyse("SEA", "option2")

# %%
# !pwd
# !mv /home/jovyan/STHSL/Logs/* /home/jovyan/error_metrics_10seeds_10epochs/SEA/Logs/
# !mv /home/jovyan/STHSL/tests_validation/* /home/jovyan/error_metrics_10seeds_10epochs/SEA/tests_validation/

# %%
# !python train.py --data SEA --use_ode_option baseline --device cuda --eval_metrics accuracy
# step_move_checkpoints("SEA", "baseline", on_conflict="overwrite")
# step_test_metrics_generation("SEA", "baseline")
# step_metrics_extraction("SEA", "baseline")
# step_analyse("SEA", "baseline")

# %%
# !python train.py --data SEA --use_ode_option option1 --device cuda --eval_metrics accuracy
# step_move_checkpoints("SEA", "option1", on_conflict="overwrite")
# step_test_metrics_generation("SEA", "option1")
# step_metrics_extraction("SEA", "option1")
# step_analyse("SEA", "option1")

# %%
# !python train.py --data SEA --use_ode_option option2 --device cuda --eval_metrics accuracy
# step_move_checkpoints("SEA", "option2", on_conflict="overwrite")
# step_test_metrics_generation("SEA", "option2")
# step_metrics_extraction("SEA", "option2")
# step_analyse("SEA", "option2")

# %%
# !pwd
# !mv /home/jovyan/STHSL/Logs/* /home/jovyan/accuracy_metrics_10seeds_10epochs/SEA/Logs
# !mv /home/jovyan/STHSL/tests_validation/* /home/jovyan/accuracy_metrics_10seeds_10epochs/tests_validation/SEA/tests_validation

# %% [markdown]
# ### LA dataset

# %%
# !python train.py --data LA --use_ode_option baseline --device cuda --eval_metrics error
# step_move_checkpoints("LA", "baseline", on_conflict="overwrite")
# step_test_metrics_generation("LA", "baseline")
# step_metrics_extraction("LA", "baseline")
# step_analyse("LA", "baseline")

# %%
# !python train.py --data LA --use_ode_option option1 --device cuda --eval_metrics error
# step_move_checkpoints("LA", "option1", on_conflict="overwrite")
# step_test_metrics_generation("LA", "option1")
# step_metrics_extraction("LA", "option1")
# step_analyse("LA", "option1")

# %%
# !python train.py --data LA --use_ode_option option2 --device cuda --eval_metrics error
# step_move_checkpoints("LA", "option2", on_conflict="overwrite")
# step_test_metrics_generation("LA", "option2")
# step_metrics_extraction("LA", "option2")
# step_analyse("LA", "option2")

# %%
# !pwd
# !mv /home/jovyan/STHSL/Logs/* /home/jovyan/error_metrics_10seeds_10epochs/LA/Logs/
# !mv /home/jovyan/STHSL/tests_validation/* /home/jovyan/error_metrics_10seeds_10epochs/LA/tests_validation/

# %%
# !python train.py --data LA --use_ode_option baseline --device cuda --eval_metrics accuracy
# step_move_checkpoints("LA", "baseline", on_conflict="overwrite")
# step_test_metrics_generation("LA", "baseline")
# step_metrics_extraction("LA", "baseline")
# step_analyse("LA", "baseline")

# %%
# !python train.py --data LA --use_ode_option option1 --device cuda --eval_metrics accuracy
# step_move_checkpoints("LA", "option1", on_conflict="overwrite")
# step_test_metrics_generation("LA", "option1")
# step_metrics_extraction("LA", "option1")
# step_analyse("LA", "option1")

# %%
# !python train.py --data LA --use_ode_option option2 --device cuda --eval_metrics accuracy
# step_move_checkpoints("LA", "option2", on_conflict="overwrite")
# step_test_metrics_generation("LA", "option2")
# step_metrics_extraction("LA", "option2")
# step_analyse("LA", "option2")

# %%
# !pwd
# !mv /home/jovyan/STHSL/Logs/* /home/jovyan/accuracy_metrics_10seeds_10epochs/LA/Logs/
# !mv /home/jovyan/STHSL/tests_validation/* /home/jovyan/accuracy_metrics_10seeds_10epochs/LA/tests_validation/

# %% [markdown]
# ### NYC dataset

# %%
# !python train.py --data NYC --use_ode_option baseline --device cuda --eval_metrics error
# step_move_checkpoints("NYC", "baseline", on_conflict="overwrite")
# step_test_metrics_generation("NYC", "baseline")
# step_metrics_extraction("NYC", "baseline")
# step_analyse("NYC", "baseline")

# %%
# !python train.py --data NYC --use_ode_option option1 --device cuda --eval_metrics error
# step_move_checkpoints("NYC", "option1", on_conflict="overwrite")
# step_test_metrics_generation("NYC", "option1")
# step_metrics_extraction("NYC", "option1")
# step_analyse("NYC", "option1")

# %%
# !python train.py --data NYC --use_ode_option option2 --device cuda --eval_metrics error
# step_move_checkpoints("NYC", "option2", on_conflict="overwrite")
# step_test_metrics_generation("NYC", "option2")
# step_metrics_extraction("NYC", "option2")
# step_analyse("NYC", "option2")

# %%
# !pwd
# !mv /home/jovyan/STHSL/Logs/* /home/jovyan/error_metrics_10seeds_10epochs/Logs/
# !mv /home/jovyan/STHSL/tests_validation/*/home/jovyan/error_metrics_10seeds_10epochs/tests_validation/

# %%
# !./cleanup_experiments.sh --dataset all --arch all --target all -y

# %%
# !python train.py --data NYC --use_ode_option baseline --device cuda --eval_metrics accuracy
# step_move_checkpoints("NYC", "baseline", on_conflict="overwrite")
# step_test_metrics_generation("NYC", "baseline")
# step_metrics_extraction("NYC", "baseline")
# step_analyse("NYC", "baseline")

# %%
# !python train.py --data NYC --use_ode_option option1 --device cuda --eval_metrics accuracy
# step_move_checkpoints("NYC", "option1", on_conflict="overwrite")
# step_test_metrics_generation("NYC", "option1")
# step_metrics_extraction("NYC", "option1")
# step_analyse("NYC", "option1")

# %%
# !python train.py --data NYC --use_ode_option option2 --device cuda --eval_metrics accuracy
# step_move_checkpoints("NYC", "option2", on_conflict="overwrite")
# step_test_metrics_generation("NYC", "option2")
# step_metrics_extraction("NYC", "option2")
# step_analyse("NYC", "option2")

# %% [markdown]
# ### CHICAGO dataset

# %%
# !python train.py --data CHI --use_ode_option baseline --device cuda --eval_metrics error
# step_move_checkpoints("CHI", "baseline", on_conflict="overwrite")
# step_test_metrics_generation("CHI", "baseline")
# step_metrics_extraction("CHI", "baseline")
# step_analyse("CHI", "baseline")

# %%
# !python train.py --data CHI --use_ode_option option1 --device cuda --eval_metrics error
# step_move_checkpoints("CHI", "option1", on_conflict="overwrite")
# step_test_metrics_generation("CHI", "option1")
# step_metrics_extraction("CHI", "option1")
# step_analyse("CHI", "option1")

# %%
# !python train.py --data CHI --use_ode_option option2 --device cuda --eval_metrics error
# step_move_checkpoints("CHI", "option2", on_conflict="overwrite")
# step_test_metrics_generation("CHI", "option2")
# step_metrics_extraction("CHI", "option2")
# step_analyse("CHI", "option2")

# %%
# !python train.py --data CHI --use_ode_option baseline --device cuda --eval_metrics accuracy
# step_move_checkpoints("CHI", "baseline", on_conflict="overwrite")
# step_test_metrics_generation("CHI", "baseline")
# step_metrics_extraction("CHI", "baseline")
# step_analyse("CHI", "baseline")

# %%
# !python train.py --data CHI --use_ode_option option1 --device cuda --eval_metrics accuracy
# step_move_checkpoints("CHI", "option1", on_conflict="overwrite")
# step_test_metrics_generation("CHI", "option1")
# step_metrics_extraction("CHI", "option1")
# step_analyse("CHI", "option1")

# %%
# !python train.py --data CHI --use_ode_option option2 --device cuda --eval_metrics accuracy
# step_move_checkpoints("CHI", "option2", on_conflict="overwrite")
# step_test_metrics_generation("CHI", "option2")
# step_metrics_extraction("CHI", "option2")
# step_analyse("CHI", "option2")

# %%
# test cell
